# %% [markdown]
# ## Creating a logistic regression model in Python!

# %%
# Reference: https://github.com/susanli2016/Machine-Learning-with-Python/blob/master/Logistic%20Regression%20balanced.ipynb

# %% [markdown]
# ### Import necessary libraries:

# %%
import pandas as pd
import numpy as np
from sklearn import preprocessing
import matplotlib.pyplot as plt

plt.rc("font", size=14) 

from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split
import seaborn as sns
sns.set(style="white")
sns.set(style="whitegrid", color_codes=True)

import matplotlib
import matplotlib.pyplot as plt
import matplotlib.dates as mdates

#from mpl_toolkits.basemap import Basemap


import os
import datetime
import pytz
import re

import peakutils
import statsmodels.api as sm

import requests

#Read data from a local csv file:

##Will change this to scrape files from the Smartfin.org website later.
#data = pd.read_csv('Motion_13735.CSV', header=0)   
#data = data.dropna()

#Print out the column headings:
#print(data.shape)
#print(list(data.columns))
# Out:
# C:\Users\evans\Anaconda3\lib\site-packages\statsmodels\tools\_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %% [markdown]
# ### Summary of specific ride IDs:

# %%
#Make sure the ride_id and the footage file match up:
ride_ids = ['15692']
footage_file = './Labelled_Footage/Footage3.txt'


#ride_ids = ['14827']
# 14743 - Motion Control July 10th
# 14750 - Magnetometer Control July 11th
# 14814 - Pool Displacement Control July 17th
# 14815 - Compass Orientation (Lying on Charger Side) July 19th
# 14816 - Orientation w Higher Sampling (Lying on Charger Side) July 20th
# 14827 - Pool Displacement Control w Higher Sampling (Jul 23)
# 14888 - First Buoy Calibration Experiment (July 30)
# 15218 - Jasmine's Second Ride Sesh filmed with GoPro (Aug 29) //no footage
# 15629 - Jasmine's First Ride Sesh filmed with VIRB (Oct. 24) //first labelled footage!
# 15669 - Jasmine's Second Ride Sesh filmed with VIRB (Nov. 7) //second labelled footage!
# 15692 - Jasmine's 3rd Ride Sesh filmed with VIRB (Nov. 9) //third labelled footage!
# 15686 - Jasmine's 4th Ride Sesh filmed with VIRB (Nov. 11) //fourth labelled footage!

# %% [markdown]
# ## Fin ID Scraper (pulls dataframes for specific ride id from website):

# %%
#%% Fin ID scraper
# Input fin ID, get all ride IDs
# base URL to which we'll append given fin IDs
fin_url_base = 'http://surf.smartfin.org/fin/'

# Look for the following text in the HTML contents in fcn below
str_id_ride = 'rideId = \'' # backslash allows us to look for single quote
str_id_date = 'var date = \'' # backslash allows us to look for single quote

#%% Ride ID scraper
# Input ride ID, get ocean and motion CSVs
# Base URL to which we'll append given ride IDs
ride_url_base = 'https://surf.smartfin.org/ride/'

# Look for the following text in the HTML contents in fcn below
str_id_csv = 'img id="temperatureChart" class="chart" src="' 

def get_csv_from_ride_id(rid):
    # Build URL for each individual ride
    ride_url = ride_url_base+str(rid)
    print(ride_url)
    
    # Get contents of ride_url
    html_contents = requests.get(ride_url).text
    
    # Find CSV identifier 
    loc_csv_id = html_contents.find(str_id_csv)
    
    # Different based on whether user logged in with FB or Google
    offset_googleOAuth = [46, 114]
    offset_facebkOAuth = [46, 112]
    if html_contents[loc_csv_id+59] == 'f': # Facebook login
        off0 = offset_facebkOAuth[0]
        off1 = offset_facebkOAuth[1]
    else: # Google login
        off0 = offset_googleOAuth[0]
        off1 = offset_googleOAuth[1]
        
    csv_id_longstr = html_contents[loc_csv_id+off0:loc_csv_id+off1]
    
#    print(csv_id_longstr)
    
    # Stitch together full URL for CSV
    if ("media" in csv_id_longstr) & ("Calibration" not in html_contents): # other junk URLs can exist and break everything
        
        ocean_csv_url = 'https://surf.smartfin.org/'+csv_id_longstr+'Ocean.CSV'
        motion_csv_url = 'https://surf.smartfin.org/'+csv_id_longstr+'Motion.CSV'
        
        print(ocean_csv_url)
        # Go to ocean_csv_url and grab contents (theoretically, a CSV)
        ocean_df_small = pd.read_csv(ocean_csv_url, parse_dates = [0])
        elapsed_timedelta = (ocean_df_small['UTC']-ocean_df_small['UTC'][0])
        ocean_df_small['elapsed'] = elapsed_timedelta/np.timedelta64(1, 's')
        
        motion_df_small = pd.read_csv(motion_csv_url, parse_dates = [0])
        
        # Reindex on timestamp if there are at least a few rows
        if len(ocean_df_small) > 1:
            ocean_df_small.set_index('UTC', drop = True, append = False, inplace = True)
            motion_df_small.set_index('UTC', drop = True, append = False, inplace = True)
            
            #print(ocean_df_small)
            #print(motion_df_small)
            
            #May need to change this sampling interval:
            sample_interval = '33ms'
            
            
            ocean_df_small_resample = ocean_df_small.resample(sample_interval).mean()
            motion_df_small_resample = motion_df_small.resample(sample_interval).mean()
            
            # No need to save many extra rows with no fix
            motion_df_small = motion_df_small[~np.isnan(motion_df_small.Latitude)]
            
            return ocean_df_small_resample, motion_df_small_resample

    else:
        ocean_df_small_resample = pd.DataFrame() # empty DF just so something is returned
        motion_df_small_resample = pd.DataFrame() 
        return ocean_df_small_resample, motion_df_small_resample
    
appended_ocean_list = [] # list of DataFrames from original CSVs
appended_motion_list = []
appended_multiIndex = [] # fin_id & ride_id used to identify each DataFrame

## Nested loops (for each fin ID, find all ride IDs, then build a DataFrame from all ride CSVs)
## (Here, ride IDS are either ocean or motion dataframes)
count_good_fins = 0
    
# Loop over ride_ids and find CSVs
for rid in ride_ids:
    try:
        new_ocean_df, new_motion_df = get_csv_from_ride_id(rid) # get given ride's CSV from its ride ID using function above
        print(len(new_ocean_df))
        print(len(new_motion_df))
        if not new_ocean_df.empty: # Calibration rides, for example
            # Append only if DF isn't empty. There may be a better way to control empty DFs which are created above
            appended_multiIndex.append(str(rid)) # build list to be multiIndex of future DataFrame
            appended_ocean_list.append(new_ocean_df)
            appended_motion_list.append(new_motion_df)
            print("Ride data has been uploaded.")
            #print("Ride: ", rid, "data has been uploaded.")
            count_good_fins += 1
        
    except: 
        print("Ride threw an exception!")
        #print("Ride ", rid, "threw an exception!")    

#%% Build the "Master" DataFrame

# appended_ocean_df.summary()
df_keys = tuple(appended_multiIndex) # keys gotta be a tuple, a list which data in it cannot be changed
ocean_df = pd.concat(appended_ocean_list, keys = df_keys, names=['ride_id'])
motion_df = pd.concat(appended_motion_list, keys = df_keys, names = ['ride_id'])


##Here, maybe just use info from the motion_df and don't worry about ocean_df data for now.
##If you do want ocean_df data, look at how Phil was getting it from "July 10th and 11th Calibration" jupyter notebook file.

#We can also check to see if the surfboard was recording "in-water-freq" or 
#"out-of-water-freq" based on how many NaN values we see. 
print(motion_df)
# Out:
# https://surf.smartfin.org/ride/15692
# https://surf.smartfin.org/media/201811/google_105349665704999793400_0006667E229D_181109191556_Ocean.CSV
# 149397
# 149434
# Ride data has been uploaded.
#                                                   Time  IMU A1  IMU A2  \
# ride_id UTC
# 15692   2018-11-09 19:16:03.789000+00:00  1.414743e+09   493.0    48.0
#         2018-11-09 19:16:03.822000+00:00           NaN     NaN     NaN
#         2018-11-09 19:16:03.855000+00:00           NaN     NaN     NaN
#         2018-11-09 19:16:03.888000+00:00           NaN     NaN     NaN
#         2018-11-09 19:16:03.921000+00:00           NaN     NaN     NaN
# ...                                                ...     ...     ...
#         2018-11-09 20:38:14.946000+00:00           NaN     NaN     NaN
#         2018-11-09 20:38:14.979000+00:00           NaN     NaN     NaN
#         2018-11-09 20:38:15.012000+00:00           NaN     NaN     NaN
#         2018-11-09 20:38:15.045000+00:00           NaN     NaN     NaN
#         2018-11-09 20:38:15.078000+00:00  1.419644e+09   501.0   -11.0
#
#                                           IMU A3  IMU G1  IMU G2  IMU G3  \
# ride_id UTC
# 15692   2018-11-09 19:16:03.789000+00:00   110.0    75.0  -124.0   -86.0
#         2018-11-09 19:16:03.822000+00:00     NaN     NaN     NaN     NaN
#         2018-11-09 19:16:03.855000+00:00     NaN     NaN     NaN     NaN
#         2018-11-09 19:16:03.888000+00:00     NaN     NaN     NaN     NaN
#         2018-11-09 19:16:03.921000+00:00     NaN     NaN     NaN     NaN
# ...                                          ...     ...     ...     ...
#         2018-11-09 20:38:14.946000+00:00     NaN     NaN     NaN     NaN
#         2018-11-09 20:38:14.979000+00:00     NaN     NaN     NaN     NaN
#         2018-11-09 20:38:15.012000+00:00     NaN     NaN     NaN     NaN
#         2018-11-09 20:38:15.045000+00:00     NaN     NaN     NaN     NaN
#         2018-11-09 20:38:15.078000+00:00    98.0    10.0    20.0     2.0
#
#                                           IMU M1  IMU M2  IMU M3   Latitude  \
# ride_id UTC
# 15692   2018-11-09 19:16:03.789000+00:00  -309.0   209.0    39.0  3285871.0
#         2018-11-09 19:16:03.822000+00:00     NaN     NaN     NaN        NaN
#         2018-11-09 19:16:03.855000+00:00     NaN     NaN     NaN        NaN
#         2018-11-09 19:16:03.888000+00:00     NaN     NaN     NaN        NaN
#         2018-11-09 19:16:03.921000+00:00     NaN     NaN     NaN        NaN
# ...                                          ...     ...     ...        ...
#         2018-11-09 20:38:14.946000+00:00     NaN     NaN     NaN        NaN
#         2018-11-09 20:38:14.979000+00:00     NaN     NaN     NaN        NaN
#         2018-11-09 20:38:15.012000+00:00     NaN     NaN     NaN        NaN
#         2018-11-09 20:38:15.045000+00:00     NaN     NaN     NaN        NaN
#         2018-11-09 20:38:15.078000+00:00  -309.0   265.0    35.0        NaN
#
#                                            Longitude
# ride_id UTC
# 15692   2018-11-09 19:16:03.789000+00:00 -11725690.0
#         2018-11-09 19:16:03.822000+00:00         NaN
#         2018-11-09 19:16:03.855000+00:00         NaN
#         2018-11-09 19:16:03.888000+00:00         NaN
#         2018-11-09 19:16:03.921000+00:00         NaN
# ...                                              ...
#         2018-11-09 20:38:14.946000+00:00         NaN
#         2018-11-09 20:38:14.979000+00:00         NaN
#         2018-11-09 20:38:15.012000+00:00         NaN
#         2018-11-09 20:38:15.045000+00:00         NaN
#         2018-11-09 20:38:15.078000+00:00         NaN
#
# [149434 rows x 12 columns]

# %% [markdown]
# ## Drop the NA values from the dataframe:

# %%
#Drop the latitude and longitude values since most of them are Nan:
motion_df_dropped = motion_df.drop(columns=['Latitude', 'Longitude'])


#Drop the NAN values from the motion data:
motion_df_dropped = motion_df_dropped.dropna(axis=0, how='any')
print(len(motion_df_dropped))
print(motion_df_dropped)
# Out:
# 21645
#                                                   Time  IMU A1  IMU A2  \
# ride_id UTC
# 15692   2018-11-09 19:16:03.789000+00:00  1.414743e+09   493.0    48.0
#         2018-11-09 19:16:04.053000+00:00  1.414743e+09   513.0    89.0
#         2018-11-09 19:16:04.284000+00:00  1.414743e+09   494.0    92.0
#         2018-11-09 19:16:04.548000+00:00  1.414744e+09   421.0   205.0
#         2018-11-09 19:16:04.812000+00:00  1.414744e+09   534.0   306.0
# ...                                                ...     ...     ...
#         2018-11-09 20:38:14.055000+00:00  1.419643e+09   501.0   -11.0
#         2018-11-09 20:38:14.319000+00:00  1.419644e+09   501.0   -11.0
#         2018-11-09 20:38:14.583000+00:00  1.419644e+09   502.0   -11.0
#         2018-11-09 20:38:14.814000+00:00  1.419644e+09   501.0   -13.0
#         2018-11-09 20:38:15.078000+00:00  1.419644e+09   501.0   -11.0
#
#                                           IMU A3  IMU G1  IMU G2  IMU G3  \
# ride_id UTC
# 15692   2018-11-09 19:16:03.789000+00:00   110.0    75.0  -124.0   -86.0
#         2018-11-09 19:16:04.053000+00:00    62.0    34.0   -36.0   -92.0
#         2018-11-09 19:16:04.284000+00:00    80.0    69.0   -63.0   -42.0
#         2018-11-09 19:16:04.548000+00:00  -104.0   192.0   -92.0   -37.0
#         2018-11-09 19:16:04.812000+00:00   -32.0  -421.0  -233.0  -229.0
# ...                                          ...     ...     ...     ...
#         2018-11-09 20:38:14.055000+00:00    99.0     9.0    21.0     2.0
#         2018-11-09 20:38:14.319000+00:00    99.0     9.0    20.0     2.0
#         2018-11-09 20:38:14.583000+00:00    99.0    10.0    21.0     1.0
#         2018-11-09 20:38:14.814000+00:00    99.0    10.0    21.0     1.0
#         2018-11-09 20:38:15.078000+00:00    98.0    10.0    20.0     2.0
#
#                                           IMU M1  IMU M2  IMU M3
# ride_id UTC
# 15692   2018-11-09 19:16:03.789000+00:00  -309.0   209.0    39.0
#         2018-11-09 19:16:04.053000+00:00  -320.0   194.0    38.0
#         2018-11-09 19:16:04.284000+00:00  -329.0   189.0    49.0
#         2018-11-09 19:16:04.548000+00:00  -330.0   180.0    64.0
#         2018-11-09 19:16:04.812000+00:00  -325.0   161.0    97.0
# ...                                          ...     ...     ...
#         2018-11-09 20:38:14.055000+00:00  -293.0   259.0    41.0
#         2018-11-09 20:38:14.319000+00:00  -303.0   267.0    37.0
#         2018-11-09 20:38:14.583000+00:00  -308.0   262.0    32.0
#         2018-11-09 20:38:14.814000+00:00  -310.0   260.0    38.0
#         2018-11-09 20:38:15.078000+00:00  -309.0   265.0    35.0
#
# [21645 rows x 10 columns]

# %% [markdown]
# ## Create an elapsed time field to sync Smartfin data with Video Footage:

# %%
#Create an elapsed_timedelta field:

#timedelta_values = (motion_df_dropped['Time']-motion_df_dropped['Time'][0])
#motion_df_dropped.insert(loc=1, column='TimeDelta', value=timedelta_values, drop=True)
motion_df_dropped['TimeDelta'] = (motion_df_dropped['Time']-motion_df_dropped['Time'][0])
#print(elapsed_timedelta)
#motion_df_dropped.head()
motion_df_dropped.head(10)
# Out:
#                                                   Time  IMU A1  IMU A2  \
# ride_id UTC
# 15692   2018-11-09 19:16:03.789000+00:00  1.414743e+09   493.0    48.0
#         2018-11-09 19:16:04.053000+00:00  1.414743e+09   513.0    89.0
#         2018-11-09 19:16:04.284000+00:00  1.414743e+09   494.0    92.0
#         2018-11-09 19:16:04.548000+00:00  1.414744e+09   421.0   205.0
#         2018-11-09 19:16:04.812000+00:00  1.414744e+09   534.0   306.0
#         2018-11-09 19:16:05.043000+00:00  1.414744e+09   455.0   149.0
#         2018-11-09 19:16:05.307000+00:00  1.414744e+09   474.0   342.0
#         2018-11-09 19:16:05.571000+00:00  1.414745e+09   363.0   323.0
#         2018-11-09 19:16:05.802000+00:00  1.414745e+09   -21.0   510.0
#         2018-11-09 19:16:06.066000+00:00  1.414745e+09    35.0   283.0
#
#                                           IMU A3  IMU G1  IMU G2  IMU G3  \
# ride_id UTC
# 15692   2018-11-09 19:16:03.789000+00:00   110.0    75.0  -124.0   -86.0
#         2018-11-09 19:16:04.053000+00:00    62.0    34.0   -36.0   -92.0
#         2018-11-09 19:16:04.284000+00:00    80.0    69.0   -63.0   -42.0
#         2018-11-09 19:16:04.548000+00:00  -104.0   192.0   -92.0   -37.0
#         2018-11-09 19:16:04.812000+00:00   -32.0  -421.0  -233.0  -229.0
#         2018-11-09 19:16:05.043000+00:00  -102.0  -355.0  -376.0  -397.0
#         2018-11-09 19:16:05.307000+00:00  -219.0  -234.0  -527.0  -465.0
#         2018-11-09 19:16:05.571000+00:00  -131.0    60.0  -662.0  -305.0
#         2018-11-09 19:16:05.802000+00:00  -447.0    78.0  -643.0  -153.0
#         2018-11-09 19:16:06.066000+00:00  -132.0  -114.0  -430.0   132.0
#
#                                           IMU M1  IMU M2  IMU M3  TimeDelta
# ride_id UTC
# 15692   2018-11-09 19:16:03.789000+00:00  -309.0   209.0    39.0        0.0
#         2018-11-09 19:16:04.053000+00:00  -320.0   194.0    38.0      252.5
#         2018-11-09 19:16:04.284000+00:00  -329.0   189.0    49.0      501.5
#         2018-11-09 19:16:04.548000+00:00  -330.0   180.0    64.0      753.5
#         2018-11-09 19:16:04.812000+00:00  -325.0   161.0    97.0     1003.5
#         2018-11-09 19:16:05.043000+00:00  -337.0   117.0   151.0     1253.5
#         2018-11-09 19:16:05.307000+00:00  -311.0    25.0   217.0     1504.5
#         2018-11-09 19:16:05.571000+00:00  -238.0    -8.0   272.0     1755.5
#         2018-11-09 19:16:05.802000+00:00  -159.0   -21.0   321.0     2006.5
#         2018-11-09 19:16:06.066000+00:00   -86.0   -38.0   326.0     2258.5

# %% [markdown]
# ## Footage sync code written by Alina:

# %%
#Footage sync code written by Alina: (Miulti-Column)

import time

#simple method: only walking, paddling, floating, surfing
#complex method: columns created based on footage file labels
def label_data( footage_file = 'Footage.txt', labelling_method = 'simple', sync_threshold = 20000 ):
    
    #First, perform sync
    sync_buf = 0
    with open(footage_file) as file:
        # for each reading in footage file: 
        for line in file:     
            
            
            labelled_time = line.split(None, 2) 
            print('labelled_time: ', labelled_time)
            try:
                cur_time = time.strptime(labelled_time[0], '%M:%S')
                print('curr_time: ', cur_time)

            except:
                continue
            labelled_time[1] = labelled_time[1].rstrip()
            if labelled_time[1].lower() == 'sync': #Assumption that first word in sync line is "sync"
                sync_time = cur_time.tm_min * 60 * 1000 + cur_time.tm_sec * 1000
                index = 0
                start = 0
                end = 0
                #Syncing occurs when IMU A2 data is negative for a longer period than the provided threshold
                #Default is 20 seconds
                for data in motion_df_dropped['IMU A2']:
                    if data < 0 and start == 0:
                        start = motion_df_dropped['TimeDelta'][index]
                    elif data > 0 and start != 0:
                        end = motion_df_dropped['TimeDelta'][index]
                        if end - start > sync_threshold:
                            sync_buf = start - sync_time
                            break
                        start = 0
                    index += 1

    accepted_labels = set()
    if labelling_method == 'simple':
        accepted_labels = {'WALKING', 'PADDLING', 'FLOATING', 'SURFING'}

        #Create new DataFrame containing label info
        label_frame = pd.DataFrame(0, index = motion_df_dropped.index, columns = accepted_labels)
        for label in accepted_labels:
            label_frame[label] = [0] * len(motion_df_dropped['Time'])
    
    #Convention of labelled footage text: "MINUTE:SECOND LABEL"
    elapsed_time = 0
    cur_label = ''
    buffer = 0
    with open(footage_file) as file:
        for line in file:
            
            if labelling_method == 'simple':
                labelled_time = line.split(None, 2) #simple categorizes on a one-word basis
            else:
                labelled_time = line.split(None, 1) #complex requires the entire label
                
            #If the first word is not a properly formatted time, the line cannot be read
            try:
                cur_time = time.strptime(labelled_time[0], '%M:%S')
                cur_timeMS = cur_time.tm_min * 60 * 1000 + cur_time.tm_sec * 1000 + sync_buf
            except:
                continue
            labelled_time[1] = labelled_time[1].rstrip() #Remove potential newline
                
            #Check for end of video and modify buffer accordingly
            if labelled_time[1].lower() == 'end of video': #Assumption that label end video with "end of video"
                buffer += cur_timeMS
                
            #----Complex "mode" below: --------
                
            #Modify accepted labels list if reading a new label and in complex mode
            elif labelling_method == 'complex' and (labelled_time[1].upper() not in accepted_labels):
                accepted_labels.add(labelled_time[1].upper())
                if not cur_label:
                    label_frame = pd.DataFrame(0, index = motion_df_dropped.index, columns = accepted_labels)
                label_frame[labelled_time[1].upper()] = [0] * len(motion_df_dropped['Time'])
                
            if labelled_time[1].upper() in accepted_labels:
                while (elapsed_time < len(motion_df_dropped['Time']) and
                      (np.isnan(motion_df_dropped['TimeDelta'][elapsed_time]) or
                       motion_df_dropped['TimeDelta'][elapsed_time] < cur_timeMS + buffer)):
                    if cur_label != '':
                        label_frame[cur_label][elapsed_time] = 1
                    elapsed_time += 1
                if labelled_time[1].upper() != 'end of video':
                    cur_label = labelled_time[1].upper()

    labelled = pd.concat([motion_df_dropped, label_frame], axis = 1)

    return labelled

pd.options.display.max_rows = 5000
pd.options.display.max_columns = 5000

# %%
motion_df_simple = label_data('../Labelled_Footage/Footage3.txt')
motion_df_simple.head(10)
# Out:
# labelled_time:  ['Filename:', 'Footage3.txt']
# labelled_time:  ['Footage', 'taken', 'from: VIRB0016, VIRB0016-2, VIRB0016-3\n']
# labelled_time:  ['Date:', '11/09/18']
# labelled_time:  ['Ride', 'ID:', '15692\n']
# labelled_time:  []
# labelled_time:  ['00:36', 'sync']
# labelled_time:  ['01:07', 'flip', 'board right side up\n']
# labelled_time:  ['01:08', 'walking', 'in water\n']
# labelled_time:  ['01:12', 'push-off']
# labelled_time:  ['01:13', 'paddling', 'into waves\n']
# labelled_time:  ['01:34', 'walking', 'in water\n']
# labelled_time:  ['01:57', 'push-off']
# labelled_time:  ['01:58', 'paddling', 'into waves\n']
# labelled_time:  ['02:37', 'sit-up']
# labelled_time:  ['02:38', 'floating']
# labelled_time:  ['02:54', 'turning', "to surfer's left\n"]
# labelled_time:  ['03:00', 'floating']
# labelled_time:  ['03:38', 'lay-down']
# labelled_time:  ['03:39', 'paddling', 'for a wave\n']
# labelled_time:  ['03:47', 'pop-up']
# labelled_time:  ['03:48', 'surfing']
# labelled_time:  ['03:56', 'step-off']
# labelled_time:  ['03:58', 'walking', 'in water\n']
# labelled_time:  ['04:07', 'push-off']
# labelled_time:  ['04:08', 'paddling', 'into waves\n']
# labelled_time:  ['04:47', 'sit-up']
# labelled_time:  ['04:48', 'floating']
# labelled_time:  ['04:53', 'turning', "to surfer's right\n"]
# labelled_time:  ['04:55', 'lay-down']
# labelled_time:  ['04:56', 'paddling', 'for a wave\n']
# labelled_time:  ['05:01', 'pop-up']
# labelled_time:  ['05:03', 'sit-back']
# labelled_time:  ['05:05', 'turning', "to surfer's left\n"]
# labelled_time:  ['05:14', 'walking', 'in water\n']
# labelled_time:  ['05:37', 'push-off']
# labelled_time:  ['05:39', 'paddling', 'into waves\n']
# labelled_time:  ['05:55', 'sit-up']
# labelled_time:  ['05:56', 'floating']
# labelled_time:  ['07:21', 'turning', "to surfer's left\n"]
# labelled_time:  ['07:27', 'lay-down']
# labelled_time:  ['07:28', 'paddling', 'for a wave\n']
# labelled_time:  ['07:32', 'pop-up']
# labelled_time:  ['07:33', 'surfing']
# labelled_time:  ['07:34', 'step-off']
# labelled_time:  ['07:35', 'off-board']
# labelled_time:  ['07:37', 'walking', 'in water\n']
# labelled_time:  ['07:49', 'push-off']
# labelled_time:  ['07:50', 'paddling', 'into waves\n']
# labelled_time:  ['08:20', 'sit-up']
# labelled_time:  ['08:21', 'floating']
# labelled_time:  ['08:32', 'turning', "to surfer's left\n"]
# labelled_time:  ['08:38', 'floating']
# labelled_time:  ['09:14', 'turning', "to surfer's right\n"]
# labelled_time:  ['09:18', 'lay-down']
# labelled_time:  ['09:19', 'paddling']
# labelled_time:  ['09:21', 'sit-back']
# labelled_time:  ['09:22', 'floating']
# labelled_time:  ['09:25', 'turning', "to surfer's right\n"]
# labelled_time:  ['09:28', 'lay-down']
# labelled_time:  ['09:29', 'paddling', 'for a wave\n']
# labelled_time:  ['09:33', 'wipe-out']
# labelled_time:  ['09:34', 'off-board']
# labelled_time:  ['09:38', 'walking', 'in water\n']
# labelled_time:  ['09:48', 'push-off']
# labelled_time:  ['09:51', 'sit-up']
# labelled_time:  ['09:52', 'floating']
# labelled_time:  ['09:54', 'lay-down']
# labelled_time:  ['09:55', 'paddling', 'into waves\n']
# labelled_time:  ['10:02', 'sit-up']
# labelled_time:  ['10:03', 'floating']
# labelled_time:  ['10:38', 'turning', "to surfer's right\n"]
# labelled_time:  ['10:40', 'lay-down']
# labelled_time:  ['10:41', 'paddling', 'for a wave\n']
# labelled_time:  ['10:48', 'pop-up']
# labelled_time:  ['10:49', 'surfing']
# labelled_time:  ['10:51', 'step-off']
# labelled_time:  ['10:52', 'off-board']
# labelled_time:  ['10:55', 'walking', 'in water\n']
# labelled_time:  ['11:03', 'push-off']
# labelled_time:  ['11:04', 'paddling', 'into waves\n']
# labelled_time:  ['11:26', 'sit-up']
# labelled_time:  ['11:27', 'floating']
# labelled_time:  ['11:52', 'turning', "to surfer's left\n"]
# labelled_time:  ['11:55', 'lay-down']
# labelled_time:  ['11:56', 'paddling', 'for a wave\n']
# labelled_time:  ['12:02', 'off-board']
# labelled_time:  ['12:07', 'push-off']
# labelled_time:  ['12:08', 'paddling', 'into waves\n']
# labelled_time:  ['12:17', 'sit-up']
# labelled_time:  ['12:18', 'floating']
# labelled_time:  ['12:37', 'turning', "to surfer's left\n"]
# labelled_time:  ['12:43', 'lay-down']
# labelled_time:  ['12:44', 'paddling', 'for a wave\n']
# labelled_time:  ['12:50', 'pop-up']
# labelled_time:  ['12:52', 'wipe-out']
# labelled_time:  ['12:53', 'off-board']
# labelled_time:  ['13:00', 'turning', "to surfer's left \n"]
# labelled_time:  ['13:03', 'push-off']
# labelled_time:  ['13:04', 'paddling', 'into waves\n']
# labelled_time:  ['13:25', 'sit-up']
# labelled_time:  ['13:26', 'floating']
# labelled_time:  ['13:28', 'lay-down']
# labelled_time:  ['13:29', 'paddling', 'into waves\n']
# labelled_time:  ['13:33', 'sit-up']
# labelled_time:  ['13:34', 'floating']
# labelled_time:  ['14:00', 'turning', "to surfer's left\n"]
# labelled_time:  ['14:05', 'floating']
# labelled_time:  ['14:11', 'turning', "to surfer's right\n"]
# labelled_time:  ['14:25', 'turning', "to surfer's left\n"]
# labelled_time:  ['14:29', 'floating']
# labelled_time:  ['15:14', 'turning', "to surfer's left\n"]
# labelled_time:  ['15:18', 'lay-down']
# labelled_time:  ['15:19', 'paddling', 'for a wave\n']
# labelled_time:  ['15:24', 'pop-up']
# labelled_time:  ['15:25', 'surfing']
# labelled_time:  ['15:33', 'step-off']
# labelled_time:  ['15:34', 'off-board']
# labelled_time:  ['15:35', 'pull-back', 'leash\n']
# labelled_time:  ['15:37', 'turning', "to surfer's right\n"]
# labelled_time:  ['15:42', 'walking', 'in water\n']
# labelled_time:  ['16:03', 'push-off']
# labelled_time:  ['16:04', 'paddling', 'into waves\n']
# labelled_time:  ['16:32', 'sit-up']
# labelled_time:  ['16:33', 'floating']
# labelled_time:  ['21:16', 'turning', "to surfer's left\n"]
# labelled_time:  ['21:22', 'lay-down']
# labelled_time:  ['21:23', 'paddling', 'for a wave\n']
# labelled_time:  ['21:26', 'pop-up']
# labelled_time:  ['21:28', 'sit-back']
# labelled_time:  ['21:29', 'off-board']
# labelled_time:  ['21:37', 'turning', "to surfer's right\n"]
# labelled_time:  ['21:48', 'push-off']
# labelled_time:  ['21:49', 'paddling', 'into waves\n']
# labelled_time:  ['22:09', 'sit-up']
# labelled_time:  ['22:10', 'floating']
# labelled_time:  ['22:39', 'turning', "to surfer's left\n"]
# labelled_time:  ['22:42', 'lay-down']
# labelled_time:  ['22:43', 'paddling', 'for a wave\n']
# labelled_time:  ['22:46', 'sit-back']
# labelled_time:  ['22:47', 'floating']
# labelled_time:  ['24:25', 'lay-down']
# labelled_time:  ['24:26', 'paddling', 'for position\n']
# labelled_time:  ['24:38', 'sit-up']
# labelled_time:  ['24:39', 'floating']
# labelled_time:  ['24:52', 'turning', "to surfer's right \n"]
# labelled_time:  ['25:01', 'new']
# labelled_time:  ['00:03', 'lay-down']
# labelled_time:  ['00:04', 'paddling', 'for a wave\n']
# labelled_time:  ['00:08', 'sit-back']
# labelled_time:  ['00:09', 'turning', "to surfer's left \n"]
# labelled_time:  ['00:11', 'turning', "to surfer's right\n"]
# labelled_time:  ['00:13', 'lay-down']
# labelled_time:  ['00:14', 'paddling', 'for a wave\n']
# labelled_time:  ['00:19', 'pop-up']
# labelled_time:  ['00:20', 'surfing']
# labelled_time:  ['00:21', 'step-off']
# labelled_time:  ['00:22', 'off-board']
# labelled_time:  ['00:24', 'pull-back', 'leash\n']
# labelled_time:  ['00:29', 'walking', 'in water\n']
# labelled_time:  ['00:33', 'turning', "to surfer's left\n"]
# labelled_time:  ['00:40', 'walking', 'in water\n']
# labelled_time:  ['00:45', 'push-off']
# labelled_time:  ['00:46', 'paddling', 'into waves\n']
# labelled_time:  ['01:04', 'sit-up']
# labelled_time:  ['01:05', 'floating']
# labelled_time:  ['01:37', 'discard']
# labelled_time:  ['02:34', 'lay-down']
# labelled_time:  ['02:35', 'paddling', 'for position\n']
# labelled_time:  ['02:39', 'sit-up']
# labelled_time:  ['02:40', 'turning', "to surfer's right\n"]
# labelled_time:  ['02:44', 'lay-down']
# labelled_time:  ['02:45', 'paddling', 'for a wave\n']
# labelled_time:  ['02:51', 'pop-up']
# labelled_time:  ['02:52', 'surfing']
# labelled_time:  ['02:55', 'step-off']
# labelled_time:  ['02:56', 'off-board']
# labelled_time:  ['02:59', 'pull-back', 'leash\n']
# labelled_time:  ['03:03', 'turning', "to surfer's left\n"]
# labelled_time:  ['03:04', 'walking', 'in water\n']
# labelled_time:  ['03:12', 'push-off']
# labelled_time:  ['03:13', 'paddling', 'into waves\n']
# labelled_time:  ['03:45', 'sit-up']
# labelled_time:  ['03:46', 'floating']
# labelled_time:  ['04:17', 'turning', "to surfer's right\n"]
# labelled_time:  ['04:21', 'lay-down']
# labelled_time:  ['04:22', 'paddling', 'for a wave\n']
# labelled_time:  ['04:29', 'pop-up']
# labelled_time:  ['04:30', 'wipe-out']
# labelled_time:  ['04:31', 'off-board']
# labelled_time:  ['04:35', 'walking', 'in water\n']
# labelled_time:  ['04:36', 'turning', "to surfer's left\n"]
# labelled_time:  ['04:38', 'walking', 'in water\n']
# labelled_time:  ['04:41', 'push-off']
# labelled_time:  ['04:42', 'paddling', 'into waves\n']
# labelled_time:  ['05:02', 'sit-up']
# labelled_time:  ['05:03', 'floating']
# labelled_time:  ['08:05', 'turning', "to surfer's right\n"]
# labelled_time:  ['08:06', 'lay-down']
# labelled_time:  ['08:07', 'paddling', 'for a wave\n']
# labelled_time:  ['08:09', 'sit-back']
# labelled_time:  ['08:11', 'off-board']
# labelled_time:  ['08:21', 'walking', 'in water\n']
# labelled_time:  ['08:23', 'turning', "to surfer's left\n"]
# labelled_time:  ['08:31', 'push-off']
# labelled_time:  ['08:32', 'floating']
# labelled_time:  ['08:36', 'paddling', 'into waves\n']
# labelled_time:  ['08:48', 'sit-up']
# labelled_time:  ['08:49', 'floating']
# labelled_time:  ['09:44', 'lay-down']
# labelled_time:  ['09:46', 'paddling', 'into waves\n']
# labelled_time:  ['09:51', 'sit-up']
# labelled_time:  ['09:52', 'floating']
# labelled_time:  ['12:49', 'turning', "to surfer's right\n"]
# labelled_time:  ['12:51', 'lay-down']
# labelled_time:  ['12:52', 'paddling', 'for a wave\n']
# labelled_time:  ['12:59', 'sit-back']
# labelled_time:  ['13:00', 'floating']
# labelled_time:  ['13:31', 'lay-down']
# labelled_time:  ['13:32', 'paddling', 'for a wave\n']
# labelled_time:  ['13:38', 'pop-up']
# labelled_time:  ['13:39', 'surfing']
# labelled_time:  ['13:43', 'step-off']
# labelled_time:  ['13:44', 'off-board']
# labelled_time:  ['13:46', 'pull-back', 'leash\n']
# labelled_time:  ['13:49', 'walking', 'in water\n']
# labelled_time:  ['13:50', 'turning', "to surfer's left\n"]
# labelled_time:  ['13:54', 'push-off']
# labelled_time:  ['13:56', 'paddling', 'into waves\n']
# labelled_time:  ['14:20', 'sit-up']
# labelled_time:  ['14:21', 'floating']
# labelled_time:  ['15:00', 'lay-down']
# labelled_time:  ['15:01', 'paddling', 'for position\n']
# labelled_time:  ['15:11', 'sit-up']
# labelled_time:  ['15:12', 'floating']
# labelled_time:  ['16:23', 'turning', "to surfer's right\n"]
# labelled_time:  ['16:25', 'lay-down']
# labelled_time:  ['16:26', 'paddling', 'for a wave\n']
# labelled_time:  ['16:32', 'sit-back']
# labelled_time:  ['16:33', 'floating']
# labelled_time:  ['17:06', 'turning', "to surfer's right\n"]
# labelled_time:  ['17:08', 'lay-down']
# labelled_time:  ['17:09', 'paddling', 'for a wave\n']
# labelled_time:  ['17:17', 'sit-back']
# labelled_time:  ['17:18', 'floating']
# labelled_time:  ['17:19', 'turning', "to surfer's left\n"]
# labelled_time:  ['17:23', 'lay-down']
# labelled_time:  ['17:24', 'paddling', 'into waves\n']
# labelled_time:  ['17:51', 'sit-up']
# labelled_time:  ['17:52', 'floating']
# labelled_time:  ['17:53', 'turning', "to surfer's right\n"]
# labelled_time:  ['17:54', 'lay-down']
# labelled_time:  ['17:55', 'paddling', 'for a wave\n']
# labelled_time:  ['17:59', 'sit-back']
# labelled_time:  ['18:00', 'floating']
# labelled_time:  ['18:16', 'lay-down']
# labelled_time:  ['18:17', 'paddling', 'for a wave\n']
# labelled_time:  ['18:21', 'pop-up']
# labelled_time:  ['18:22', 'surfing']
# labelled_time:  ['18:27', 'step-off']
# labelled_time:  ['18:28', 'off-board']
# labelled_time:  ['18:31', 'pull-back', 'leash\n']
# labelled_time:  ['18:34', 'walking', 'in water\n']
# labelled_time:  ['18:35', 'turning', "to surfer's left\n"]
# labelled_time:  ['18:38', 'walking', 'in water\n']
# labelled_time:  ['18:59', 'push-off']
# labelled_time:  ['19:01', 'paddling', 'into waves\n']
# labelled_time:  ['19:28', 'sit-up']
# labelled_time:  ['19:29', 'floating']
# labelled_time:  ['20:10', 'turning', "to surfer's right\n"]
# labelled_time:  ['20:15', 'lay-down']
# labelled_time:  ['20:16', 'paddling', 'for a wave\n']
# labelled_time:  ['20:21', 'pop-up']
# labelled_time:  ['20:22', 'surfing']
# labelled_time:  ['20:24', 'wipe-out']
# labelled_time:  ['20:25', 'off-board']
# labelled_time:  ['20:26', 'pull-back', 'leash\n']
# labelled_time:  ['20:30', 'turning', "to surfer's right\n"]
# labelled_time:  ['20:36', 'walking', 'in water\n']
# labelled_time:  ['20:39', 'push-off']
# labelled_time:  ['20:40', 'paddling', 'into waves\n']
# labelled_time:  ['20:47', 'sit-up']
# labelled_time:  ['20:48', 'floating']
# labelled_time:  ['20:49', 'turning', "to surfer's right\n"]
# labelled_time:  ['20:50', 'lay-down']
# labelled_time:  ['20:51', 'paddling', 'for a wave\n']
# labelled_time:  ['20:53', 'sit-back']
# labelled_time:  ['20:54', 'floating']
# labelled_time:  ['20:55', 'turning', "to surfer's left\n"]
# labelled_time:  ['20:59', 'lay-down']
# labelled_time:  ['21:00', 'paddling', 'into waves\n']
# labelled_time:  ['21:18', 'sit-up']
# labelled_time:  ['21:19', 'floating']
# labelled_time:  ['21:40', 'turning', "to surfer's right\n"]
# labelled_time:  ['21:43', 'lay-down']
# labelled_time:  ['21:44', 'paddling', 'for a wave\n']
# labelled_time:  ['21:51', 'sit-back']
# labelled_time:  ['21:52', 'turning', "to surfer's left\n"]
# labelled_time:  ['21:57', 'floating']
# labelled_time:  ['22:28', 'turning', "to surfer's right\n"]
# labelled_time:  ['22:31', 'lay-down']
# labelled_time:  ['22:32', 'paddling', 'for a wave\n']
# labelled_time:  ['22:37', 'pop-up']
# labelled_time:  ['22:38', 'surfing']
# labelled_time:  ['22:44', 'step-off']
# labelled_time:  ['22:45', 'off-board']
# labelled_time:  ['22:47', 'pull-back', 'leash\n']
# labelled_time:  ['22:50', 'turning', "to surfer's right\n"]
# labelled_time:  ['22:54', 'walking', 'in water\n']
# labelled_time:  ['23:16', 'push-off']
# labelled_time:  ['23:17', 'paddling', 'into waves\n']
# labelled_time:  ['23:35', 'sit-up']
# labelled_time:  ['23:36', 'floating']
# labelled_time:  ['23:48', 'turning', "to surfer's right\n"]
# labelled_time:  ['23:50', 'lay-down']
# labelled_time:  ['23:51', 'paddling', 'for a wave\n']
# labelled_time:  ['23:56', 'pop-up']
# labelled_time:  ['23:57', 'surfing']
# labelled_time:  ['24:00', 'step-off']
# labelled_time:  ['24:01', 'off-board']
# labelled_time:  ['24:03', 'pull-back', 'leash\n']
# labelled_time:  ['24:09', 'walking', 'in water\n']
# labelled_time:  ['24:10', 'turning', "to surfer's left\n"]
# labelled_time:  ['24:16', 'push-off']
# labelled_time:  ['24:17', 'paddling', 'into waves\n']
# labelled_time:  ['24:50', 'sit-up']
# labelled_time:  ['24:51', 'floating']
# labelled_time:  ['25:01', 'end', 'of video\n']
# labelled_time:  ['00:09', 'turning', "to surfer's right\n"]
# labelled_time:  ['00:11', 'lay-down']
# labelled_time:  ['00:12', 'paddling', 'for a wave\n']
# labelled_time:  ['00:16', 'sit-back']
# labelled_time:  ['00:17', 'turning', "to surfer's left\n"]
# labelled_time:  ['00:22', 'floating']
# labelled_time:  ['00:30', 'turning', "to surfer's right\n"]
# labelled_time:  ['00:32', 'lay-down']
# labelled_time:  ['00:33', 'paddling', 'for a wave\n']
# labelled_time:  ['00:40', 'sit-back']
# labelled_time:  ['00:41', 'floating']
# labelled_time:  ['00:42', 'turning', "to surfer's left\n"]
# labelled_time:  ['00:49', 'lay-down']
# labelled_time:  ['00:50', 'floating']
# labelled_time:  ['00:58', 'paddling', 'into waves\n']
# labelled_time:  ['01:19', 'sit-up']
# labelled_time:  ['01:20', 'floating']
# labelled_time:  ['01:49', 'turning', "to surfer's right\n"]
# labelled_time:  ['01:52', 'lay-down']
# labelled_time:  ['01:53', 'paddling', 'for a wave\n']
# labelled_time:  ['01:56', 'pop-up']
# labelled_time:  ['01:57', 'surfing']
# labelled_time:  ['02:01', 'step-off']
# labelled_time:  ['02:02', 'off-board']
# labelled_time:  ['02:05', 'pull-back', 'leash\n']
# labelled_time:  ['02:08', 'walking', 'in water\n']
# labelled_time:  ['02:10', 'push-off']
# labelled_time:  ['02:11', 'paddling', 'for a wave\n']
# labelled_time:  ['02:13', 'pop-up']
# labelled_time:  ['02:14', 'surfing']
# labelled_time:  ['02:18', 'step-off']
# labelled_time:  ['02:20', 'pull-back', 'leash\n']
# labelled_time:  ['02:26', 'walking', 'in water\n']
# labelled_time:  ['02:27', 'turning', "to surfer's right\n"]
# labelled_time:  ['02:32', 'walking', 'in water\n']
# labelled_time:  ['02:42', 'push-off']
# labelled_time:  ['02:43', 'paddling', 'into waves\n']
# labelled_time:  ['03:07', 'sit-up']
# labelled_time:  ['03:08', 'floating']
# labelled_time:  ['03:22', 'lay-down']
# labelled_time:  ['03:23', 'paddling', 'into waves\n']
# labelled_time:  ['03:24', 'sit-up']
# labelled_time:  ['03:25', 'turning', "to surfer's left\n"]
# labelled_time:  ['03:28', 'lay-down']
# labelled_time:  ['03:29', 'paddling', 'for a wave\n']
# labelled_time:  ['03:32', 'pop-up']
# labelled_time:  ['03:35', 'wipe-out']
# labelled_time:  ['03:36', 'off-board']
# labelled_time:  ['03:38', 'pull-back', 'leash\n']
# labelled_time:  ['03:46', 'walking', 'in water\n']
# labelled_time:  ['03:47', 'turning', "to surfer's left\n"]
# labelled_time:  ['03:49', 'push-off']
# labelled_time:  ['03:50', 'paddling', 'into waves\n']
# labelled_time:  ['04:30', 'sit-up']
# labelled_time:  ['04:31', 'floating']
# labelled_time:  ['05:12', 'turning', "to surfer's right\n"]
# labelled_time:  ['05:17', 'lay-down']
# labelled_time:  ['05:18', 'paddling', 'for a wave\n']
# labelled_time:  ['05:23', 'pop-up']
# labelled_time:  ['05:24', 'surfing']
# labelled_time:  ['05:26', 'off-board']
# labelled_time:  ['05:34', 'walking', 'in water\n']
# labelled_time:  ['05:35', 'turning', "to surfer's left\n"]
# labelled_time:  ['05:42', 'push-off']
# labelled_time:  ['05:43', 'paddling', 'into waves\n']
# labelled_time:  ['06:00', 'sit-up']
# labelled_time:  ['06:01', 'floating']
# labelled_time:  ['06:14', 'turning', "to surfer's right\n"]
# labelled_time:  ['06:16', 'lay-down']
# labelled_time:  ['06:17', 'paddling', 'for a wave\n']
# labelled_time:  ['06:24', 'pop-up']
# labelled_time:  ['06:25', 'surfing']
# labelled_time:  ['06:30', 'step-off']
# labelled_time:  ['06:31', 'off-board']
# labelled_time:  ['06:32', 'pull-back', 'leash\n']
# labelled_time:  ['06:36', 'walking', 'in water\n']
# labelled_time:  ['06:37', 'turning', "to surfer's right\n"]
# labelled_time:  ['06:44', 'push-off']
# labelled_time:  ['06:45', 'paddling', 'into waves\n']
# labelled_time:  ['07:21', 'sit-up']
# labelled_time:  ['07:22', 'floating']
# labelled_time:  ['07:44', 'turning', "to surfer's left\n"]
# labelled_time:  ['07:47', 'floating']
# labelled_time:  ['07:52', 'turning', "to surfer's right\n"]
# labelled_time:  ['07:57', 'lay-down']
# labelled_time:  ['08:03', 'paddling', 'into waves\n']
# labelled_time:  ['08:10', 'sit-up']
# labelled_time:  ['08:11', 'floating']
# labelled_time:  ['08:14', 'turning', "to surfer's right\n"]
# labelled_time:  ['08:18', 'floating']
# labelled_time:  ['08:23', 'turning', "to surfer's right\n"]
# labelled_time:  ['08:24', 'lay-down']
# labelled_time:  ['08:25', 'paddling', 'for a wave\n']
# labelled_time:  ['08:30', 'pop-up']
# labelled_time:  ['08:31', 'surfing']
# labelled_time:  ['08:34', 'step-off']
# labelled_time:  ['08:35', 'off-board']
# labelled_time:  ['08:42', 'pull-back', 'leash\n']
# labelled_time:  ['08:44', 'walking', 'in water\n']
# labelled_time:  ['08:47', 'turning', "to surfer's left\n"]
# labelled_time:  ['08:52', 'push-off']
# labelled_time:  ['08:53', 'paddling', 'into waves\n']
# labelled_time:  ['09:09', 'sit-up']
# labelled_time:  ['09:10', 'floating']
# labelled_time:  ['09:24', 'turning', "to surfer's left\n"]
# labelled_time:  ['09:28', 'lay-down']
# labelled_time:  ['09:29', 'paddling', 'for a wave\n']
# labelled_time:  ['09:34', 'pop-up']
# labelled_time:  ['09:35', 'surfing']
# labelled_time:  ['09:39', 'step-off']
# labelled_time:  ['09:40', 'off-board']
# labelled_time:  ['09:42', 'pull-back', 'leash\n']
# labelled_time:  ['09:48', 'walking', 'in water\n']
# labelled_time:  ['10:17', 'done,', 'out of water\n']
# labelled_time:  ['10:18', 'walking', 'out of water\n']
# labelled_time:  ['10:38', 'end', 'of video\n']
# labelled_time:  []
# labelled_time:  []
# labelled_time:  []
# labelled_time:  []
# labelled_time:  []
# labelled_time:  []
# labelled_time:  []
# labelled_time:  []
# labelled_time:  []
# labelled_time:  []
# labelled_time:  []
# curr_time:  time.struct_time(tm_year=1900, tm_mon=1, tm_mday=1, tm_hour=0, tm_min=0, tm_sec=36, tm_wday=0, tm_yday=1, tm_isdst=-1)
# curr_time:  time.struct_time(tm_year=1900, tm_mon=1, tm_mday=1, tm_hour=0, tm_min=1, tm_sec=7, tm_wday=0, tm_yday=1, tm_isdst=-1)
# curr_time:  time.struct_time(tm_year=1900, tm_mon=1, tm_mday=1, tm_hour=0, tm_min=1, tm_sec=8, tm_wday=0, tm_yday=1, tm_isdst=-1)
# curr_time:  time.struct_time(tm_year=1900, tm_mon=1, tm_mday=1, tm_hour=0, tm_min=1, tm_sec=12, tm_wday=0, tm_yday=1, tm_isdst=-1)
# curr_time:  time.struct_time(tm_year=1900, tm_mon=1, tm_mday=1, tm_hour=0, tm_min=1, tm_sec=13, tm_wday=0, tm_yday=1, tm_isdst=-1)
# curr_time:  time.struct_time(tm_year=1900, tm_mon=1, tm_mday=1, tm_hour=0, tm_min=1, tm_sec=34, tm_wday=0, tm_yday=1, tm_isdst=-1)
# curr_time:  time.struct_time(tm_year=1900, tm_mon=1, tm_mday=1, tm_hour=0, tm_min=1, tm_sec=57, tm_wday=0, tm_yday=1, tm_isdst=-1)
# curr_time:  time.struct_time(tm_year=1900, tm_mon=1, tm_mday=1, tm_hour=0, tm_min=1, tm_sec=58, tm_wday=0, tm_yday=1, tm_isdst=-1)
# curr_time:  time.struct_time(tm_year=1900, tm_mon=1, tm_mday=1, tm_hour=0, tm_min=2, tm_sec=37, tm_wday=0, tm_yday=1, tm_isdst=-1)
# curr_time:  time.struct_time(tm_year=1900, tm_mon=1, tm_mday=1, tm_hour=0, tm_min=2, tm_sec=38, tm_wday=0, tm_yday=1, tm_isdst=-1)
# curr_time:  time.struct_time(tm_year=1900, tm_mon=1, tm_mday=1, tm_hour=0, tm_min=2, tm_sec=54, tm_wday=0, tm_yday=1, tm_isdst=-1)
# curr_time:  time.struct_time(tm_year=1900, tm_mon=1, tm_mday=1, tm_hour=0, tm_min=3, tm_sec=0, tm_wday=0, tm_yday=1, tm_isdst=-1)
# curr_time:  time.struct_time(tm_year=1900, tm_mon=1, tm_mday=1, tm_hour=0, tm_min=3, tm_sec=38, tm_wday=0, tm_yday=1, tm_isdst=-1)
# curr_time:  time.struct_time(tm_year=1900, tm_mon=1, tm_mday=1, tm_hour=0, tm_min=3, tm_sec=39, tm_wday=0, tm_yday=1, tm_isdst=-1)
# curr_time:  time.struct_time(tm_year=1900, tm_mon=1, tm_mday=1, tm_hour=0, tm_min=3, tm_sec=47, tm_wday=0, tm_yday=1, tm_isdst=-1)
# curr_time:  time.struct_time(tm_year=1900, tm_mon=1, tm_mday=1, tm_hour=0, tm_min=3, tm_sec=48, tm_wday=0, tm_yday=1, tm_isdst=-1)
# curr_time:  time.struct_time(tm_year=1900, tm_mon=1, tm_mday=1, tm_hour=0, tm_min=3, tm_sec=56, tm_wday=0, tm_yday=1, tm_isdst=-1)
# curr_time:  time.struct_time(tm_year=1900, tm_mon=1, tm_mday=1, tm_hour=0, tm_min=3, tm_sec=58, tm_wday=0, tm_yday=1, tm_isdst=-1)
# curr_time:  time.struct_time(tm_year=1900, tm_mon=1, tm_mday=1, tm_hour=0, tm_min=4, tm_sec=7, tm_wday=0, tm_yday=1, tm_isdst=-1)
# curr_time:  time.struct_time(tm_year=1900, tm_mon=1, tm_mday=1, tm_hour=0, tm_min=4, tm_sec=8, tm_wday=0, tm_yday=1, tm_isdst=-1)
# curr_time:  time.struct_time(tm_year=1900, tm_mon=1, tm_mday=1, tm_hour=0, tm_min=4, tm_sec=47, tm_wday=0, tm_yday=1, tm_isdst=-1)
# curr_time:  time.struct_time(tm_year=1900, tm_mon=1, tm_mday=1, tm_hour=0, tm_min=4, tm_sec=48, tm_wday=0, tm_yday=1, tm_isdst=-1)
# curr_time:  time.struct_time(tm_year=1900, tm_mon=1, tm_mday=1, tm_hour=0, tm_min=4, tm_sec=53, tm_wday=0, tm_yday=1, tm_isdst=-1)
# curr_time:  time.struct_time(tm_year=1900, tm_mon=1, tm_mday=1, tm_hour=0, tm_min=4, tm_sec=55, tm_wday=0, tm_yday=1, tm_isdst=-1)
# curr_time:  time.struct_time(tm_year=1900, tm_mon=1, tm_mday=1, tm_hour=0, tm_min=4, tm_sec=56, tm_wday=0, tm_yday=1, tm_isdst=-1)
# curr_time:  time.struct_time(tm_year=1900, tm_mon=1, tm_mday=1, tm_hour=0, tm_min=5, tm_sec=1, tm_wday=0, tm_yday=1, tm_isdst=-1)
# curr_time:  time.struct_time(tm_year=1900, tm_mon=1, tm_mday=1, tm_hour=0, tm_min=5, tm_sec=3, tm_wday=0, tm_yday=1, tm_isdst=-1)
# curr_time:  time.struct_time(tm_year=1900, tm_mon=1, tm_mday=1, tm_hour=0, tm_min=5, tm_sec=5, tm_wday=0, tm_yday=1, tm_isdst=-1)
# curr_time:  time.struct_time(tm_year=1900, tm_mon=1, tm_mday=1, tm_hour=0, tm_min=5, tm_sec=14, tm_wday=0, tm_yday=1, tm_isdst=-1)
# curr_time:  time.struct_time(tm_year=1900, tm_mon=1, tm_mday=1, tm_hour=0, tm_min=5, tm_sec=37, tm_wday=0, tm_yday=1, tm_isdst=-1)
# curr_time:  time.struct_time(tm_year=1900, tm_mon=1, tm_mday=1, tm_hour=0, tm_min=5, tm_sec=39, tm_wday=0, tm_yday=1, tm_isdst=-1)
# curr_time:  time.struct_time(tm_year=1900, tm_mon=1, tm_mday=1, tm_hour=0, tm_min=5, tm_sec=55, tm_wday=0, tm_yday=1, tm_isdst=-1)
# curr_time:  time.struct_time(tm_year=1900, tm_mon=1, tm_mday=1, tm_hour=0, tm_min=5, tm_sec=56, tm_wday=0, tm_yday=1, tm_isdst=-1)
# curr_time:  time.struct_time(tm_year=1900, tm_mon=1, tm_mday=1, tm_hour=0, tm_min=7, tm_sec=21, tm_wday=0, tm_yday=1, tm_isdst=-1)
# curr_time:  time.struct_time(tm_year=1900, tm_mon=1, tm_mday=1, tm_hour=0, tm_min=7, tm_sec=27, tm_wday=0, tm_yday=1, tm_isdst=-1)
# curr_time:  time.struct_time(tm_year=1900, tm_mon=1, tm_mday=1, tm_hour=0, tm_min=7, tm_sec=28, tm_wday=0, tm_yday=1, tm_isdst=-1)
# curr_time:  time.struct_time(tm_year=1900, tm_mon=1, tm_mday=1, tm_hour=0, tm_min=7, tm_sec=32, tm_wday=0, tm_yday=1, tm_isdst=-1)
# curr_time:  time.struct_time(tm_year=1900, tm_mon=1, tm_mday=1, tm_hour=0, tm_min=7, tm_sec=33, tm_wday=0, tm_yday=1, tm_isdst=-1)
# curr_time:  time.struct_time(tm_year=1900, tm_mon=1, tm_mday=1, tm_hour=0, tm_min=7, tm_sec=34, tm_wday=0, tm_yday=1, tm_isdst=-1)
# curr_time:  time.struct_time(tm_year=1900, tm_mon=1, tm_mday=1, tm_hour=0, tm_min=7, tm_sec=35, tm_wday=0, tm_yday=1, tm_isdst=-1)
# curr_time:  time.struct_time(tm_year=1900, tm_mon=1, tm_mday=1, tm_hour=0, tm_min=7, tm_sec=37, tm_wday=0, tm_yday=1, tm_isdst=-1)
# curr_time:  time.struct_time(tm_year=1900, tm_mon=1, tm_mday=1, tm_hour=0, tm_min=7, tm_sec=49, tm_wday=0, tm_yday=1, tm_isdst=-1)
# curr_time:  time.struct_time(tm_year=1900, tm_mon=1, tm_mday=1, tm_hour=0, tm_min=7, tm_sec=50, tm_wday=0, tm_yday=1, tm_isdst=-1)
# curr_time:  time.struct_time(tm_year=1900, tm_mon=1, tm_mday=1, tm_hour=0, tm_min=8, tm_sec=20, tm_wday=0, tm_yday=1, tm_isdst=-1)
# curr_time:  time.struct_time(tm_year=1900, tm_mon=1, tm_mday=1, tm_hour=0, tm_min=8, tm_sec=21, tm_wday=0, tm_yday=1, tm_isdst=-1)
# curr_time:  time.struct_time(tm_year=1900, tm_mon=1, tm_mday=1, tm_hour=0, tm_min=8, tm_sec=32, tm_wday=0, tm_yday=1, tm_isdst=-1)
# curr_time:  time.struct_time(tm_year=1900, tm_mon=1, tm_mday=1, tm_hour=0, tm_min=8, tm_sec=38, tm_wday=0, tm_yday=1, tm_isdst=-1)
# curr_time:  time.struct_time(tm_year=1900, tm_mon=1, tm_mday=1, tm_hour=0, tm_min=9, tm_sec=14, tm_wday=0, tm_yday=1, tm_isdst=-1)
# curr_time:  time.struct_time(tm_year=1900, tm_mon=1, tm_mday=1, tm_hour=0, tm_min=9, tm_sec=18, tm_wday=0, tm_yday=1, tm_isdst=-1)
# curr_time:  time.struct_time(tm_year=1900, tm_mon=1, tm_mday=1, tm_hour=0, tm_min=9, tm_sec=19, tm_wday=0, tm_yday=1, tm_isdst=-1)
# curr_time:  time.struct_time(tm_year=1900, tm_mon=1, tm_mday=1, tm_hour=0, tm_min=9, tm_sec=21, tm_wday=0, tm_yday=1, tm_isdst=-1)
# curr_time:  time.struct_time(tm_year=1900, tm_mon=1, tm_mday=1, tm_hour=0, tm_min=9, tm_sec=22, tm_wday=0, tm_yday=1, tm_isdst=-1)
# curr_time:  time.struct_time(tm_year=1900, tm_mon=1, tm_mday=1, tm_hour=0, tm_min=9, tm_sec=25, tm_wday=0, tm_yday=1, tm_isdst=-1)
# curr_time:  time.struct_time(tm_year=1900, tm_mon=1, tm_mday=1, tm_hour=0, tm_min=9, tm_sec=28, tm_wday=0, tm_yday=1, tm_isdst=-1)
# curr_time:  time.struct_time(tm_year=1900, tm_mon=1, tm_mday=1, tm_hour=0, tm_min=9, tm_sec=29, tm_wday=0, tm_yday=1, tm_isdst=-1)
# curr_time:  time.struct_time(tm_year=1900, tm_mon=1, tm_mday=1, tm_hour=0, tm_min=9, tm_sec=33, tm_wday=0, tm_yday=1, tm_isdst=-1)
# curr_time:  time.struct_time(tm_year=1900, tm_mon=1, tm_mday=1, tm_hour=0, tm_min=9, tm_sec=34, tm_wday=0, tm_yday=1, tm_isdst=-1)
# curr_time:  time.struct_time(tm_year=1900, tm_mon=1, tm_mday=1, tm_hour=0, tm_min=9, tm_sec=38, tm_wday=0, tm_yday=1, tm_isdst=-1)
# curr_time:  time.struct_time(tm_year=1900, tm_mon=1, tm_mday=1, tm_hour=0, tm_min=9, tm_sec=48, tm_wday=0, tm_yday=1, tm_isdst=-1)
# curr_time:  time.struct_time(tm_year=1900, tm_mon=1, tm_mday=1, tm_hour=0, tm_min=9, tm_sec=51, tm_wday=0, tm_yday=1, tm_isdst=-1)
# curr_time:  time.struct_time(tm_year=1900, tm_mon=1, tm_mday=1, tm_hour=0, tm_min=9, tm_sec=52, tm_wday=0, tm_yday=1, tm_isdst=-1)
# curr_time:  time.struct_time(tm_year=1900, tm_mon=1, tm_mday=1, tm_hour=0, tm_min=9, tm_sec=54, tm_wday=0, tm_yday=1, tm_isdst=-1)
# curr_time:  time.struct_time(tm_year=1900, tm_mon=1, tm_mday=1, tm_hour=0, tm_min=9, tm_sec=55, tm_wday=0, tm_yday=1, tm_isdst=-1)
# curr_time:  time.struct_time(tm_year=1900, tm_mon=1, tm_mday=1, tm_hour=0, tm_min=10, tm_sec=2, tm_wday=0, tm_yday=1, tm_isdst=-1)
# curr_time:  time.struct_time(tm_year=1900, tm_mon=1, tm_mday=1, tm_hour=0, tm_min=10, tm_sec=3, tm_wday=0, tm_yday=1, tm_isdst=-1)
# curr_time:  time.struct_time(tm_year=1900, tm_mon=1, tm_mday=1, tm_hour=0, tm_min=10, tm_sec=38, tm_wday=0, tm_yday=1, tm_isdst=-1)
# curr_time:  time.struct_time(tm_year=1900, tm_mon=1, tm_mday=1, tm_hour=0, tm_min=10, tm_sec=40, tm_wday=0, tm_yday=1, tm_isdst=-1)
# curr_time:  time.struct_time(tm_year=1900, tm_mon=1, tm_mday=1, tm_hour=0, tm_min=10, tm_sec=41, tm_wday=0, tm_yday=1, tm_isdst=-1)
# curr_time:  time.struct_time(tm_year=1900, tm_mon=1, tm_mday=1, tm_hour=0, tm_min=10, tm_sec=48, tm_wday=0, tm_yday=1, tm_isdst=-1)
# curr_time:  time.struct_time(tm_year=1900, tm_mon=1, tm_mday=1, tm_hour=0, tm_min=10, tm_sec=49, tm_wday=0, tm_yday=1, tm_isdst=-1)
# curr_time:  time.struct_time(tm_year=1900, tm_mon=1, tm_mday=1, tm_hour=0, tm_min=10, tm_sec=51, tm_wday=0, tm_yday=1, tm_isdst=-1)
# curr_time:  time.struct_time(tm_year=1900, tm_mon=1, tm_mday=1, tm_hour=0, tm_min=10, tm_sec=52, tm_wday=0, tm_yday=1, tm_isdst=-1)
# curr_time:  time.struct_time(tm_year=1900, tm_mon=1, tm_mday=1, tm_hour=0, tm_min=10, tm_sec=55, tm_wday=0, tm_yday=1, tm_isdst=-1)
# curr_time:  time.struct_time(tm_year=1900, tm_mon=1, tm_mday=1, tm_hour=0, tm_min=11, tm_sec=3, tm_wday=0, tm_yday=1, tm_isdst=-1)
# curr_time:  time.struct_time(tm_year=1900, tm_mon=1, tm_mday=1, tm_hour=0, tm_min=11, tm_sec=4, tm_wday=0, tm_yday=1, tm_isdst=-1)
# curr_time:  time.struct_time(tm_year=1900, tm_mon=1, tm_mday=1, tm_hour=0, tm_min=11, tm_sec=26, tm_wday=0, tm_yday=1, tm_isdst=-1)
# curr_time:  time.struct_time(tm_year=1900, tm_mon=1, tm_mday=1, tm_hour=0, tm_min=11, tm_sec=27, tm_wday=0, tm_yday=1, tm_isdst=-1)
# curr_time:  time.struct_time(tm_year=1900, tm_mon=1, tm_mday=1, tm_hour=0, tm_min=11, tm_sec=52, tm_wday=0, tm_yday=1, tm_isdst=-1)
# curr_time:  time.struct_time(tm_year=1900, tm_mon=1, tm_mday=1, tm_hour=0, tm_min=11, tm_sec=55, tm_wday=0, tm_yday=1, tm_isdst=-1)
# curr_time:  time.struct_time(tm_year=1900, tm_mon=1, tm_mday=1, tm_hour=0, tm_min=11, tm_sec=56, tm_wday=0, tm_yday=1, tm_isdst=-1)
# curr_time:  time.struct_time(tm_year=1900, tm_mon=1, tm_mday=1, tm_hour=0, tm_min=12, tm_sec=2, tm_wday=0, tm_yday=1, tm_isdst=-1)
# curr_time:  time.struct_time(tm_year=1900, tm_mon=1, tm_mday=1, tm_hour=0, tm_min=12, tm_sec=7, tm_wday=0, tm_yday=1, tm_isdst=-1)
# curr_time:  time.struct_time(tm_year=1900, tm_mon=1, tm_mday=1, tm_hour=0, tm_min=12, tm_sec=8, tm_wday=0, tm_yday=1, tm_isdst=-1)
# curr_time:  time.struct_time(tm_year=1900, tm_mon=1, tm_mday=1, tm_hour=0, tm_min=12, tm_sec=17, tm_wday=0, tm_yday=1, tm_isdst=-1)
# curr_time:  time.struct_time(tm_year=1900, tm_mon=1, tm_mday=1, tm_hour=0, tm_min=12, tm_sec=18, tm_wday=0, tm_yday=1, tm_isdst=-1)
# curr_time:  time.struct_time(tm_year=1900, tm_mon=1, tm_mday=1, tm_hour=0, tm_min=12, tm_sec=37, tm_wday=0, tm_yday=1, tm_isdst=-1)
# curr_time:  time.struct_time(tm_year=1900, tm_mon=1, tm_mday=1, tm_hour=0, tm_min=12, tm_sec=43, tm_wday=0, tm_yday=1, tm_isdst=-1)
# curr_time:  time.struct_time(tm_year=1900, tm_mon=1, tm_mday=1, tm_hour=0, tm_min=12, tm_sec=44, tm_wday=0, tm_yday=1, tm_isdst=-1)
# curr_time:  time.struct_time(tm_year=1900, tm_mon=1, tm_mday=1, tm_hour=0, tm_min=12, tm_sec=50, tm_wday=0, tm_yday=1, tm_isdst=-1)
# curr_time:  time.struct_time(tm_year=1900, tm_mon=1, tm_mday=1, tm_hour=0, tm_min=12, tm_sec=52, tm_wday=0, tm_yday=1, tm_isdst=-1)
# curr_time:  time.struct_time(tm_year=1900, tm_mon=1, tm_mday=1, tm_hour=0, tm_min=12, tm_sec=53, tm_wday=0, tm_yday=1, tm_isdst=-1)
# curr_time:  time.struct_time(tm_year=1900, tm_mon=1, tm_mday=1, tm_hour=0, tm_min=13, tm_sec=0, tm_wday=0, tm_yday=1, tm_isdst=-1)
# curr_time:  time.struct_time(tm_year=1900, tm_mon=1, tm_mday=1, tm_hour=0, tm_min=13, tm_sec=3, tm_wday=0, tm_yday=1, tm_isdst=-1)
# curr_time:  time.struct_time(tm_year=1900, tm_mon=1, tm_mday=1, tm_hour=0, tm_min=13, tm_sec=4, tm_wday=0, tm_yday=1, tm_isdst=-1)
# curr_time:  time.struct_time(tm_year=1900, tm_mon=1, tm_mday=1, tm_hour=0, tm_min=13, tm_sec=25, tm_wday=0, tm_yday=1, tm_isdst=-1)
# curr_time:  time.struct_time(tm_year=1900, tm_mon=1, tm_mday=1, tm_hour=0, tm_min=13, tm_sec=26, tm_wday=0, tm_yday=1, tm_isdst=-1)
# curr_time:  time.struct_time(tm_year=1900, tm_mon=1, tm_mday=1, tm_hour=0, tm_min=13, tm_sec=28, tm_wday=0, tm_yday=1, tm_isdst=-1)
# curr_time:  time.struct_time(tm_year=1900, tm_mon=1, tm_mday=1, tm_hour=0, tm_min=13, tm_sec=29, tm_wday=0, tm_yday=1, tm_isdst=-1)
# curr_time:  time.struct_time(tm_year=1900, tm_mon=1, tm_mday=1, tm_hour=0, tm_min=13, tm_sec=33, tm_wday=0, tm_yday=1, tm_isdst=-1)
# curr_time:  time.struct_time(tm_year=1900, tm_mon=1, tm_mday=1, tm_hour=0, tm_min=13, tm_sec=34, tm_wday=0, tm_yday=1, tm_isdst=-1)
# curr_time:  time.struct_time(tm_year=1900, tm_mon=1, tm_mday=1, tm_hour=0, tm_min=14, tm_sec=0, tm_wday=0, tm_yday=1, tm_isdst=-1)
# curr_time:  time.struct_time(tm_year=1900, tm_mon=1, tm_mday=1, tm_hour=0, tm_min=14, tm_sec=5, tm_wday=0, tm_yday=1, tm_isdst=-1)
# curr_time:  time.struct_time(tm_year=1900, tm_mon=1, tm_mday=1, tm_hour=0, tm_min=14, tm_sec=11, tm_wday=0, tm_yday=1, tm_isdst=-1)
# curr_time:  time.struct_time(tm_year=1900, tm_mon=1, tm_mday=1, tm_hour=0, tm_min=14, tm_sec=25, tm_wday=0, tm_yday=1, tm_isdst=-1)
# curr_time:  time.struct_time(tm_year=1900, tm_mon=1, tm_mday=1, tm_hour=0, tm_min=14, tm_sec=29, tm_wday=0, tm_yday=1, tm_isdst=-1)
# curr_time:  time.struct_time(tm_year=1900, tm_mon=1, tm_mday=1, tm_hour=0, tm_min=15, tm_sec=14, tm_wday=0, tm_yday=1, tm_isdst=-1)
# curr_time:  time.struct_time(tm_year=1900, tm_mon=1, tm_mday=1, tm_hour=0, tm_min=15, tm_sec=18, tm_wday=0, tm_yday=1, tm_isdst=-1)
# curr_time:  time.struct_time(tm_year=1900, tm_mon=1, tm_mday=1, tm_hour=0, tm_min=15, tm_sec=19, tm_wday=0, tm_yday=1, tm_isdst=-1)
# curr_time:  time.struct_time(tm_year=1900, tm_mon=1, tm_mday=1, tm_hour=0, tm_min=15, tm_sec=24, tm_wday=0, tm_yday=1, tm_isdst=-1)
# curr_time:  time.struct_time(tm_year=1900, tm_mon=1, tm_mday=1, tm_hour=0, tm_min=15, tm_sec=25, tm_wday=0, tm_yday=1, tm_isdst=-1)
# curr_time:  time.struct_time(tm_year=1900, tm_mon=1, tm_mday=1, tm_hour=0, tm_min=15, tm_sec=33, tm_wday=0, tm_yday=1, tm_isdst=-1)
# curr_time:  time.struct_time(tm_year=1900, tm_mon=1, tm_mday=1, tm_hour=0, tm_min=15, tm_sec=34, tm_wday=0, tm_yday=1, tm_isdst=-1)
# curr_time:  time.struct_time(tm_year=1900, tm_mon=1, tm_mday=1, tm_hour=0, tm_min=15, tm_sec=35, tm_wday=0, tm_yday=1, tm_isdst=-1)
# curr_time:  time.struct_time(tm_year=1900, tm_mon=1, tm_mday=1, tm_hour=0, tm_min=15, tm_sec=37, tm_wday=0, tm_yday=1, tm_isdst=-1)
# curr_time:  time.struct_time(tm_year=1900, tm_mon=1, tm_mday=1, tm_hour=0, tm_min=15, tm_sec=42, tm_wday=0, tm_yday=1, tm_isdst=-1)
# curr_time:  time.struct_time(tm_year=1900, tm_mon=1, tm_mday=1, tm_hour=0, tm_min=16, tm_sec=3, tm_wday=0, tm_yday=1, tm_isdst=-1)
# curr_time:  time.struct_time(tm_year=1900, tm_mon=1, tm_mday=1, tm_hour=0, tm_min=16, tm_sec=4, tm_wday=0, tm_yday=1, tm_isdst=-1)
# curr_time:  time.struct_time(tm_year=1900, tm_mon=1, tm_mday=1, tm_hour=0, tm_min=16, tm_sec=32, tm_wday=0, tm_yday=1, tm_isdst=-1)
# curr_time:  time.struct_time(tm_year=1900, tm_mon=1, tm_mday=1, tm_hour=0, tm_min=16, tm_sec=33, tm_wday=0, tm_yday=1, tm_isdst=-1)
# curr_time:  time.struct_time(tm_year=1900, tm_mon=1, tm_mday=1, tm_hour=0, tm_min=21, tm_sec=16, tm_wday=0, tm_yday=1, tm_isdst=-1)
# curr_time:  time.struct_time(tm_year=1900, tm_mon=1, tm_mday=1, tm_hour=0, tm_min=21, tm_sec=22, tm_wday=0, tm_yday=1, tm_isdst=-1)
# curr_time:  time.struct_time(tm_year=1900, tm_mon=1, tm_mday=1, tm_hour=0, tm_min=21, tm_sec=23, tm_wday=0, tm_yday=1, tm_isdst=-1)
# curr_time:  time.struct_time(tm_year=1900, tm_mon=1, tm_mday=1, tm_hour=0, tm_min=21, tm_sec=26, tm_wday=0, tm_yday=1, tm_isdst=-1)
# curr_time:  time.struct_time(tm_year=1900, tm_mon=1, tm_mday=1, tm_hour=0, tm_min=21, tm_sec=28, tm_wday=0, tm_yday=1, tm_isdst=-1)
# curr_time:  time.struct_time(tm_year=1900, tm_mon=1, tm_mday=1, tm_hour=0, tm_min=21, tm_sec=29, tm_wday=0, tm_yday=1, tm_isdst=-1)
# curr_time:  time.struct_time(tm_year=1900, tm_mon=1, tm_mday=1, tm_hour=0, tm_min=21, tm_sec=37, tm_wday=0, tm_yday=1, tm_isdst=-1)
# curr_time:  time.struct_time(tm_year=1900, tm_mon=1, tm_mday=1, tm_hour=0, tm_min=21, tm_sec=48, tm_wday=0, tm_yday=1, tm_isdst=-1)
# curr_time:  time.struct_time(tm_year=1900, tm_mon=1, tm_mday=1, tm_hour=0, tm_min=21, tm_sec=49, tm_wday=0, tm_yday=1, tm_isdst=-1)
# curr_time:  time.struct_time(tm_year=1900, tm_mon=1, tm_mday=1, tm_hour=0, tm_min=22, tm_sec=9, tm_wday=0, tm_yday=1, tm_isdst=-1)
# curr_time:  time.struct_time(tm_year=1900, tm_mon=1, tm_mday=1, tm_hour=0, tm_min=22, tm_sec=10, tm_wday=0, tm_yday=1, tm_isdst=-1)
# curr_time:  time.struct_time(tm_year=1900, tm_mon=1, tm_mday=1, tm_hour=0, tm_min=22, tm_sec=39, tm_wday=0, tm_yday=1, tm_isdst=-1)
# curr_time:  time.struct_time(tm_year=1900, tm_mon=1, tm_mday=1, tm_hour=0, tm_min=22, tm_sec=42, tm_wday=0, tm_yday=1, tm_isdst=-1)
# curr_time:  time.struct_time(tm_year=1900, tm_mon=1, tm_mday=1, tm_hour=0, tm_min=22, tm_sec=43, tm_wday=0, tm_yday=1, tm_isdst=-1)
# curr_time:  time.struct_time(tm_year=1900, tm_mon=1, tm_mday=1, tm_hour=0, tm_min=22, tm_sec=46, tm_wday=0, tm_yday=1, tm_isdst=-1)
# curr_time:  time.struct_time(tm_year=1900, tm_mon=1, tm_mday=1, tm_hour=0, tm_min=22, tm_sec=47, tm_wday=0, tm_yday=1, tm_isdst=-1)
# curr_time:  time.struct_time(tm_year=1900, tm_mon=1, tm_mday=1, tm_hour=0, tm_min=24, tm_sec=25, tm_wday=0, tm_yday=1, tm_isdst=-1)
# curr_time:  time.struct_time(tm_year=1900, tm_mon=1, tm_mday=1, tm_hour=0, tm_min=24, tm_sec=26, tm_wday=0, tm_yday=1, tm_isdst=-1)
# curr_time:  time.struct_time(tm_year=1900, tm_mon=1, tm_mday=1, tm_hour=0, tm_min=24, tm_sec=38, tm_wday=0, tm_yday=1, tm_isdst=-1)
# curr_time:  time.struct_time(tm_year=1900, tm_mon=1, tm_mday=1, tm_hour=0, tm_min=24, tm_sec=39, tm_wday=0, tm_yday=1, tm_isdst=-1)
# curr_time:  time.struct_time(tm_year=1900, tm_mon=1, tm_mday=1, tm_hour=0, tm_min=24, tm_sec=52, tm_wday=0, tm_yday=1, tm_isdst=-1)
# curr_time:  time.struct_time(tm_year=1900, tm_mon=1, tm_mday=1, tm_hour=0, tm_min=25, tm_sec=1, tm_wday=0, tm_yday=1, tm_isdst=-1)
# curr_time:  time.struct_time(tm_year=1900, tm_mon=1, tm_mday=1, tm_hour=0, tm_min=0, tm_sec=3, tm_wday=0, tm_yday=1, tm_isdst=-1)
# curr_time:  time.struct_time(tm_year=1900, tm_mon=1, tm_mday=1, tm_hour=0, tm_min=0, tm_sec=4, tm_wday=0, tm_yday=1, tm_isdst=-1)
# curr_time:  time.struct_time(tm_year=1900, tm_mon=1, tm_mday=1, tm_hour=0, tm_min=0, tm_sec=8, tm_wday=0, tm_yday=1, tm_isdst=-1)
# curr_time:  time.struct_time(tm_year=1900, tm_mon=1, tm_mday=1, tm_hour=0, tm_min=0, tm_sec=9, tm_wday=0, tm_yday=1, tm_isdst=-1)
# curr_time:  time.struct_time(tm_year=1900, tm_mon=1, tm_mday=1, tm_hour=0, tm_min=0, tm_sec=11, tm_wday=0, tm_yday=1, tm_isdst=-1)
# curr_time:  time.struct_time(tm_year=1900, tm_mon=1, tm_mday=1, tm_hour=0, tm_min=0, tm_sec=13, tm_wday=0, tm_yday=1, tm_isdst=-1)
# curr_time:  time.struct_time(tm_year=1900, tm_mon=1, tm_mday=1, tm_hour=0, tm_min=0, tm_sec=14, tm_wday=0, tm_yday=1, tm_isdst=-1)
# curr_time:  time.struct_time(tm_year=1900, tm_mon=1, tm_mday=1, tm_hour=0, tm_min=0, tm_sec=19, tm_wday=0, tm_yday=1, tm_isdst=-1)
# curr_time:  time.struct_time(tm_year=1900, tm_mon=1, tm_mday=1, tm_hour=0, tm_min=0, tm_sec=20, tm_wday=0, tm_yday=1, tm_isdst=-1)
# curr_time:  time.struct_time(tm_year=1900, tm_mon=1, tm_mday=1, tm_hour=0, tm_min=0, tm_sec=21, tm_wday=0, tm_yday=1, tm_isdst=-1)
# curr_time:  time.struct_time(tm_year=1900, tm_mon=1, tm_mday=1, tm_hour=0, tm_min=0, tm_sec=22, tm_wday=0, tm_yday=1, tm_isdst=-1)
# curr_time:  time.struct_time(tm_year=1900, tm_mon=1, tm_mday=1, tm_hour=0, tm_min=0, tm_sec=24, tm_wday=0, tm_yday=1, tm_isdst=-1)
# curr_time:  time.struct_time(tm_year=1900, tm_mon=1, tm_mday=1, tm_hour=0, tm_min=0, tm_sec=29, tm_wday=0, tm_yday=1, tm_isdst=-1)
# curr_time:  time.struct_time(tm_year=1900, tm_mon=1, tm_mday=1, tm_hour=0, tm_min=0, tm_sec=33, tm_wday=0, tm_yday=1, tm_isdst=-1)
# curr_time:  time.struct_time(tm_year=1900, tm_mon=1, tm_mday=1, tm_hour=0, tm_min=0, tm_sec=40, tm_wday=0, tm_yday=1, tm_isdst=-1)
# curr_time:  time.struct_time(tm_year=1900, tm_mon=1, tm_mday=1, tm_hour=0, tm_min=0, tm_sec=45, tm_wday=0, tm_yday=1, tm_isdst=-1)
# curr_time:  time.struct_time(tm_year=1900, tm_mon=1, tm_mday=1, tm_hour=0, tm_min=0, tm_sec=46, tm_wday=0, tm_yday=1, tm_isdst=-1)
# curr_time:  time.struct_time(tm_year=1900, tm_mon=1, tm_mday=1, tm_hour=0, tm_min=1, tm_sec=4, tm_wday=0, tm_yday=1, tm_isdst=-1)
# curr_time:  time.struct_time(tm_year=1900, tm_mon=1, tm_mday=1, tm_hour=0, tm_min=1, tm_sec=5, tm_wday=0, tm_yday=1, tm_isdst=-1)
# curr_time:  time.struct_time(tm_year=1900, tm_mon=1, tm_mday=1, tm_hour=0, tm_min=1, tm_sec=37, tm_wday=0, tm_yday=1, tm_isdst=-1)
# curr_time:  time.struct_time(tm_year=1900, tm_mon=1, tm_mday=1, tm_hour=0, tm_min=2, tm_sec=34, tm_wday=0, tm_yday=1, tm_isdst=-1)
# curr_time:  time.struct_time(tm_year=1900, tm_mon=1, tm_mday=1, tm_hour=0, tm_min=2, tm_sec=35, tm_wday=0, tm_yday=1, tm_isdst=-1)
# curr_time:  time.struct_time(tm_year=1900, tm_mon=1, tm_mday=1, tm_hour=0, tm_min=2, tm_sec=39, tm_wday=0, tm_yday=1, tm_isdst=-1)
# curr_time:  time.struct_time(tm_year=1900, tm_mon=1, tm_mday=1, tm_hour=0, tm_min=2, tm_sec=40, tm_wday=0, tm_yday=1, tm_isdst=-1)
# curr_time:  time.struct_time(tm_year=1900, tm_mon=1, tm_mday=1, tm_hour=0, tm_min=2, tm_sec=44, tm_wday=0, tm_yday=1, tm_isdst=-1)
# curr_time:  time.struct_time(tm_year=1900, tm_mon=1, tm_mday=1, tm_hour=0, tm_min=2, tm_sec=45, tm_wday=0, tm_yday=1, tm_isdst=-1)
# curr_time:  time.struct_time(tm_year=1900, tm_mon=1, tm_mday=1, tm_hour=0, tm_min=2, tm_sec=51, tm_wday=0, tm_yday=1, tm_isdst=-1)
# curr_time:  time.struct_time(tm_year=1900, tm_mon=1, tm_mday=1, tm_hour=0, tm_min=2, tm_sec=52, tm_wday=0, tm_yday=1, tm_isdst=-1)
# curr_time:  time.struct_time(tm_year=1900, tm_mon=1, tm_mday=1, tm_hour=0, tm_min=2, tm_sec=55, tm_wday=0, tm_yday=1, tm_isdst=-1)
# curr_time:  time.struct_time(tm_year=1900, tm_mon=1, tm_mday=1, tm_hour=0, tm_min=2, tm_sec=56, tm_wday=0, tm_yday=1, tm_isdst=-1)
# curr_time:  time.struct_time(tm_year=1900, tm_mon=1, tm_mday=1, tm_hour=0, tm_min=2, tm_sec=59, tm_wday=0, tm_yday=1, tm_isdst=-1)
# curr_time:  time.struct_time(tm_year=1900, tm_mon=1, tm_mday=1, tm_hour=0, tm_min=3, tm_sec=3, tm_wday=0, tm_yday=1, tm_isdst=-1)
# curr_time:  time.struct_time(tm_year=1900, tm_mon=1, tm_mday=1, tm_hour=0, tm_min=3, tm_sec=4, tm_wday=0, tm_yday=1, tm_isdst=-1)
# curr_time:  time.struct_time(tm_year=1900, tm_mon=1, tm_mday=1, tm_hour=0, tm_min=3, tm_sec=12, tm_wday=0, tm_yday=1, tm_isdst=-1)
# curr_time:  time.struct_time(tm_year=1900, tm_mon=1, tm_mday=1, tm_hour=0, tm_min=3, tm_sec=13, tm_wday=0, tm_yday=1, tm_isdst=-1)
# curr_time:  time.struct_time(tm_year=1900, tm_mon=1, tm_mday=1, tm_hour=0, tm_min=3, tm_sec=45, tm_wday=0, tm_yday=1, tm_isdst=-1)
# curr_time:  time.struct_time(tm_year=1900, tm_mon=1, tm_mday=1, tm_hour=0, tm_min=3, tm_sec=46, tm_wday=0, tm_yday=1, tm_isdst=-1)
# curr_time:  time.struct_time(tm_year=1900, tm_mon=1, tm_mday=1, tm_hour=0, tm_min=4, tm_sec=17, tm_wday=0, tm_yday=1, tm_isdst=-1)
# curr_time:  time.struct_time(tm_year=1900, tm_mon=1, tm_mday=1, tm_hour=0, tm_min=4, tm_sec=21, tm_wday=0, tm_yday=1, tm_isdst=-1)
# curr_time:  time.struct_time(tm_year=1900, tm_mon=1, tm_mday=1, tm_hour=0, tm_min=4, tm_sec=22, tm_wday=0, tm_yday=1, tm_isdst=-1)
# curr_time:  time.struct_time(tm_year=1900, tm_mon=1, tm_mday=1, tm_hour=0, tm_min=4, tm_sec=29, tm_wday=0, tm_yday=1, tm_isdst=-1)
# curr_time:  time.struct_time(tm_year=1900, tm_mon=1, tm_mday=1, tm_hour=0, tm_min=4, tm_sec=30, tm_wday=0, tm_yday=1, tm_isdst=-1)
# curr_time:  time.struct_time(tm_year=1900, tm_mon=1, tm_mday=1, tm_hour=0, tm_min=4, tm_sec=31, tm_wday=0, tm_yday=1, tm_isdst=-1)
# curr_time:  time.struct_time(tm_year=1900, tm_mon=1, tm_mday=1, tm_hour=0, tm_min=4, tm_sec=35, tm_wday=0, tm_yday=1, tm_isdst=-1)
# curr_time:  time.struct_time(tm_year=1900, tm_mon=1, tm_mday=1, tm_hour=0, tm_min=4, tm_sec=36, tm_wday=0, tm_yday=1, tm_isdst=-1)
# curr_time:  time.struct_time(tm_year=1900, tm_mon=1, tm_mday=1, tm_hour=0, tm_min=4, tm_sec=38, tm_wday=0, tm_yday=1, tm_isdst=-1)
# curr_time:  time.struct_time(tm_year=1900, tm_mon=1, tm_mday=1, tm_hour=0, tm_min=4, tm_sec=41, tm_wday=0, tm_yday=1, tm_isdst=-1)
# curr_time:  time.struct_time(tm_year=1900, tm_mon=1, tm_mday=1, tm_hour=0, tm_min=4, tm_sec=42, tm_wday=0, tm_yday=1, tm_isdst=-1)
# curr_time:  time.struct_time(tm_year=1900, tm_mon=1, tm_mday=1, tm_hour=0, tm_min=5, tm_sec=2, tm_wday=0, tm_yday=1, tm_isdst=-1)
# curr_time:  time.struct_time(tm_year=1900, tm_mon=1, tm_mday=1, tm_hour=0, tm_min=5, tm_sec=3, tm_wday=0, tm_yday=1, tm_isdst=-1)
# curr_time:  time.struct_time(tm_year=1900, tm_mon=1, tm_mday=1, tm_hour=0, tm_min=8, tm_sec=5, tm_wday=0, tm_yday=1, tm_isdst=-1)
# curr_time:  time.struct_time(tm_year=1900, tm_mon=1, tm_mday=1, tm_hour=0, tm_min=8, tm_sec=6, tm_wday=0, tm_yday=1, tm_isdst=-1)
# curr_time:  time.struct_time(tm_year=1900, tm_mon=1, tm_mday=1, tm_hour=0, tm_min=8, tm_sec=7, tm_wday=0, tm_yday=1, tm_isdst=-1)
# curr_time:  time.struct_time(tm_year=1900, tm_mon=1, tm_mday=1, tm_hour=0, tm_min=8, tm_sec=9, tm_wday=0, tm_yday=1, tm_isdst=-1)
# curr_time:  time.struct_time(tm_year=1900, tm_mon=1, tm_mday=1, tm_hour=0, tm_min=8, tm_sec=11, tm_wday=0, tm_yday=1, tm_isdst=-1)
# curr_time:  time.struct_time(tm_year=1900, tm_mon=1, tm_mday=1, tm_hour=0, tm_min=8, tm_sec=21, tm_wday=0, tm_yday=1, tm_isdst=-1)
# curr_time:  time.struct_time(tm_year=1900, tm_mon=1, tm_mday=1, tm_hour=0, tm_min=8, tm_sec=23, tm_wday=0, tm_yday=1, tm_isdst=-1)
# curr_time:  time.struct_time(tm_year=1900, tm_mon=1, tm_mday=1, tm_hour=0, tm_min=8, tm_sec=31, tm_wday=0, tm_yday=1, tm_isdst=-1)
# curr_time:  time.struct_time(tm_year=1900, tm_mon=1, tm_mday=1, tm_hour=0, tm_min=8, tm_sec=32, tm_wday=0, tm_yday=1, tm_isdst=-1)
# curr_time:  time.struct_time(tm_year=1900, tm_mon=1, tm_mday=1, tm_hour=0, tm_min=8, tm_sec=36, tm_wday=0, tm_yday=1, tm_isdst=-1)
# curr_time:  time.struct_time(tm_year=1900, tm_mon=1, tm_mday=1, tm_hour=0, tm_min=8, tm_sec=48, tm_wday=0, tm_yday=1, tm_isdst=-1)
# curr_time:  time.struct_time(tm_year=1900, tm_mon=1, tm_mday=1, tm_hour=0, tm_min=8, tm_sec=49, tm_wday=0, tm_yday=1, tm_isdst=-1)
# curr_time:  time.struct_time(tm_year=1900, tm_mon=1, tm_mday=1, tm_hour=0, tm_min=9, tm_sec=44, tm_wday=0, tm_yday=1, tm_isdst=-1)
# curr_time:  time.struct_time(tm_year=1900, tm_mon=1, tm_mday=1, tm_hour=0, tm_min=9, tm_sec=46, tm_wday=0, tm_yday=1, tm_isdst=-1)
# curr_time:  time.struct_time(tm_year=1900, tm_mon=1, tm_mday=1, tm_hour=0, tm_min=9, tm_sec=51, tm_wday=0, tm_yday=1, tm_isdst=-1)
# curr_time:  time.struct_time(tm_year=1900, tm_mon=1, tm_mday=1, tm_hour=0, tm_min=9, tm_sec=52, tm_wday=0, tm_yday=1, tm_isdst=-1)
# curr_time:  time.struct_time(tm_year=1900, tm_mon=1, tm_mday=1, tm_hour=0, tm_min=12, tm_sec=49, tm_wday=0, tm_yday=1, tm_isdst=-1)
# curr_time:  time.struct_time(tm_year=1900, tm_mon=1, tm_mday=1, tm_hour=0, tm_min=12, tm_sec=51, tm_wday=0, tm_yday=1, tm_isdst=-1)
# curr_time:  time.struct_time(tm_year=1900, tm_mon=1, tm_mday=1, tm_hour=0, tm_min=12, tm_sec=52, tm_wday=0, tm_yday=1, tm_isdst=-1)
# curr_time:  time.struct_time(tm_year=1900, tm_mon=1, tm_mday=1, tm_hour=0, tm_min=12, tm_sec=59, tm_wday=0, tm_yday=1, tm_isdst=-1)
# curr_time:  time.struct_time(tm_year=1900, tm_mon=1, tm_mday=1, tm_hour=0, tm_min=13, tm_sec=0, tm_wday=0, tm_yday=1, tm_isdst=-1)
# ...
# curr_time:  time.struct_time(tm_year=1900, tm_mon=1, tm_mday=1, tm_hour=0, tm_min=2, tm_sec=2, tm_wday=0, tm_yday=1, tm_isdst=-1)
# curr_time:  time.struct_time(tm_year=1900, tm_mon=1, tm_mday=1, tm_hour=0, tm_min=2, tm_sec=5, tm_wday=0, tm_yday=1, tm_isdst=-1)
# curr_time:  time.struct_time(tm_year=1900, tm_mon=1, tm_mday=1, tm_hour=0, tm_min=2, tm_sec=8, tm_wday=0, tm_yday=1, tm_isdst=-1)
# curr_time:  time.struct_time(tm_year=1900, tm_mon=1, tm_mday=1, tm_hour=0, tm_min=2, tm_sec=10, tm_wday=0, tm_yday=1, tm_isdst=-1)
# curr_time:  time.struct_time(tm_year=1900, tm_mon=1, tm_mday=1, tm_hour=0, tm_min=2, tm_sec=11, tm_wday=0, tm_yday=1, tm_isdst=-1)
# curr_time:  time.struct_time(tm_year=1900, tm_mon=1, tm_mday=1, tm_hour=0, tm_min=2, tm_sec=13, tm_wday=0, tm_yday=1, tm_isdst=-1)
# curr_time:  time.struct_time(tm_year=1900, tm_mon=1, tm_mday=1, tm_hour=0, tm_min=2, tm_sec=14, tm_wday=0, tm_yday=1, tm_isdst=-1)
# curr_time:  time.struct_time(tm_year=1900, tm_mon=1, tm_mday=1, tm_hour=0, tm_min=2, tm_sec=18, tm_wday=0, tm_yday=1, tm_isdst=-1)
# curr_time:  time.struct_time(tm_year=1900, tm_mon=1, tm_mday=1, tm_hour=0, tm_min=2, tm_sec=20, tm_wday=0, tm_yday=1, tm_isdst=-1)
# curr_time:  time.struct_time(tm_year=1900, tm_mon=1, tm_mday=1, tm_hour=0, tm_min=2, tm_sec=26, tm_wday=0, tm_yday=1, tm_isdst=-1)
# curr_time:  time.struct_time(tm_year=1900, tm_mon=1, tm_mday=1, tm_hour=0, tm_min=2, tm_sec=27, tm_wday=0, tm_yday=1, tm_isdst=-1)
# curr_time:  time.struct_time(tm_year=1900, tm_mon=1, tm_mday=1, tm_hour=0, tm_min=2, tm_sec=32, tm_wday=0, tm_yday=1, tm_isdst=-1)
# curr_time:  time.struct_time(tm_year=1900, tm_mon=1, tm_mday=1, tm_hour=0, tm_min=2, tm_sec=42, tm_wday=0, tm_yday=1, tm_isdst=-1)
# curr_time:  time.struct_time(tm_year=1900, tm_mon=1, tm_mday=1, tm_hour=0, tm_min=2, tm_sec=43, tm_wday=0, tm_yday=1, tm_isdst=-1)
# curr_time:  time.struct_time(tm_year=1900, tm_mon=1, tm_mday=1, tm_hour=0, tm_min=3, tm_sec=7, tm_wday=0, tm_yday=1, tm_isdst=-1)
# curr_time:  time.struct_time(tm_year=1900, tm_mon=1, tm_mday=1, tm_hour=0, tm_min=3, tm_sec=8, tm_wday=0, tm_yday=1, tm_isdst=-1)
# curr_time:  time.struct_time(tm_year=1900, tm_mon=1, tm_mday=1, tm_hour=0, tm_min=3, tm_sec=22, tm_wday=0, tm_yday=1, tm_isdst=-1)
# curr_time:  time.struct_time(tm_year=1900, tm_mon=1, tm_mday=1, tm_hour=0, tm_min=3, tm_sec=23, tm_wday=0, tm_yday=1, tm_isdst=-1)
# curr_time:  time.struct_time(tm_year=1900, tm_mon=1, tm_mday=1, tm_hour=0, tm_min=3, tm_sec=24, tm_wday=0, tm_yday=1, tm_isdst=-1)
# curr_time:  time.struct_time(tm_year=1900, tm_mon=1, tm_mday=1, tm_hour=0, tm_min=3, tm_sec=25, tm_wday=0, tm_yday=1, tm_isdst=-1)
# curr_time:  time.struct_time(tm_year=1900, tm_mon=1, tm_mday=1, tm_hour=0, tm_min=3, tm_sec=28, tm_wday=0, tm_yday=1, tm_isdst=-1)
# curr_time:  time.struct_time(tm_year=1900, tm_mon=1, tm_mday=1, tm_hour=0, tm_min=3, tm_sec=29, tm_wday=0, tm_yday=1, tm_isdst=-1)
# curr_time:  time.struct_time(tm_year=1900, tm_mon=1, tm_mday=1, tm_hour=0, tm_min=3, tm_sec=32, tm_wday=0, tm_yday=1, tm_isdst=-1)
# curr_time:  time.struct_time(tm_year=1900, tm_mon=1, tm_mday=1, tm_hour=0, tm_min=3, tm_sec=35, tm_wday=0, tm_yday=1, tm_isdst=-1)
# curr_time:  time.struct_time(tm_year=1900, tm_mon=1, tm_mday=1, tm_hour=0, tm_min=3, tm_sec=36, tm_wday=0, tm_yday=1, tm_isdst=-1)
# curr_time:  time.struct_time(tm_year=1900, tm_mon=1, tm_mday=1, tm_hour=0, tm_min=3, tm_sec=38, tm_wday=0, tm_yday=1, tm_isdst=-1)
# curr_time:  time.struct_time(tm_year=1900, tm_mon=1, tm_mday=1, tm_hour=0, tm_min=3, tm_sec=46, tm_wday=0, tm_yday=1, tm_isdst=-1)
# curr_time:  time.struct_time(tm_year=1900, tm_mon=1, tm_mday=1, tm_hour=0, tm_min=3, tm_sec=47, tm_wday=0, tm_yday=1, tm_isdst=-1)
# curr_time:  time.struct_time(tm_year=1900, tm_mon=1, tm_mday=1, tm_hour=0, tm_min=3, tm_sec=49, tm_wday=0, tm_yday=1, tm_isdst=-1)
# curr_time:  time.struct_time(tm_year=1900, tm_mon=1, tm_mday=1, tm_hour=0, tm_min=3, tm_sec=50, tm_wday=0, tm_yday=1, tm_isdst=-1)
# curr_time:  time.struct_time(tm_year=1900, tm_mon=1, tm_mday=1, tm_hour=0, tm_min=4, tm_sec=30, tm_wday=0, tm_yday=1, tm_isdst=-1)
# curr_time:  time.struct_time(tm_year=1900, tm_mon=1, tm_mday=1, tm_hour=0, tm_min=4, tm_sec=31, tm_wday=0, tm_yday=1, tm_isdst=-1)
# curr_time:  time.struct_time(tm_year=1900, tm_mon=1, tm_mday=1, tm_hour=0, tm_min=5, tm_sec=12, tm_wday=0, tm_yday=1, tm_isdst=-1)
# curr_time:  time.struct_time(tm_year=1900, tm_mon=1, tm_mday=1, tm_hour=0, tm_min=5, tm_sec=17, tm_wday=0, tm_yday=1, tm_isdst=-1)
# curr_time:  time.struct_time(tm_year=1900, tm_mon=1, tm_mday=1, tm_hour=0, tm_min=5, tm_sec=18, tm_wday=0, tm_yday=1, tm_isdst=-1)
# curr_time:  time.struct_time(tm_year=1900, tm_mon=1, tm_mday=1, tm_hour=0, tm_min=5, tm_sec=23, tm_wday=0, tm_yday=1, tm_isdst=-1)
# curr_time:  time.struct_time(tm_year=1900, tm_mon=1, tm_mday=1, tm_hour=0, tm_min=5, tm_sec=24, tm_wday=0, tm_yday=1, tm_isdst=-1)
# curr_time:  time.struct_time(tm_year=1900, tm_mon=1, tm_mday=1, tm_hour=0, tm_min=5, tm_sec=26, tm_wday=0, tm_yday=1, tm_isdst=-1)
# curr_time:  time.struct_time(tm_year=1900, tm_mon=1, tm_mday=1, tm_hour=0, tm_min=5, tm_sec=34, tm_wday=0, tm_yday=1, tm_isdst=-1)
# curr_time:  time.struct_time(tm_year=1900, tm_mon=1, tm_mday=1, tm_hour=0, tm_min=5, tm_sec=35, tm_wday=0, tm_yday=1, tm_isdst=-1)
# curr_time:  time.struct_time(tm_year=1900, tm_mon=1, tm_mday=1, tm_hour=0, tm_min=5, tm_sec=42, tm_wday=0, tm_yday=1, tm_isdst=-1)
# curr_time:  time.struct_time(tm_year=1900, tm_mon=1, tm_mday=1, tm_hour=0, tm_min=5, tm_sec=43, tm_wday=0, tm_yday=1, tm_isdst=-1)
# curr_time:  time.struct_time(tm_year=1900, tm_mon=1, tm_mday=1, tm_hour=0, tm_min=6, tm_sec=0, tm_wday=0, tm_yday=1, tm_isdst=-1)
# curr_time:  time.struct_time(tm_year=1900, tm_mon=1, tm_mday=1, tm_hour=0, tm_min=6, tm_sec=1, tm_wday=0, tm_yday=1, tm_isdst=-1)
# curr_time:  time.struct_time(tm_year=1900, tm_mon=1, tm_mday=1, tm_hour=0, tm_min=6, tm_sec=14, tm_wday=0, tm_yday=1, tm_isdst=-1)
# curr_time:  time.struct_time(tm_year=1900, tm_mon=1, tm_mday=1, tm_hour=0, tm_min=6, tm_sec=16, tm_wday=0, tm_yday=1, tm_isdst=-1)
# curr_time:  time.struct_time(tm_year=1900, tm_mon=1, tm_mday=1, tm_hour=0, tm_min=6, tm_sec=17, tm_wday=0, tm_yday=1, tm_isdst=-1)
# curr_time:  time.struct_time(tm_year=1900, tm_mon=1, tm_mday=1, tm_hour=0, tm_min=6, tm_sec=24, tm_wday=0, tm_yday=1, tm_isdst=-1)
# curr_time:  time.struct_time(tm_year=1900, tm_mon=1, tm_mday=1, tm_hour=0, tm_min=6, tm_sec=25, tm_wday=0, tm_yday=1, tm_isdst=-1)
# curr_time:  time.struct_time(tm_year=1900, tm_mon=1, tm_mday=1, tm_hour=0, tm_min=6, tm_sec=30, tm_wday=0, tm_yday=1, tm_isdst=-1)
# curr_time:  time.struct_time(tm_year=1900, tm_mon=1, tm_mday=1, tm_hour=0, tm_min=6, tm_sec=31, tm_wday=0, tm_yday=1, tm_isdst=-1)
# curr_time:  time.struct_time(tm_year=1900, tm_mon=1, tm_mday=1, tm_hour=0, tm_min=6, tm_sec=32, tm_wday=0, tm_yday=1, tm_isdst=-1)
# curr_time:  time.struct_time(tm_year=1900, tm_mon=1, tm_mday=1, tm_hour=0, tm_min=6, tm_sec=36, tm_wday=0, tm_yday=1, tm_isdst=-1)
# curr_time:  time.struct_time(tm_year=1900, tm_mon=1, tm_mday=1, tm_hour=0, tm_min=6, tm_sec=37, tm_wday=0, tm_yday=1, tm_isdst=-1)
# curr_time:  time.struct_time(tm_year=1900, tm_mon=1, tm_mday=1, tm_hour=0, tm_min=6, tm_sec=44, tm_wday=0, tm_yday=1, tm_isdst=-1)
# curr_time:  time.struct_time(tm_year=1900, tm_mon=1, tm_mday=1, tm_hour=0, tm_min=6, tm_sec=45, tm_wday=0, tm_yday=1, tm_isdst=-1)
# curr_time:  time.struct_time(tm_year=1900, tm_mon=1, tm_mday=1, tm_hour=0, tm_min=7, tm_sec=21, tm_wday=0, tm_yday=1, tm_isdst=-1)
# curr_time:  time.struct_time(tm_year=1900, tm_mon=1, tm_mday=1, tm_hour=0, tm_min=7, tm_sec=22, tm_wday=0, tm_yday=1, tm_isdst=-1)
# curr_time:  time.struct_time(tm_year=1900, tm_mon=1, tm_mday=1, tm_hour=0, tm_min=7, tm_sec=44, tm_wday=0, tm_yday=1, tm_isdst=-1)
# curr_time:  time.struct_time(tm_year=1900, tm_mon=1, tm_mday=1, tm_hour=0, tm_min=7, tm_sec=47, tm_wday=0, tm_yday=1, tm_isdst=-1)
# curr_time:  time.struct_time(tm_year=1900, tm_mon=1, tm_mday=1, tm_hour=0, tm_min=7, tm_sec=52, tm_wday=0, tm_yday=1, tm_isdst=-1)
# curr_time:  time.struct_time(tm_year=1900, tm_mon=1, tm_mday=1, tm_hour=0, tm_min=7, tm_sec=57, tm_wday=0, tm_yday=1, tm_isdst=-1)
# curr_time:  time.struct_time(tm_year=1900, tm_mon=1, tm_mday=1, tm_hour=0, tm_min=8, tm_sec=3, tm_wday=0, tm_yday=1, tm_isdst=-1)
# curr_time:  time.struct_time(tm_year=1900, tm_mon=1, tm_mday=1, tm_hour=0, tm_min=8, tm_sec=10, tm_wday=0, tm_yday=1, tm_isdst=-1)
# curr_time:  time.struct_time(tm_year=1900, tm_mon=1, tm_mday=1, tm_hour=0, tm_min=8, tm_sec=11, tm_wday=0, tm_yday=1, tm_isdst=-1)
# curr_time:  time.struct_time(tm_year=1900, tm_mon=1, tm_mday=1, tm_hour=0, tm_min=8, tm_sec=14, tm_wday=0, tm_yday=1, tm_isdst=-1)
# curr_time:  time.struct_time(tm_year=1900, tm_mon=1, tm_mday=1, tm_hour=0, tm_min=8, tm_sec=18, tm_wday=0, tm_yday=1, tm_isdst=-1)
# curr_time:  time.struct_time(tm_year=1900, tm_mon=1, tm_mday=1, tm_hour=0, tm_min=8, tm_sec=23, tm_wday=0, tm_yday=1, tm_isdst=-1)
# curr_time:  time.struct_time(tm_year=1900, tm_mon=1, tm_mday=1, tm_hour=0, tm_min=8, tm_sec=24, tm_wday=0, tm_yday=1, tm_isdst=-1)
# curr_time:  time.struct_time(tm_year=1900, tm_mon=1, tm_mday=1, tm_hour=0, tm_min=8, tm_sec=25, tm_wday=0, tm_yday=1, tm_isdst=-1)
# curr_time:  time.struct_time(tm_year=1900, tm_mon=1, tm_mday=1, tm_hour=0, tm_min=8, tm_sec=30, tm_wday=0, tm_yday=1, tm_isdst=-1)
# curr_time:  time.struct_time(tm_year=1900, tm_mon=1, tm_mday=1, tm_hour=0, tm_min=8, tm_sec=31, tm_wday=0, tm_yday=1, tm_isdst=-1)
# curr_time:  time.struct_time(tm_year=1900, tm_mon=1, tm_mday=1, tm_hour=0, tm_min=8, tm_sec=34, tm_wday=0, tm_yday=1, tm_isdst=-1)
# curr_time:  time.struct_time(tm_year=1900, tm_mon=1, tm_mday=1, tm_hour=0, tm_min=8, tm_sec=35, tm_wday=0, tm_yday=1, tm_isdst=-1)
# curr_time:  time.struct_time(tm_year=1900, tm_mon=1, tm_mday=1, tm_hour=0, tm_min=8, tm_sec=42, tm_wday=0, tm_yday=1, tm_isdst=-1)
# curr_time:  time.struct_time(tm_year=1900, tm_mon=1, tm_mday=1, tm_hour=0, tm_min=8, tm_sec=44, tm_wday=0, tm_yday=1, tm_isdst=-1)
# curr_time:  time.struct_time(tm_year=1900, tm_mon=1, tm_mday=1, tm_hour=0, tm_min=8, tm_sec=47, tm_wday=0, tm_yday=1, tm_isdst=-1)
# curr_time:  time.struct_time(tm_year=1900, tm_mon=1, tm_mday=1, tm_hour=0, tm_min=8, tm_sec=52, tm_wday=0, tm_yday=1, tm_isdst=-1)
# curr_time:  time.struct_time(tm_year=1900, tm_mon=1, tm_mday=1, tm_hour=0, tm_min=8, tm_sec=53, tm_wday=0, tm_yday=1, tm_isdst=-1)
# curr_time:  time.struct_time(tm_year=1900, tm_mon=1, tm_mday=1, tm_hour=0, tm_min=9, tm_sec=9, tm_wday=0, tm_yday=1, tm_isdst=-1)
# curr_time:  time.struct_time(tm_year=1900, tm_mon=1, tm_mday=1, tm_hour=0, tm_min=9, tm_sec=10, tm_wday=0, tm_yday=1, tm_isdst=-1)
# curr_time:  time.struct_time(tm_year=1900, tm_mon=1, tm_mday=1, tm_hour=0, tm_min=9, tm_sec=24, tm_wday=0, tm_yday=1, tm_isdst=-1)
# curr_time:  time.struct_time(tm_year=1900, tm_mon=1, tm_mday=1, tm_hour=0, tm_min=9, tm_sec=28, tm_wday=0, tm_yday=1, tm_isdst=-1)
# curr_time:  time.struct_time(tm_year=1900, tm_mon=1, tm_mday=1, tm_hour=0, tm_min=9, tm_sec=29, tm_wday=0, tm_yday=1, tm_isdst=-1)
# curr_time:  time.struct_time(tm_year=1900, tm_mon=1, tm_mday=1, tm_hour=0, tm_min=9, tm_sec=34, tm_wday=0, tm_yday=1, tm_isdst=-1)
# curr_time:  time.struct_time(tm_year=1900, tm_mon=1, tm_mday=1, tm_hour=0, tm_min=9, tm_sec=35, tm_wday=0, tm_yday=1, tm_isdst=-1)
# curr_time:  time.struct_time(tm_year=1900, tm_mon=1, tm_mday=1, tm_hour=0, tm_min=9, tm_sec=39, tm_wday=0, tm_yday=1, tm_isdst=-1)
# curr_time:  time.struct_time(tm_year=1900, tm_mon=1, tm_mday=1, tm_hour=0, tm_min=9, tm_sec=40, tm_wday=0, tm_yday=1, tm_isdst=-1)
# curr_time:  time.struct_time(tm_year=1900, tm_mon=1, tm_mday=1, tm_hour=0, tm_min=9, tm_sec=42, tm_wday=0, tm_yday=1, tm_isdst=-1)
# curr_time:  time.struct_time(tm_year=1900, tm_mon=1, tm_mday=1, tm_hour=0, tm_min=9, tm_sec=48, tm_wday=0, tm_yday=1, tm_isdst=-1)
# curr_time:  time.struct_time(tm_year=1900, tm_mon=1, tm_mday=1, tm_hour=0, tm_min=10, tm_sec=17, tm_wday=0, tm_yday=1, tm_isdst=-1)
# curr_time:  time.struct_time(tm_year=1900, tm_mon=1, tm_mday=1, tm_hour=0, tm_min=10, tm_sec=18, tm_wday=0, tm_yday=1, tm_isdst=-1)
# curr_time:  time.struct_time(tm_year=1900, tm_mon=1, tm_mday=1, tm_hour=0, tm_min=10, tm_sec=38, tm_wday=0, tm_yday=1, tm_isdst=-1)
#                                                   Time  IMU A1  IMU A2  \
# ride_id UTC
# 15692   2018-11-09 19:16:03.789000+00:00  1.414743e+09   493.0    48.0
#         2018-11-09 19:16:04.053000+00:00  1.414743e+09   513.0    89.0
#         2018-11-09 19:16:04.284000+00:00  1.414743e+09   494.0    92.0
#         2018-11-09 19:16:04.548000+00:00  1.414744e+09   421.0   205.0
#         2018-11-09 19:16:04.812000+00:00  1.414744e+09   534.0   306.0
#         2018-11-09 19:16:05.043000+00:00  1.414744e+09   455.0   149.0
#         2018-11-09 19:16:05.307000+00:00  1.414744e+09   474.0   342.0
#         2018-11-09 19:16:05.571000+00:00  1.414745e+09   363.0   323.0
#         2018-11-09 19:16:05.802000+00:00  1.414745e+09   -21.0   510.0
#         2018-11-09 19:16:06.066000+00:00  1.414745e+09    35.0   283.0
#
#                                           IMU A3  IMU G1  IMU G2  IMU G3  \
# ride_id UTC
# 15692   2018-11-09 19:16:03.789000+00:00   110.0    75.0  -124.0   -86.0
#         2018-11-09 19:16:04.053000+00:00    62.0    34.0   -36.0   -92.0
#         2018-11-09 19:16:04.284000+00:00    80.0    69.0   -63.0   -42.0
#         2018-11-09 19:16:04.548000+00:00  -104.0   192.0   -92.0   -37.0
#         2018-11-09 19:16:04.812000+00:00   -32.0  -421.0  -233.0  -229.0
#         2018-11-09 19:16:05.043000+00:00  -102.0  -355.0  -376.0  -397.0
#         2018-11-09 19:16:05.307000+00:00  -219.0  -234.0  -527.0  -465.0
#         2018-11-09 19:16:05.571000+00:00  -131.0    60.0  -662.0  -305.0
#         2018-11-09 19:16:05.802000+00:00  -447.0    78.0  -643.0  -153.0
#         2018-11-09 19:16:06.066000+00:00  -132.0  -114.0  -430.0   132.0
#
#                                           IMU M1  IMU M2  IMU M3  TimeDelta  \
# ride_id UTC
# 15692   2018-11-09 19:16:03.789000+00:00  -309.0   209.0    39.0        0.0
#         2018-11-09 19:16:04.053000+00:00  -320.0   194.0    38.0      252.5
#         2018-11-09 19:16:04.284000+00:00  -329.0   189.0    49.0      501.5
#         2018-11-09 19:16:04.548000+00:00  -330.0   180.0    64.0      753.5
#         2018-11-09 19:16:04.812000+00:00  -325.0   161.0    97.0     1003.5
#         2018-11-09 19:16:05.043000+00:00  -337.0   117.0   151.0     1253.5
#         2018-11-09 19:16:05.307000+00:00  -311.0    25.0   217.0     1504.5
#         2018-11-09 19:16:05.571000+00:00  -238.0    -8.0   272.0     1755.5
#         2018-11-09 19:16:05.802000+00:00  -159.0   -21.0   321.0     2006.5
#         2018-11-09 19:16:06.066000+00:00   -86.0   -38.0   326.0     2258.5
#
#                                           WALKING  FLOATING  SURFING  PADDLING
# ride_id UTC
# 15692   2018-11-09 19:16:03.789000+00:00        0         0        0         0
#         2018-11-09 19:16:04.053000+00:00        0         0        0         0
#         2018-11-09 19:16:04.284000+00:00        0         0        0         0
#         2018-11-09 19:16:04.548000+00:00        0         0        0         0
#         2018-11-09 19:16:04.812000+00:00        0         0        0         0
#         2018-11-09 19:16:05.043000+00:00        0         0        0         0
#         2018-11-09 19:16:05.307000+00:00        0         0        0         0
#         2018-11-09 19:16:05.571000+00:00        0         0        0         0
#         2018-11-09 19:16:05.802000+00:00        0         0        0         0
#         2018-11-09 19:16:06.066000+00:00        0         0        0         0

# %%
motion_df_complex = label_data('../Labelled_Footage/Footage3.txt', 'complex')
motion_df_complex.head(10)
# Out:
#                                                   Time  IMU A1  IMU A2  \
# ride_id UTC
# 15692   2018-11-09 19:16:03.789000+00:00  1.414743e+09   493.0    48.0
#         2018-11-09 19:16:04.053000+00:00  1.414743e+09   513.0    89.0
#         2018-11-09 19:16:04.284000+00:00  1.414743e+09   494.0    92.0
#         2018-11-09 19:16:04.548000+00:00  1.414744e+09   421.0   205.0
#         2018-11-09 19:16:04.812000+00:00  1.414744e+09   534.0   306.0
#         2018-11-09 19:16:05.043000+00:00  1.414744e+09   455.0   149.0
#         2018-11-09 19:16:05.307000+00:00  1.414744e+09   474.0   342.0
#         2018-11-09 19:16:05.571000+00:00  1.414745e+09   363.0   323.0
#         2018-11-09 19:16:05.802000+00:00  1.414745e+09   -21.0   510.0
#         2018-11-09 19:16:06.066000+00:00  1.414745e+09    35.0   283.0
#
#                                           IMU A3  IMU G1  IMU G2  IMU G3  \
# ride_id UTC
# 15692   2018-11-09 19:16:03.789000+00:00   110.0    75.0  -124.0   -86.0
#         2018-11-09 19:16:04.053000+00:00    62.0    34.0   -36.0   -92.0
#         2018-11-09 19:16:04.284000+00:00    80.0    69.0   -63.0   -42.0
#         2018-11-09 19:16:04.548000+00:00  -104.0   192.0   -92.0   -37.0
#         2018-11-09 19:16:04.812000+00:00   -32.0  -421.0  -233.0  -229.0
#         2018-11-09 19:16:05.043000+00:00  -102.0  -355.0  -376.0  -397.0
#         2018-11-09 19:16:05.307000+00:00  -219.0  -234.0  -527.0  -465.0
#         2018-11-09 19:16:05.571000+00:00  -131.0    60.0  -662.0  -305.0
#         2018-11-09 19:16:05.802000+00:00  -447.0    78.0  -643.0  -153.0
#         2018-11-09 19:16:06.066000+00:00  -132.0  -114.0  -430.0   132.0
#
#                                           IMU M1  IMU M2  IMU M3  TimeDelta  \
# ride_id UTC
# 15692   2018-11-09 19:16:03.789000+00:00  -309.0   209.0    39.0        0.0
#         2018-11-09 19:16:04.053000+00:00  -320.0   194.0    38.0      252.5
#         2018-11-09 19:16:04.284000+00:00  -329.0   189.0    49.0      501.5
#         2018-11-09 19:16:04.548000+00:00  -330.0   180.0    64.0      753.5
#         2018-11-09 19:16:04.812000+00:00  -325.0   161.0    97.0     1003.5
#         2018-11-09 19:16:05.043000+00:00  -337.0   117.0   151.0     1253.5
#         2018-11-09 19:16:05.307000+00:00  -311.0    25.0   217.0     1504.5
#         2018-11-09 19:16:05.571000+00:00  -238.0    -8.0   272.0     1755.5
#         2018-11-09 19:16:05.802000+00:00  -159.0   -21.0   321.0     2006.5
#         2018-11-09 19:16:06.066000+00:00   -86.0   -38.0   326.0     2258.5
#
#                                           SYNC  FLIP BOARD RIGHT SIDE UP  \
# ride_id UTC
# 15692   2018-11-09 19:16:03.789000+00:00     0                         0
#         2018-11-09 19:16:04.053000+00:00     0                         0
#         2018-11-09 19:16:04.284000+00:00     0                         0
#         2018-11-09 19:16:04.548000+00:00     0                         0
#         2018-11-09 19:16:04.812000+00:00     0                         0
#         2018-11-09 19:16:05.043000+00:00     0                         0
#         2018-11-09 19:16:05.307000+00:00     0                         0
#         2018-11-09 19:16:05.571000+00:00     0                         0
#         2018-11-09 19:16:05.802000+00:00     0                         0
#         2018-11-09 19:16:06.066000+00:00     0                         0
#
#                                           WALKING IN WATER  PUSH-OFF  \
# ride_id UTC
# 15692   2018-11-09 19:16:03.789000+00:00                 0         0
#         2018-11-09 19:16:04.053000+00:00                 0         0
#         2018-11-09 19:16:04.284000+00:00                 0         0
#         2018-11-09 19:16:04.548000+00:00                 0         0
#         2018-11-09 19:16:04.812000+00:00                 0         0
#         2018-11-09 19:16:05.043000+00:00                 0         0
#         2018-11-09 19:16:05.307000+00:00                 0         0
#         2018-11-09 19:16:05.571000+00:00                 0         0
#         2018-11-09 19:16:05.802000+00:00                 0         0
#         2018-11-09 19:16:06.066000+00:00                 0         0
#
#                                           PADDLING INTO WAVES  SIT-UP  \
# ride_id UTC
# 15692   2018-11-09 19:16:03.789000+00:00                    0       0
#         2018-11-09 19:16:04.053000+00:00                    0       0
#         2018-11-09 19:16:04.284000+00:00                    0       0
#         2018-11-09 19:16:04.548000+00:00                    0       0
#         2018-11-09 19:16:04.812000+00:00                    0       0
#         2018-11-09 19:16:05.043000+00:00                    0       0
#         2018-11-09 19:16:05.307000+00:00                    0       0
#         2018-11-09 19:16:05.571000+00:00                    0       0
#         2018-11-09 19:16:05.802000+00:00                    0       0
#         2018-11-09 19:16:06.066000+00:00                    0       0
#
#                                           FLOATING  TURNING TO SURFER'S LEFT  \
# ride_id UTC
# 15692   2018-11-09 19:16:03.789000+00:00         0                         0
#         2018-11-09 19:16:04.053000+00:00         0                         0
#         2018-11-09 19:16:04.284000+00:00         0                         0
#         2018-11-09 19:16:04.548000+00:00         0                         0
#         2018-11-09 19:16:04.812000+00:00         0                         0
#         2018-11-09 19:16:05.043000+00:00         0                         0
#         2018-11-09 19:16:05.307000+00:00         0                         0
#         2018-11-09 19:16:05.571000+00:00         0                         0
#         2018-11-09 19:16:05.802000+00:00         0                         0
#         2018-11-09 19:16:06.066000+00:00         0                         0
#
#                                           LAY-DOWN  PADDLING FOR A WAVE  \
# ride_id UTC
# 15692   2018-11-09 19:16:03.789000+00:00         0                    0
#         2018-11-09 19:16:04.053000+00:00         0                    0
#         2018-11-09 19:16:04.284000+00:00         0                    0
#         2018-11-09 19:16:04.548000+00:00         0                    0
#         2018-11-09 19:16:04.812000+00:00         0                    0
#         2018-11-09 19:16:05.043000+00:00         0                    0
#         2018-11-09 19:16:05.307000+00:00         0                    0
#         2018-11-09 19:16:05.571000+00:00         0                    0
#         2018-11-09 19:16:05.802000+00:00         0                    0
#         2018-11-09 19:16:06.066000+00:00         0                    0
#
#                                           POP-UP  SURFING  STEP-OFF  \
# ride_id UTC
# 15692   2018-11-09 19:16:03.789000+00:00       0        0         0
#         2018-11-09 19:16:04.053000+00:00       0        0         0
#         2018-11-09 19:16:04.284000+00:00       0        0         0
#         2018-11-09 19:16:04.548000+00:00       0        0         0
#         2018-11-09 19:16:04.812000+00:00       0        0         0
#         2018-11-09 19:16:05.043000+00:00       0        0         0
#         2018-11-09 19:16:05.307000+00:00       0        0         0
#         2018-11-09 19:16:05.571000+00:00       0        0         0
#         2018-11-09 19:16:05.802000+00:00       0        0         0
#         2018-11-09 19:16:06.066000+00:00       0        0         0
#
#                                           TURNING TO SURFER'S RIGHT  SIT-BACK  \
# ride_id UTC
# 15692   2018-11-09 19:16:03.789000+00:00                          0         0
#         2018-11-09 19:16:04.053000+00:00                          0         0
#         2018-11-09 19:16:04.284000+00:00                          0         0
#         2018-11-09 19:16:04.548000+00:00                          0         0
#         2018-11-09 19:16:04.812000+00:00                          0         0
#         2018-11-09 19:16:05.043000+00:00                          0         0
#         2018-11-09 19:16:05.307000+00:00                          0         0
#         2018-11-09 19:16:05.571000+00:00                          0         0
#         2018-11-09 19:16:05.802000+00:00                          0         0
#         2018-11-09 19:16:06.066000+00:00                          0         0
#
#                                           OFF-BOARD  PADDLING  WIPE-OUT  \
# ride_id UTC
# 15692   2018-11-09 19:16:03.789000+00:00          0         0         0
#         2018-11-09 19:16:04.053000+00:00          0         0         0
#         2018-11-09 19:16:04.284000+00:00          0         0         0
#         2018-11-09 19:16:04.548000+00:00          0         0         0
#         2018-11-09 19:16:04.812000+00:00          0         0         0
#         2018-11-09 19:16:05.043000+00:00          0         0         0
#         2018-11-09 19:16:05.307000+00:00          0         0         0
#         2018-11-09 19:16:05.571000+00:00          0         0         0
#         2018-11-09 19:16:05.802000+00:00          0         0         0
#         2018-11-09 19:16:06.066000+00:00          0         0         0
#
#                                           PULL-BACK LEASH  \
# ride_id UTC
# 15692   2018-11-09 19:16:03.789000+00:00                0
#         2018-11-09 19:16:04.053000+00:00                0
#         2018-11-09 19:16:04.284000+00:00                0
#         2018-11-09 19:16:04.548000+00:00                0
#         2018-11-09 19:16:04.812000+00:00                0
#         2018-11-09 19:16:05.043000+00:00                0
#         2018-11-09 19:16:05.307000+00:00                0
#         2018-11-09 19:16:05.571000+00:00                0
#         2018-11-09 19:16:05.802000+00:00                0
#         2018-11-09 19:16:06.066000+00:00                0
#
#                                           PADDLING FOR POSITION  NEW  DISCARD  \
# ride_id UTC
# 15692   2018-11-09 19:16:03.789000+00:00                      0    0        0
#         2018-11-09 19:16:04.053000+00:00                      0    0        0
#         2018-11-09 19:16:04.284000+00:00                      0    0        0
#         2018-11-09 19:16:04.548000+00:00                      0    0        0
#         2018-11-09 19:16:04.812000+00:00                      0    0        0
#         2018-11-09 19:16:05.043000+00:00                      0    0        0
#         2018-11-09 19:16:05.307000+00:00                      0    0        0
#         2018-11-09 19:16:05.571000+00:00                      0    0        0
#         2018-11-09 19:16:05.802000+00:00                      0    0        0
#         2018-11-09 19:16:06.066000+00:00                      0    0        0
#
#                                           DONE, OUT OF WATER  \
# ride_id UTC
# 15692   2018-11-09 19:16:03.789000+00:00                   0
#         2018-11-09 19:16:04.053000+00:00                   0
#         2018-11-09 19:16:04.284000+00:00                   0
#         2018-11-09 19:16:04.548000+00:00                   0
#         2018-11-09 19:16:04.812000+00:00                   0
#         2018-11-09 19:16:05.043000+00:00                   0
#         2018-11-09 19:16:05.307000+00:00                   0
#         2018-11-09 19:16:05.571000+00:00                   0
#         2018-11-09 19:16:05.802000+00:00                   0
#         2018-11-09 19:16:06.066000+00:00                   0
#
#                                           WALKING OUT OF WATER
# ride_id UTC
# 15692   2018-11-09 19:16:03.789000+00:00                     0
#         2018-11-09 19:16:04.053000+00:00                     0
#         2018-11-09 19:16:04.284000+00:00                     0
#         2018-11-09 19:16:04.548000+00:00                     0
#         2018-11-09 19:16:04.812000+00:00                     0
#         2018-11-09 19:16:05.043000+00:00                     0
#         2018-11-09 19:16:05.307000+00:00                     0
#         2018-11-09 19:16:05.571000+00:00                     0
#         2018-11-09 19:16:05.802000+00:00                     0
#         2018-11-09 19:16:06.066000+00:00                     0

# %% [markdown]
# ## Concatenate multiple footage files that we have so far to create a larger mass of data samples.

# %%
df1_complex = label_data('Footage.txt', 'complex')
df2_complex = label_data('Footage2.txt', 'complex')
df3_complex = label_data('Footage3.txt', 'complex')
df4_complex = label_data('Footage4.txt', 'complex')

df_concatenated = pd.concat([df1_complex, df2_complex, df3_complex, df4_complex])

print("Shape of first dataframe:", df1_complex.shape)
print("Shape of all combined dataframes:", df_concatenated.shape)

print("Printing dataframe...")
#print(df1_complex.head(10))
print(df_concatenated.head(10))

# %% [markdown]
# ### Convert the Raw IMU data values to real units:

# %%
#correct IMU data

#make a deep copy of motion_df_labelled
df_converted = motion_df_complex.copy(deep = 'true')

#for rows in df_corrected
for row in range(0, df_converted.shape[0]):
    
    #convert acceleromters (new: m/s^2)
    df_converted.iloc[row, df_converted.columns.get_loc('IMU A1')] *= -0.019141  #forwards/backwards
    df_converted.iloc[row, df_converted.columns.get_loc('IMU A2')] *= 0.019141   #upside down/right side up
    df_converted.iloc[row, df_converted.columns.get_loc('IMU A3')] *= 0.019141   #sideways: negative = left, positive = right
 
    #convert gyroscopes (new: deg/s)
    df_converted.iloc[row, df_converted.columns.get_loc('IMU G1')] /= 8.2        #roll
    df_converted.iloc[row, df_converted.columns.get_loc('IMU G2')] /= 8.2        #yaw
    df_converted.iloc[row, df_converted.columns.get_loc('IMU G3')] /= 8.2        #pitch (flipping forwards/backwards)

motion_df_complex.head(10)

# %%
#df_converted.head(10)

# %%
#list(df_converted)

# %%
## Drop data columns that we don't care about predicting/visualizing: 
df_converted = df_converted.drop(columns=["FLIP BOARD RIGHT SIDE UP", "NEW", "DONE, OUT OF WATER"])
#df_converted = df_converted.drop(columns!=["SURFING, FLOATING, PADDLING INTO WAVES, PADDLING FOR A WAVE, PADDLING FOR POSITION, PADDLING"])

# %% [markdown]
# ## Plot IMU Signals with Labels:

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
plt.rcParams['figure.figsize'] = [50, 10]

#define a function that plots a column of dataf in relation to time. color coded to match labels in dataf
#requires that:
#dataf has a 'TimeDelta' column
#labels: walking, surfing, floating, paddling

def createPlot (dataf, column):
    
        #create new data frame to be plotted
        #Only consider columns after Velocity
        dfPlot = pd.DataFrame(columns = ['TIME'] + list(dataf)[list(dataf).index('TimeDelta') + 1:], dtype = float)
        
        #add timedelta column from dataf to dfPlot
        dfPlot['TIME'] = dataf['TimeDelta']
        
        #get the index of the column to be graphed
        columnInd = dataf.columns.get_loc(column)
        
        #for each row in dfPlot (number of IMU readings)
        for row in range(0, dfPlot.shape[0]):
            
            #for the indexes of the label columns in dfPlot
            for col in range(1, dfPlot.shape[1]):
                
                #if a label in the row is 1 in dataf
                if dataf.iloc[row, dataf.columns.get_loc(dfPlot.columns[col])] == 1:
                    
                    #add the sensors value to the corresponding column in dfPlot
                    dfPlot.iloc[row, dfPlot.columns.get_loc(dfPlot.columns[col])] = dataf.iloc[row, columnInd]
                    #dfPlot.iloc[row, dfPlot.columns.get]
        
        #Set up colormap so that we don't see a repeat in color when graphing
        #plt.gca().set_prop_cycle('color',plt.cm.plasma(np.linspace(0,1,dfPlot.shape[1])))
        plt.gca().set_prop_cycle('color',plt.cm.tab20(np.linspace(0,1,dfPlot.shape[1])))
        for col in range (1, dfPlot.shape[1]):
            plt.plot(dfPlot['TIME'], dfPlot[list(dfPlot)[col]])
        
        plt.gca().legend(loc = 'lower left')
        plt.title(column)
        plt.xlabel("Time")
        plt.ylabel("IMU Data")

        #file_name = column
        #pdf_string = '.jpg'
        #file_name += pdf_string
        
        #plt.savefig(file_name)
        plt.show()
        
        return

# %%
#For plotting, just comment out the "concatenation" lines. 

#Need to clear kernel and then only run all above so that it plots on axes directly below, rather than on another plot
print("Creating Plots...")
createPlot(df_converted,'IMU A1')
createPlot(df_converted,'IMU A2')
createPlot(df_converted,'IMU A3')
#createPlot(df_converted,'IMU G1')
#createPlot(df_converted,'IMU G2')
#createPlot(df_converted,'IMU G3')
#createPlot(df_converted,'IMU M1')
#createPlot(df_converted,'IMU M2')
#createPlot(df_converted,'IMU M3')

print("Done")

# %% [markdown]
# ### Instead of looking at all labels, just look at floating vs. not floating:

# %%
print(list(df_converted.columns))

drop_list = ['SYNC', 'WALKING IN WATER', 'PUSH-OFF', 'PADDLING INTO WAVES', 'SIT-UP', "TURNING TO SURFER'S LEFT", 'LAY-DOWN', 'PADDLING FOR A WAVE', 'POP-UP', 'SURFING', 'STEP-OFF', "TURNING TO SURFER'S RIGHT", 'SIT-BACK', 'OFF-BOARD', 'PADDLING', 'WIPE-OUT', 'PULL-BACK LEASH', 'PADDLING FOR POSITION', 'DISCARD', 'WALKING OUT OF WATER']
for x in drop_list: 
    if x in df_converted.columns:
        df_converted = df_converted.drop(columns=[x])

# %%
print("Creating Plots...")
createPlot(df_converted,'IMU A1')
createPlot(df_converted,'IMU A2')
createPlot(df_converted,'IMU A3')

# %%
#df_converted["IMU A2"]
df_converted["TimeDelta"]

# %% [markdown]
# ### Now we can try analyzing a "floating" time-slice in the middle of this data:

# %%
#Look at IMU A2 time-slice from 1,050,000 to 1,300,000:

keys = df_converted["TimeDelta"]
values = df_converted["IMU A2"]
imu_a2_time_dict = dict(zip(keys, values))

#Now need to slice the dictionary into 2 new lists: 
time_slice = []
imu_a2_slice = []
for time in imu_a2_time_dict:
    if time > 1050000 and time < 1300000:
        time_slice = float(time)
        #print(imu_a2_time_dict[time] - 9.80665)
        #Need to also subtract gravity from IMU A2 value:
        imu_a2_slice = float(imu_a2_time_dict[time] - 9.80665)

# %%
import matplotlib.pyplot as plt
import pylab
# %matplotlib inline

print("Plot not showing up for some reason - axis tick issue?")

plt.plot(x=time_slice, y=imu_a2_slice, color="black", linewidth=2, markersize=12)
#plt.xticks=(np.arange(1050000, 1300000, step=50000))
plt.xlabel('Time Elapsed [ms]')
plt.ylabel('IMU A2')

plt.show();

# %% [markdown]
# ### Detrend the data:

# %%
dacc_array = signal.detrend(imu_a2_slice)
f_s = 5.0 #sampling frequency

# %% [markdown]
# ### Filter the data:

# %%
#Copy from: http://localhost:8890/notebooks/BuoyCallibratorData_DoubleIntegralAnalysis.ipynb

# %%
#According to historic CDIP data: 
#http://cdip.ucsd.edu/offline/wavecdf/wnc_browse.php?ARCHIVE/201p1/201p1_historic+waveHs+201811
#Expecting significant wave height between 0.5 and 0.7m 
#Expecting wave period between 7s and 12s
