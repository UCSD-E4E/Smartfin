# %% [markdown]
# # Smartfin Ride API
# The Smartfin Ride API makes it quick and easy to obtain smartfin ride data using a Django REST API.
#
# All ride queries go through the ride endpoint, so all urls should be in the format:
# "[domain name]/ride/"

# %%
# jasmines ride ids
# 14743 - Motion Control July 10th
# 14750 - Magnetometer Control July 11th
# 14814 - Pool Displacement Control July 17th
# 14815 - Compass Orientation (Lying on Charger Side) July 19th
# 14816 - Orientation w Higher Sampling (Lying on Charger Side) July 20th
# 14827 - Pool Displacement Control w Higher Sampling (Jul 23)
# 14888 - First Buoy Calibration Experiment (July 30)
# 15218 - Jasmine's Second Ride Sesh filmed with GoPro (Aug 29) //no footage
# 15629 - Jasmine's First Ride Sesh filmed with VIRB (Oct. 24) //first labelled footage!
# 15669 - Jasmine's Second Ride Sesh filmed with VIRB (Nov. 7) //second labelled footage!
# 15692 - Jasmine's 3rd Ride Sesh filmed with VIRB (Nov. 9) //third labelled footage!
# 15686 - Jasmine's 4th Ride Sesh filmed with VIRB (Nov. 11) //fourth labelled footage!

# %%
base_url_example = f'http://127.0.0.1:8000/ride/'

# %%
rideId = '30000'
field = 'heightSmartfin'
fieldGetSingleExample = f'http://127.0.0.1:8000/ride/field-get/{rideId}/{field}/'

# %% [markdown]
# ## EXAMPLES OF EACH FUNCTION

# %%
# imports
import requests
import pandas as pd
from io import BytesIO

# %% [markdown]
# ## URLs

# %% [markdown]
# 'List all ride ids': '/ride-list/',
#
# 'List all the ride fields': '/ride-fields/'
#
# 'Get single ride': '/ride-get/<str:rideId>/',
#
# 'Get random set of rides': '/many/ride-get/<int:count>/',
#
# 'Filter rides by location': '/location/ride-get/<str:location>/',
#
# 'Filter rides by date': '/date/ride-get/<str:startDate>/<str:endDate>/',
#
# 'Get single ride attribute': 'field-get/<str:rideId>/<str:fields>/',
#
# 'Get attributes of random set of rides': 'random/field-get/<int:count>/<str:fields>/',
#
# 'Get attributes of rides filtered by location': 'location/field-get/<str:location>/<str:fields>/',
#
# 'Get attributes of rides filtered by date': 'date/field-get/<str:startDate>/<str:endDate>/<str:fields>/',
#
# 'Update heights of all rides in database': 'update-heights/',
# 'Get list of active CDIP buoys': 'buoy-list/'

# %%
testing = False # determines what url we are requesting from
domainName = 'http://ec2-54-203-7-235.us-west-2.compute.amazonaws.com'

# %% [markdown]
# ## api info queries

# %% [markdown]
# #### get all the ride ids in the database

# %%
if testing: 
    apiOverview = f'http://127.0.0.1:8000/ride'
else:
    apiOverview = f'{domainName}/ride'

# %%
response = requests.get(apiOverview).json()
response
# Out:
# {'List api endpoints': '/',
#  'List ride fields': '/fields',
#  'Get all rides in db': '/rides',
#  'Get field of all rides in db': '/rides/fields=<str:fields>',
#  'Get single ride': '/rides/rideId=<str:rideId>',
#  'Filter rides by location': '/rides/location=<str:location>',
#  'Filter rides by date': '/rides/startDate=<str:startDate>,endDate=<str:endDate>',
#  'Get single ride attribute': 'rides/rideId=<str:rideId>/fields=<str:fields>',
#  'Get attributes of rides filtered by location': 'rides/location=<str:location>/fields=<str:fields>',
#  'Get attributes of rides filtered by date': 'rides/startDate=<str:startDate>,endDate=<str:endDate>/fields=<str:fields>',
#  'Update heights of all rides in database': 'update-heights',
#  'Get list of active CDIP buoys': 'buoys'}

# %% [markdown]
# #### get list of ride data fields

# %%
if testing:
    rideFields = f'http://127.0.0.1:8000/ride/fields'
else:
    rideFields = f'{domainName}/ride/fields'

# %%
response = requests.get(rideFields).json()
response
# Out:
# {'id of smartfin session': 'rideId',
#  'location (city, county, state) of session': 'loc1, loc2, loc3',
#  'start time of session': 'startTime',
#  'end time of session': 'endTime',
#  'significant wave height calculated by smartfin': 'heightSmartfin',
#  'significant wave height reported by nearest CDIP buoy': 'heightCDIP',
#  'calibrated ocean temperature read by smartfin': 'tempSmartfin',
#  'ocean temperature reported by nearest CDIP buoy': 'tempCDIP',
#  'nearest CDIP buoy to smartfin session': 'buoyCDIP',
#  'latitude of smartfin session': 'latitude',
#  'longitude of smartfin session': 'longitude'}

# %% [markdown]
# ## get ride data

# %% [markdown]
# #### get all rides in db

# %%
if testing:
    rideList = f'http://127.0.0.1:8000/ride/rides'
else:
    rideList = f'{domainName}/ride/rides'

response = requests.get(rideList).json()
response
# Out:
# {'packrat_source_id:Sfin-1a0027001047373333353132-200507-185842': ['aea80be2-f842-529b-8f5d-2f4fb7dc7109'],
#  'packrat_source_id:Sfin-3f0022001847363439353035-200908-203906': ['3813e432-1c49-503c-9a17-49c7220f80fe'],
#  'packrat_source_id:Sfin-3f0022001847363439353035-200827-194533': ['33b9d6e3-7665-58ed-9777-043c7d93e46a'],
#  'packrat_source_id:Sfin-3f0022001847363439353035-191118-171356': ['c480965d-1283-5e4d-9090-a0f8aa144055'],
#  'packrat_source_id:Sfin-33002a001847363439353035-190613-201653': ['e2792918-b2e9-55b7-b7e7-ee07b616bbe8'],
#  'packrat_source_id:Sfin-3f0022001847363439353035-200827-192545': ['4d73eb86-aed2-566f-8a6d-0d4b9b371b71'],
#  'packrat_source_id:Sfin-3f0022001847363439353035-200806-165127': ['9a24cec3-059b-5727-bc64-7d4a8a4155df'],
#  'packrat_source_id:Sfin-3f0022001847363439353035-201005-144429': ['b8e29c73-bc0b-5a16-a1a3-d6fc904818e2'],
#  'packrat_source_id:Sfin-33002a001847363439353035-190712-125339': ['b875ce76-718c-5911-b3e3-927f4d141cb5'],
#  'packrat_source_id:Sfin-3a0025001047373333353132-191005-192511': ['ad870e5d-e0d9-5202-ae14-8cbd14dd7b47'],
#  'packrat_source_id:Sfin-330026001847363439353035-200807-175416': ['15e89130-30d3-5c79-8269-5e2588fe1c40'],
#  'packrat_source_id:Sfin-3a0025001047373333353132-191218-004119': ['b495e4eb-9e48-5b25-969c-7197e61190ee'],
#  'packrat_source_id:Sfin-330026001847363439353035-200724-173316': ['f7443e27-2d36-5333-8f39-27e65396f022'],
#  'packrat_source_id:Sfin-28001c001947373037323234-190124-222856': ['c1c41ebc-da0d-57c8-8125-816afd1df5da'],
#  'packrat_source_id:Sfin-330026001847363439353035-200707-154244': ['a8734ccb-5d94-5b6e-a0e3-54247fb6aa73'],
#  'packrat_source_id:Sfin-33002a001847363439353035-190712-133655': ['5182eaf4-68d5-5b63-b37c-3889e8698039'],
#  'packrat_source_id:Sfin-330026001847363439353035-200714-202651': ['df261260-62f5-5e05-b652-ad9f44f5c239'],
#  'packrat_source_id:Sfin-3f0022001847363439353035-200908-202527': ['ef5d60fe-a183-5e67-8928-088a283b766a'],
#  'packrat_source_id:Sfin-330026001847363439353035-200714-211015': ['90aff95a-61a1-5386-adad-a084da1e2f95'],
#  'packrat_source_id:Sfin-1a0027001047373333353132-190823-132803': ['ffc69f5e-377e-5415-8b5a-a4239a863af1'],
#  'packrat_source_id:Sfin-3f0022001847363439353035-200811-172035': ['b10fcb6b-c21b-52fc-a65e-96ef5e9b06bd'],
#  'packrat_source_id:Sfin-28001c001947373037323234-190118-195006': ['b9de8713-47f2-532e-9fcd-5d3b6f1fc50d'],
#  'packrat_source_id:Sfin-1a0027001047373333353132-200606-161936': ['e59922f4-08ec-5058-8b1e-dae675b1c1fd'],
#  'packrat_source_id:Sfin-28001c001947373037323234-190124-221753': ['99a93c24-0ae8-51ad-99bb-f3d5e7b1800d'],
#  'packrat_source_id:Sfin-1a0027001047373333353132-200822-195043': ['fb0aa5ec-6fe0-5667-924e-bfdc09416e68'],
#  'packrat_source_id:Sfin-330026001847363439353035-200716-202519': ['733db10f-1a79-5adb-9635-8d1cd0e0b7c9'],
#  'packrat_source_id:Sfin-1a0027001047373333353132-201024-190341': ['652cabc2-c3cd-514b-9878-b910c59ba87a'],
#  'packrat_source_id:Sfin-33002a001847363439353035-190615-111619': ['af17e36b-d589-5399-872f-5a0d4dc1fc5b'],
#  'packrat_source_id:Sfin-1a0027001047373333353132-200531-154822': ['b6988652-068e-5e2f-a521-2cebbccd1721'],
#  'packrat_source_id:Sfin-330026001847363439353035-200804-121549': ['d01728b4-3bcf-510a-970f-a204163c384a'],
#  'packrat_source_id:Sfin-330026001847363439353035-200716-210128': ['50a2e00f-3599-5b01-abe8-42dead7b2b47'],
#  'packrat_source_id:Sfin-33002a001847363439353035-190615-131939': ['ed55d694-6651-5450-928c-6e5af93677c5'],
#  'packrat_source_id:Sfin-3f0022001847363439353035-200908-185623': ['6c75dda8-3e90-590b-887f-ab3f3cb0af32'],
#  'packrat_source_id:Sfin-1a0027001047373333353132-201123-135816': ['86a822f0-dd5b-56f6-b8f2-7d4128cee1b9'],
#  'packrat_source_id:Sfin-330026001847363439353035-200716-203209': ['cbcf390e-133d-5a5b-b7cd-ecd3ecfb8ed1'],
#  'packrat_source_id:Sfin-3a0025001047373333353132-190818-171215': ['a54baf0e-8f3d-59e9-a664-0be2b6e127d1'],
#  'packrat_source_id:Sfin-3f0022001847363439353035-201005-152049': ['0d9d5a80-1665-5114-a970-0ad47fb65ae3'],
#  'packrat_source_id:Sfin-330026001847363439353035-200716-215903': ['e6007978-d9eb-5f37-9a3a-ccfd57c9dc81'],
#  'packrat_source_id:Sfin-360045000e47373333353132-190525-143340': ['f585736d-8edd-5c72-993e-85d0b33567b6'],
#  'packrat_source_id:Sfin-330026001847363439353035-200714-201635': ['52519af3-7ba9-5272-99a8-d656ebb77099'],
#  'packrat_source_id:Sfin-1a0027001047373333353132-200802-141455': ['20efff9c-aa19-5273-91b5-aa29c1e34397'],
#  'packrat_source_id:Sfin-3a0025001047373333353132-190816-122856': ['5ffb79ff-bb4c-5348-a96b-b4f65d2e9111'],
#  'packrat_source_id:Sfin-33002a001847363439353035-190615-121045': ['ef928bfd-9424-5603-a60c-c886ba20ada5'],
#  'packrat_source_id:Sfin-330026001847363439353035-200716-213808': ['14c9b7f0-e16b-5c14-b329-9bd7bf4d71da'],
#  'packrat_source_id:Sfin-3f0022001847363439353035-201005-152636': ['10086d74-bd5a-57c2-b2a0-2d8b4bc31e06'],
#  'packrat_source_id:Sfin-3a0025001047373333353132-190813-143245': ['a5198db4-ee2f-5b7f-9f96-6c671823dfae'],
#  'packrat_source_id:Sfin-3f0022001847363439353035-201005-144239': ['2b9216a1-5141-5bb3-b4d9-aa0d5550eb31'],
#  'packrat_source_id:Sfin-3f0022001847363439353035-200827-203059': ['c8ab6fff-4b66-5369-bce4-e9fe6818dade'],
#  'packrat_source_id:Sfin-330026001847363439353035-200716-221256': ['1b7f35fc-21c5-5261-ab73-8d7b250f7a54'],
#  'packrat_source_id:Sfin-3f0022001847363439353035-200827-204220': ['e7ef7ec1-66ae-5a50-a0c5-69325f13b2b2'],
#  'packrat_source_id:Sfin-3a0025001047373333353132-200122-004857': ['757ada76-3937-5ea9-8f51-6620766ff9d8'],
#  'packrat_source_id:Sfin-360045000e47373333353132-190515-161259': ['cfd5659e-5612-5bf1-9fcb-40307d3dae34'],
#  'packrat_source_id:Sfin-33002a001847363439353035-190618-044507': ['ea426835-44a6-53a0-8c44-d46bdd8a10af'],
#  'packrat_source_id:Sfin-3f0022001847363439353035-200908-184804': ['d660b37e-fb59-5322-9c6d-7f14f5c141c4'],
#  'packrat_source_id:Sfin-3f0022001847363439353035-191118-170431': ['ea22366c-d698-53ba-9fd1-99a31e7bedde'],
#  'packrat_source_id:Sfin-1a0027001047373333353132-200516-174706': ['a907c7a5-ba1b-5efb-a32c-c3fbc12f9a2b'],
#  'packrat_source_id:Sfin-3f0022001847363439353035-200908-173311': ['566d8c91-0926-549b-875b-a9d773aa49b6'],
#  'packrat_source_id:Sfin-330026001847363439353035-200722-201002': ['f67e6e0f-e72c-56f5-981e-01b0a14c69fc'],
#  'packrat_source_id:Sfin-330026001847363439353035-200807-153603': ['c528e449-57e0-522e-ba95-5cc77440cf11'],
#  'packrat_source_id:Sfin-3f0022001847363439353035-200811-171538': ['c1db7783-e4f5-53ea-a5e7-05a7b683e66c'],
#  'packrat_source_id:Sfin-1a0027001047373333353132-190329-194128': ['b40a158a-656b-5bef-a73a-017bff24dacd'],
#  'packrat_source_id:Sfin-330026001847363439353035-200716-205652': ['3a8725f6-8de1-59af-afcf-75103fd3abc3'],
#  'packrat_source_id:Sfin-330026001847363439353035-200722-202008': ['09722544-524c-5914-9527-a5f82e2678fb'],
#  'packrat_source_id:Sfin-3f0022001847363439353035-191118-171529': ['f964ad5a-89df-5c49-96cb-5a5bacff21d0'],
#  'packrat_source_id:Sfin-3f0022001847363439353035-200908-175437': ['856d7955-6a3d-5e11-ac7d-77592be88c56'],
#  'packrat_source_id:Sfin-28001c001947373037323234-181014-135230': ['e0082382-d872-5fa6-a2e9-f7319cc3300d'],
#  'packrat_source_id:Sfin-3f0022001847363439353035-201005-151907': ['3921deeb-5421-5dc2-88f1-b4c98c854191'],
#  'packrat_source_id:Sfin-330026001847363439353035-200714-212254': ['bc718cb8-379e-5d10-8af4-8828bc6d6161'],
#  'packrat_source_id:Sfin-33002a001847363439353035-190702-142823': ['4d9145dc-eded-55f5-9408-32424f0a78f9'],
#  'packrat_source_id:Sfin-3f0022001847363439353035-200827-191530': ['d4cd90f3-c5fe-5816-8860-9fa90cd17a76'],
#  'packrat_source_id:Sfin-3f0022001847363439353035-200827-202042': ['5338ac37-097e-5c81-a3d8-162496302393'],
#  'packrat_source_id:Sfin-3f0022001847363439353035-200831-144054': ['6e4e1f8b-6b7a-556e-ae9f-21d380ba824d'],
#  'packrat_source_id:Sfin-330026001847363439353035-200716-205814': ['ccbfd03f-4d7c-55ef-852b-cede1bdc92e7'],
#  'packrat_source_id:Sfin-1a0027001047373333353132-200926-202820': ['aa96c464-fcaf-5525-8b9f-9442ff2bde4b'],
#  'packrat_source_id:Sfin-3f0022001847363439353035-200908-184435': ['8a5d454a-db4b-5344-9649-369bcc2b3e2d'],
#  'packrat_source_id:Sfin-3f0022001847363439353035-200831-140507': ['632f23c3-e81e-5a95-b225-2d698bb9131c'],
#  'packrat_source_id:Sfin-1a0027001047373333353132-200822-205158': ['f3ad16fd-5c17-5bcf-83c9-0f8c26ed4099'],
#  'packrat_source_id:Sfin-330026001847363439353035-200716-214615': ['47ccea75-30c5-5cb5-8de9-38901624af62'],
#  'packrat_source_id:Sfin-3f0022001847363439353035-201005-144908': ['b5782240-2021-5043-b04f-0bcaa18d74f9'],
#  'packrat_source_id:Sfin-3f001f001847363439353035-181220-161126': ['2e117b76-36e5-5d7e-b9d3-473b83172c00'],
#  'packrat_source_id:Sfin-28001c001947373037323234-190118-175331': ['3cb200a4-5238-5026-9205-a31139da76e5'],
#  'packrat_source_id:Sfin-3a0025001047373333353132-190828-194437': ['8f755476-3036-5b52-a9d9-5d230528617d'],
#  'packrat_source_id:Sfin-360045000e47373333353132-190525-160533': ['2ae1f5e5-6f62-5fa2-bb9b-d246ca8acbf7'],
#  'packrat_source_id:Sfin-330026001847363439353035-200707-150035': ['010ba75d-9459-51b8-93ed-658bc7258e4c'],
#  'packrat_source_id:Sfin-28001c001947373037323234-181025-010339': ['213d0feb-6fa6-52b7-883c-5fc9c625c7db'],
#  'packrat_source_id:Sfin-1a0027001047373333353132-190813-142523': ['29b1ab12-f2c9-550e-83c1-355182c87d2e'],
#  'packrat_source_id:Sfin-1a0027001047373333353132-201122-160734': ['c9602d9c-e6a6-505c-bad4-b3982d0d56a8'],
#  'packrat_source_id:Sfin-330026001847363439353035-200714-195433': ['030013c8-03df-553f-892a-811fb6f2745f'],
#  'packrat_source_id:Sfin-1a0027001047373333353132-190329-200120': ['7abce46f-a5a2-5f68-9c01-050faaccd161'],
#  'packrat_source_id:Sfin-20002e001347373333353132-190219-205607': ['71ac188b-2843-5a53-a4fc-dd67c6527fa7'],
#  'packrat_source_id:Sfin-1a0027001047373333353132-200527-012935': ['a9f0b8a6-b6c6-518c-be85-fba739d3d4e9'],
#  'packrat_source_id:Sfin-1a0027001047373333353132-191118-170437': ['3612f8aa-11a5-5469-867b-48fc12322e13'],
#  'packrat_source_id:Sfin-3f0022001847363439353035-200908-182928': ['2d367387-4f19-51dd-be6e-59d86f8b4000'],
#  'packrat_source_id:Sfin-3f0022001847363439353035-200908-204044': ['868d42e9-208f-555f-b7cc-733f83668433'],
#  'packrat_source_id:Sfin-330026001847363439353035-200716-211058': ['faad5aee-6d2f-52d7-99eb-0eeebf91b398'],
#  'packrat_source_id:Sfin-28001c001947373037323234-181012-213044': ['b09c74ac-74b0-50d1-96a0-afe621f7a45c'],
#  'packrat_source_id:Sfin-28001c001947373037323234-181218-155852': ['48f2c03d-bb15-51bc-a27e-f5d2968031a6'],
#  'packrat_source_id:Sfin-1a0027001047373333353132-191118-171847': ['7bfd82c9-6841-5554-a9cb-f8cbde042bf2'],
#  'packrat_source_id:Sfin-3a0025001047373333353132-190815-210212': ['216cf7eb-125d-5ceb-9c40-d7fcbcac1e6e'],
#  'packrat_source_id:Sfin-3f0022001847363439353035-201005-150714': ['0e546762-c855-539b-b70b-8d162878a58d'],
#  'packrat_source_id:Sfin-33002a001847363439353035-190611-041444': ['bce80857-83ce-5cb1-a634-95712635b775'],
#  'packrat_source_id:Sfin-1a0027001047373333353132-200906-152755': ['a9b2449a-38bd-5bba-bf43-21492418f944'],
#  'packrat_source_id:Sfin-330026001847363439353035-200716-202216': ['7e97673e-8b97-5d48-855a-df520bc7a2f6'],
#  'packrat_source_id:Sfin-330026001847363439353035-200716-201120': ['a6654eb8-e268-5a44-bd10-80012b99627a'],
#  'packrat_source_id:Sfin-330026001847363439353035-200714-212645': ['3e32fb57-e9ec-55d6-bc36-675826452fa0'],
#  'packrat_source_id:Sfin-28001c001947373037323234-181025-154609': ['a6813604-13e0-512c-978d-857bab55beb5'],
#  'packrat_source_id:Sfin-3f0022001847363439353035-200809-150218': ['825c2593-b407-5791-8ad9-053e7a695454'],
#  'packrat_source_id:Sfin-3a0025001047373333353132-191005-185734': ['f376c89a-663d-56ee-83f7-454ea04e604e'],
#  'packrat_source_id:Sfin-3f0022001847363439353035-200908-204524': ['02c5a517-6ac1-5003-a57f-c3e4215b8880'],
#  'packrat_source_id:Sfin-1a0027001047373333353132-191118-171626': ['7bbd88ca-7f68-56ee-9125-3e9aec5a280a'],
#  'packrat_source_id:Sfin-28001c001947373037323234-190118-195659': ['438bf44e-c759-57bc-9752-feb12ff3499f'],
#  'packrat_source_id:Sfin-3f0022001847363439353035-200911-183520': ['245c829e-855c-5265-ac1b-e4ec7cd35e74'],
#  'packrat_source_id:Sfin-330026001847363439353035-200714-213221': ['8272e634-668d-5e7c-8f15-4e37bc3ee4cb'],
#  'packrat_source_id:Sfin-3f0022001847363439353035-200917-122917': ['41c408e4-9ef8-5c34-a4a3-f7693badb5e5'],
#  'packrat_source_id:Sfin-3f0022001847363439353035-200908-174707': ['b3fcb3b7-f172-58f0-842f-3be30579d3ba'],
#  'packrat_source_id:Sfin-1a0027001047373333353132-201205-174519': ['6995c985-e824-5bf3-8cb8-21e7119c439b'],
#  'packrat_source_id:Sfin-3f0022001847363439353035-200827-193259': ['f6ee726e-1fe5-5ea2-9185-f966684052a0'],
#  'packrat_source_id:Sfin-33002a001847363439353035-190615-121324': ['0e2dae40-0deb-581e-b2c4-2ee6ea44052b'],
#  'packrat_source_id:Sfin-3f0022001847363439353035-191118-171632': ['370e9527-acc0-59a1-b9d3-4e42a8ac9a3d'],
#  'packrat_source_id:Sfin-330026001847363439353035-200707-151120': ['723542b8-23fc-5136-9c2a-24ffcdb32a97'],
#  'packrat_source_id:Sfin-1a0027001047373333353132-200527-211638': ['4b2ee4bf-8716-5c05-adf3-c154bccbd32f'],
#  'packrat_source_id:Sfin-330026001847363439353035-200714-200816': ['f7b5029a-6097-5c27-9c35-03cdf079c866'],
#  'packrat_source_id:Sfin-330026001847363439353035-200716-215144': ['8dc97260-410e-5a57-8737-d0765ab72f50'],
#  'packrat_source_id:Sfin-1a0027001047373333353132-191118-171339': ['23097186-63ac-5615-8c69-71b9fcf0e299'],
#  'packrat_source_id:Sfin-330026001847363439353035-200716-202846': ['ba51b883-b600-5483-a254-47360a1b02ce'],
#  'packrat_source_id:Sfin-1a0027001047373333353132-200613-203155': ['e6eb14b7-19da-5cac-9d44-259781f76dcc'],
#  'packrat_source_id:Sfin-1a0027001047373333353132-200621-154552': ['05f19f41-bff0-5f0e-b4da-6b4e112bb300'],
#  'packrat_source_id:Sfin-3f0022001847363439353035-200827-210427': ['96917f92-1c04-5c3b-9434-47653004280c'],
#  'packrat_source_id:Sfin-3f0022001847363439353035-201005-143351': ['6c5e8e05-c394-5165-b12d-6df168d43ccf'],
#  'packrat_source_id:Sfin-3f0022001847363439353035-201005-132937': ['f880c3e3-3017-5bfc-aa80-42b81b641fc4'],
#  'packrat_source_id:Sfin-330026001847363439353035-200716-212606': ['ecf02c77-8abb-5e8a-88b2-d0841e62ac9c'],
#  'packrat_source_id:Sfin-3f0022001847363439353035-200827-195618': ['3f9b5bf3-241c-59c7-a762-7c715c1f876d'],
#  'packrat_source_id:Sfin-3f0022001847363439353035-200827-192313': ['e1eb400c-5f86-576f-b94f-6783b37d4bdb'],
#  'packrat_source_id:Sfin-330026001847363439353035-200707-144704': ['fa5f283e-ceca-5449-b25f-cc18b8634fd1'],
#  'packrat_source_id:Sfin-330026001847363439353035-200716-211528': ['fb4a18a2-85a5-5fd0-9835-4ba1521be89d'],
#  'packrat_source_id:Sfin-330026001847363439353035-200716-203553': ['581a9850-da41-5b3c-8b23-0011f8836228'],
#  'packrat_source_id:Sfin-33002a001847363439353035-190613-202618': ['a2566875-0171-54b6-8322-3b9168ef7dfb'],
#  'packrat_source_id:Sfin-1a0027001047373333353132-190809-131734': ['6f3608db-fde3-5bb5-bf8d-1cd47eeb0628'],
#  'packrat_source_id:Sfin-3f0022001847363439353035-200827-193858': ['6c036628-eebb-5d8d-8fe6-4b5cbfcc16b8'],
#  'packrat_source_id:Sfin-330026001847363439353035-200716-211741': ['5199b8a0-117b-5da0-b69f-2a62b32c926e'],
#  'packrat_source_id:Sfin-1a0027001047373333353132-201128-122039': ['624ede2f-ff80-51e1-ac4b-394182fb00c4'],
#  'packrat_source_id:Sfin-330026001847363439353035-200716-220033': ['fe00e87f-c9ee-54cb-b57b-c76af1dadec6'],
#  'packrat_source_id:Sfin-330026001847363439353035-200707-163647': ['e5e3cdfd-3a3e-5a2d-9619-beb2797cf9e4'],
#  'packrat_source_id:Sfin-3f0022001847363439353035-200827-191314': ['674fc95a-b447-5931-af4e-1f00d30f71bc'],
#  'packrat_source_id:Sfin-3f0022001847363439353035-200827-192149': ['ce3aca9a-c086-5a01-be50-da3282d35abc'],
#  'packrat_source_id:Sfin-28001c001947373037323234-181115-154035': ['934ca48b-3b14-51e9-8e0c-d86b2435090f'],
#  'packrat_source_id:Sfin-330026001847363439353035-200716-205950': ['b7a6af3a-de04-583e-87ba-66421af38901'],
#  'packrat_source_id:Sfin-330026001847363439353035-200724-170630': ['79a9f384-2e4e-536d-ade4-5fbb4ebfacac'],
#  'packrat_source_id:Sfin-33002a001847363439353035-190712-133314': ['a7a827e2-6e2a-592a-a258-1ccc92f400ee'],
#  'packrat_source_id:Sfin-330026001847363439353035-200807-140517': ['27cab690-c226-50f5-aed6-8f3177e73873'],
#  'packrat_source_id:Sfin-33002a001847363439353035-190613-201205': ['ddb8cac9-fd24-50cb-9478-2a6232ef634c'],
#  'packrat_source_id:Sfin-330026001847363439353035-200707-144045': ['6945a0f4-8d05-5035-a3af-bc09bad96f05'],
#  'packrat_source_id:Sfin-1a0027001047373333353132-201219-163609': ['cebf1ce2-5eba-5f57-9e32-d3bdf079c4b0'],
#  'packrat_source_id:Sfin-330026001847363439353035-200716-213435': ['fa0ef0fc-a8e3-508a-982d-e91bb4d20d0a'],
#  'packrat_source_id:Sfin-3f001f001847363439353035-181219-182710': ['d043cbc2-a808-5bf1-99ee-ea9f7f619c90'],
#  'packrat_source_id:Sfin-3a0025001047373333353132-191118-170430': ['850a1a8b-c7b9-5d96-b69f-1057ea24e297'],
#  'packrat_source_id:Sfin-330026001847363439353035-200716-222409': ['7185db36-1810-5ae8-aca5-50787c6bceee'],
#  'packrat_source_id:Sfin-3f0022001847363439353035-200908-185838': ['ab099839-b139-58e4-b9c6-a1a21a7a1c1a'],
#  'packrat_source_id:Sfin-1a0027001047373333353132-201228-174643': ['1d826ddd-ea08-5747-97c6-cea81536c021'],
#  'packrat_source_id:Sfin-3f0022001847363439353035-200908-185408': ['1bd1836c-fd30-54b2-aaa1-9c13984b2ee1'],
#  'packrat_source_id:Sfin-3a0025001047373333353132-191220-004805': ['8620e391-413e-5840-991a-8ee6f21c6f66'],
#  'packrat_source_id:Sfin-330026001847363439353035-200716-200842': ['773a70c9-c370-5cde-ac88-d6356bb275ce'],
#  'packrat_source_id:Sfin-28001c001947373037323234-181021-142945': ['9789d133-93e8-5e1e-81ac-49afbf72189c'],
#  'packrat_source_id:Sfin-1a0027001047373333353132-201125-183824': ['cc92411d-97fe-5c88-95ec-fe0da6a50b6d'],
#  'packrat_source_id:Sfin-330026001847363439353035-200716-215304': ['d4fa9a01-571a-5596-b321-aa1aeaadf986'],
#  'packrat_source_id:Sfin-330026001847363439353035-200714-201952': ['f12d93ee-b418-556f-b622-01dfd0512a08'],
#  'packrat_source_id:Sfin-33002a001847363439353035-190611-050835': ['fe1b9976-59f8-5ea2-bfa8-0b83d37a18b3'],
#  'packrat_source_id:Sfin-33002a001847363439353035-190615-155259': ['9ed508e1-90fa-5b4e-8ea4-f788affdd272'],
#  'packrat_source_id:Sfin-28001c001947373037323234-181010-184714': ['c79ae548-4e04-5aae-818a-1ba1c0273575'],
#  'packrat_source_id:Sfin-330026001847363439353035-200306-154437': ['077f4fa7-8fe5-58b1-875a-398a27a6fc0d'],
#  'packrat_source_id:Sfin-1a0027001047373333353132-201122-171052': ['64d1f72b-8b3c-56be-892f-6eb9595de802'],
#  'packrat_source_id:Sfin-3f0022001847363439353035-200922-210259': ['ddd7e930-ab09-58a2-925b-7d1dc7468f11']}

# %% [markdown]
# #### get fields of all rides in db

# %%
if testing:
    rideList = f'http://127.0.0.1:8000/ride/rides/fields=heightSmartfin,tempSmartfin'
else:
    rideList = f'{domainName}/ride/rides/fields=heightSmartfin,tempSmartfin'

response = requests.get(rideList).json()
response
# Out:
# {'data': [{'rideId': '13000',
#    'heightSmartfin': 0.9584823352947973,
#    'tempSmartfin': 24.13346904024768},
#   {'rideId': '16000',
#    'heightSmartfin': 0.40845185873427914,
#    'tempSmartfin': 17.172475763016156},
#   {'rideId': '16376',
#    'heightSmartfin': 0.9460319998263358,
#    'tempSmartfin': 17.275294392523367},
#   {'rideId': '16345',
#    'heightSmartfin': 0.3808737691417218,
#    'tempSmartfin': 16.602045454545454},
#   {'rideId': '16318',
#    'heightSmartfin': 0.5428762299265988,
#    'tempSmartfin': 19.160367231638414},
#   {'rideId': '16302',
#    'heightSmartfin': 0.6718289115566997,
#    'tempSmartfin': 19.758730240549824},
#   {'rideId': '16301',
#    'heightSmartfin': 0.4013681093396742,
#    'tempSmartfin': 19.13324066390042},
#   {'rideId': '16300',
#    'heightSmartfin': 0.49562878481694916,
#    'tempSmartfin': 19.056392947103276},
#   {'rideId': '16299',
#    'heightSmartfin': 0.43162395826775946,
#    'tempSmartfin': 19.359534626038784},
#   {'rideId': '16298',
#    'heightSmartfin': 0.6791315978701143,
#    'tempSmartfin': 17.93609531772575},
#   {'rideId': '16297',
#    'heightSmartfin': 0.43871618389742056,
#    'tempSmartfin': 20.342345646437995},
#   {'rideId': '16290',
#    'heightSmartfin': 1.3446089018207055,
#    'tempSmartfin': 20.6526261682243},
#   {'rideId': '16289',
#    'heightSmartfin': 0.6124114661985623,
#    'tempSmartfin': 21.28510817307692},
#   {'rideId': '16278',
#    'heightSmartfin': 13.402122248843234,
#    'tempSmartfin': 21.42676334106729},
#   {'rideId': '16262',
#    'heightSmartfin': 0.5257326257318952,
#    'tempSmartfin': 21.07598},
#   {'rideId': '16253',
#    'heightSmartfin': 0.7603094257000951,
#    'tempSmartfin': 20.56265},
#   {'rideId': '16252',
#    'heightSmartfin': 0.5244763530689744,
#    'tempSmartfin': 21.78315335753176},
#   {'rideId': '16250',
#    'heightSmartfin': 0.5308156496001618,
#    'tempSmartfin': 23.673319786096258},
#   {'rideId': '16249',
#    'heightSmartfin': 0.3141288025546928,
#    'tempSmartfin': 25.567789612676055},
#   {'rideId': '16243',
#    'heightSmartfin': 0.6210725285853507,
#    'tempSmartfin': 23.82446410684474},
#   {'rideId': '16239',
#    'heightSmartfin': 0.6949528728123969,
#    'tempSmartfin': 26.088663551401872},
#   {'rideId': '16238',
#    'heightSmartfin': 0.3230272591645206,
#    'tempSmartfin': 25.742544568245126},
#   {'rideId': '16237',
#    'heightSmartfin': 0.30515738118656105,
#    'tempSmartfin': 25.798082524271845},
#   {'rideId': '16225',
#    'heightSmartfin': 0.5617861937189434,
#    'tempSmartfin': 21.660911729141475},
#   {'rideId': '16222',
#    'heightSmartfin': 0.4888846897250368,
#    'tempSmartfin': 21.986965897693075},
#   {'rideId': '16221',
#    'heightSmartfin': 0.46394038356167805,
#    'tempSmartfin': 22.036060810810817},
#   {'rideId': '16212',
#    'heightSmartfin': 0.4103094581106867,
#    'tempSmartfin': 20.533486486486485},
#   {'rideId': '16211',
#    'heightSmartfin': 0.5039792322452558,
#    'tempSmartfin': 20.964627408993575},
#   {'rideId': '16197',
#    'heightSmartfin': 0.8283634273375001,
#    'tempSmartfin': 22.022547263681588},
#   {'rideId': '16196',
#    'heightSmartfin': 5.443058418243037,
#    'tempSmartfin': 23.12582252559727},
#   {'rideId': '16195',
#    'heightSmartfin': 0.4343562987458954,
#    'tempSmartfin': 23.029375},
#   {'rideId': '16192',
#    'heightSmartfin': 0.5017183758555545,
#    'tempSmartfin': 23.37277222222222},
#   {'rideId': '16191',
#    'heightSmartfin': 0.642197994479234,
#    'tempSmartfin': 22.986109090909093},
#   {'rideId': '16189',
#    'heightSmartfin': 0.37585717800720597,
#    'tempSmartfin': 23.140972273567467},
#   {'rideId': '16178',
#    'heightSmartfin': 0.4704977184591453,
#    'tempSmartfin': 18.86951451187335},
#   {'rideId': '16177',
#    'heightSmartfin': 0.621566826362141,
#    'tempSmartfin': 21.213252077562327},
#   {'rideId': '16175',
#    'heightSmartfin': 0.5714897617186816,
#    'tempSmartfin': 20.65331929480901},
#   {'rideId': '16173',
#    'heightSmartfin': 0.49568249578993706,
#    'tempSmartfin': 21.150633517495397},
#   {'rideId': '16171',
#    'heightSmartfin': 0.5522366718274178,
#    'tempSmartfin': 20.26179865771812},
#   {'rideId': '16169',
#    'heightSmartfin': 0.4204739961160755,
#    'tempSmartfin': 19.33209245283019},
#   {'rideId': '16168',
#    'heightSmartfin': 0.528580888368911,
#    'tempSmartfin': 18.534223706176963},
#   {'rideId': '16167',
#    'heightSmartfin': 0.5220379380877774,
#    'tempSmartfin': 22.757891089108906},
#   {'rideId': '16161',
#    'heightSmartfin': 0.5280891441323716,
#    'tempSmartfin': 22.547958471760797},
#   {'rideId': '16160',
#    'heightSmartfin': 0.6445993393206252,
#    'tempSmartfin': 19.8430507859734},
#   {'rideId': '16158',
#    'heightSmartfin': 0.6227975974022982,
#    'tempSmartfin': 18.79893243243243},
#   {'rideId': '16152',
#    'heightSmartfin': 0.6099946371209849,
#    'tempSmartfin': 16.164471215351814},
#   {'rideId': '16148',
#    'heightSmartfin': 0.7370040122823286,
#    'tempSmartfin': 17.222762214983714},
#   {'rideId': '16140',
#    'heightSmartfin': 0.36072965927671047,
#    'tempSmartfin': 19.85794616419919},
#   {'rideId': '16137',
#    'heightSmartfin': 0.2833940627684416,
#    'tempSmartfin': 18.939855392156865},
#   {'rideId': '16135',
#    'heightSmartfin': 0.3968926971374553,
#    'tempSmartfin': 19.571597727272728},
#   {'rideId': '16134',
#    'heightSmartfin': 0.3515648229045688,
#    'tempSmartfin': 19.904956435643566},
#   {'rideId': '16128',
#    'heightSmartfin': 0.6307692597542487,
#    'tempSmartfin': 20.751139204545453},
#   {'rideId': '16126',
#    'heightSmartfin': 0.5532440526363992,
#    'tempSmartfin': 20.460031837916066},
#   {'rideId': '16115',
#    'heightSmartfin': 0.7739041667096287,
#    'tempSmartfin': 17.57927047146402},
#   {'rideId': '16106',
#    'heightSmartfin': 0.8666619215905952,
#    'tempSmartfin': 18.0425},
#   {'rideId': '16103',
#    'heightSmartfin': 0.9466108802237144,
#    'tempSmartfin': 17.682581257413997},
#   {'rideId': '16101',
#    'heightSmartfin': 0.3748512059225787,
#    'tempSmartfin': 18.607677667766776},
#   {'rideId': '16100',
#    'heightSmartfin': 0.5798144840241994,
#    'tempSmartfin': 16.84068209255533},
#   {'rideId': '16099',
#    'heightSmartfin': 5.86383570724265,
#    'tempSmartfin': 18.571798095238094},
#   {'rideId': '16098',
#    'heightSmartfin': 0.6585840842332937,
#    'tempSmartfin': 18.527776286353465},
#   {'rideId': '16088',
#    'heightSmartfin': 0.7021443095937877,
#    'tempSmartfin': 18.33839882697947},
#   {'rideId': '16081',
#    'heightSmartfin': 0.5629105544765778,
#    'tempSmartfin': 18.71829341317365},
#   {'rideId': '16079',
#    'heightSmartfin': 0.5343034566572307,
#    'tempSmartfin': 18.3360584918957},
#   {'rideId': '16076',
#    'heightSmartfin': 0.5321975203481288,
#    'tempSmartfin': 19.275597765363127},
#   {'rideId': '16075',
#    'heightSmartfin': 0.625128594193755,
#    'tempSmartfin': 19.27739926062847},
#   {'rideId': '16073',
#    'heightSmartfin': 0.5526880437476933,
#    'tempSmartfin': 18.892421157684634},
#   {'rideId': '16072',
#    'heightSmartfin': 0.42121212508304046,
#    'tempSmartfin': 19.21462909090909},
#   {'rideId': '15996',
#    'heightSmartfin': 0.5384636597695007,
#    'tempSmartfin': 15.83214629258517},
#   {'rideId': '15983',
#    'heightSmartfin': 0.6335982351252639,
#    'tempSmartfin': 16.803871264367814},
#   {'rideId': '15980',
#    'heightSmartfin': 1.3126418245845508,
#    'tempSmartfin': 15.413704805491992},
#   {'rideId': '15978',
#    'heightSmartfin': 0.4958321926134144,
#    'tempSmartfin': 15.80256952380952},
#   {'rideId': '15972',
#    'heightSmartfin': 0.6531221269397142,
#    'tempSmartfin': 14.210163999999999},
#   {'rideId': '15963',
#    'heightSmartfin': 0.8751134002551536,
#    'tempSmartfin': 15.065393258426967},
#   {'rideId': '15962',
#    'heightSmartfin': 0.46403378477939916,
#    'tempSmartfin': 15.612076023391813},
#   {'rideId': '15953',
#    'heightSmartfin': 0.7336012494335505,
#    'tempSmartfin': 16.578817438692095},
#   {'rideId': '15945',
#    'heightSmartfin': 0.4130687409449136,
#    'tempSmartfin': 15.729092307692307},
#   {'rideId': '15859',
#    'heightSmartfin': 0.7219074882063148,
#    'tempSmartfin': 15.12332394366197},
#   {'rideId': '15858',
#    'heightSmartfin': 0.6456327123294124,
#    'tempSmartfin': 15.260178041543025},
#   {'rideId': '15857',
#    'heightSmartfin': 0.4667968559896883,
#    'tempSmartfin': 15.337380232558141},
#   {'rideId': '15856',
#    'heightSmartfin': 0.33065953780985163,
#    'tempSmartfin': 15.171859649122807},
#   {'rideId': '15854',
#    'heightSmartfin': 0.5808067594807285,
#    'tempSmartfin': 15.583867216117214},
#   {'rideId': '15848',
#    'heightSmartfin': 0.5286699403101088,
#    'tempSmartfin': 15.232898047722344},
#   {'rideId': '16380',
#    'heightSmartfin': 0.5548853024235092,
#    'tempSmartfin': 17.33151226158038},
#   {'rideId': '15692',
#    'heightSmartfin': 0.45559016163497096,
#    'tempSmartfin': 20.044069023569023},
#   {'rideId': 'Sfin-33002a001847363439353035-190712-133655',
#    'heightSmartfin': 0.11838336873968074,
#    'tempSmartfin': 19.404572147651006},
#   {'rideId': 'Sfin-33002a001847363439353035-190611-050835',
#    'heightSmartfin': 0.3059217567528088,
#    'tempSmartfin': 15.187985248447205},
#   {'rideId': 'Sfin-1a0027001047373333353132-190823-132803',
#    'heightSmartfin': 0.281283425601486,
#    'tempSmartfin': 19.139231209982537},
#   {'rideId': 'Sfin-33002a001847363439353035-190613-202618',
#    'heightSmartfin': 0.14820025140417228,
#    'tempSmartfin': 14.401965725806452},
#   {'rideId': 'Sfin-3a0025001047373333353132-190818-171215',
#    'heightSmartfin': 0.028016691875265096,
#    'tempSmartfin': -33.36292467398765},
#   {'rideId': 'Sfin-33002a001847363439353035-190712-125339',
#    'heightSmartfin': 0.18665585174876706,
#    'tempSmartfin': 19.583834909716252}]}

# %% [markdown]
# ### get single ride by id

# %%
rideId = 'Sfin-3a0025001047373333353132-190818-171215'
testing = False
if testing:
    rideGetSingle = f'http://127.0.0.1:8000/ride/rides/rideId={rideId}' # creates new ride and upload all ride data to db
else:
    rideGetSingle = f'{domainName}/ride/rides/rideId={rideId}' # creates new ride and upload all ride data to db

response = requests.get(rideGetSingle).json()
response
# Out:
# {'rideId': 'Sfin-3a0025001047373333353132-190818-171215',
#  'loc1': 'Ocean City',
#  'loc2': 'Cape May County',
#  'loc3': 'New Jersey',
#  'startTime': 1566148335,
#  'endTime': 1566151475,
#  'heightSmartfin': 0.028016691875265096,
#  'tempSmartfin': -33.36292467398765,
#  'buoyCDIP': '209',
#  'heightCDIP': 0.9350000023841858,
#  'tempCDIP': 25.575000762939453,
#  'latitude': 39.287038811188815,
#  'longitude': -74.55268051748251}

# %%
location = 'San Diego'

if testing:
    rideGetLocation = f'http://127.0.0.1:8000/ride/rides/location={location}' # creates new ride and upload all ride data to db
else:
    rideGetLocation = f'{domainName}/ride/rides/location={location}' # creates new ride and upload all ride data to db

response = requests.get(rideGetLocation).json()
response
# Out:
# [{'rideId': '16000',
#   'loc1': 'La Jolla',
#   'loc2': 'San Diego',
#   'loc3': 'San Diego County',
#   'startTime': 1552778033,
#   'endTime': 1552781386,
#   'heightSmartfin': 0.40845185873427914,
#   'tempSmartfin': 17.172475763016156,
#   'buoyCDIP': '201',
#   'heightCDIP': 0.45499998331069946,
#   'tempCDIP': 16.7945499420166,
#   'latitude': 32.85231859863946,
#   'longitude': -117.26381327891156},
#  {'rideId': '16345',
#   'loc1': 'La Jolla',
#   'loc2': 'San Diego',
#   'loc3': 'San Diego County',
#   'startTime': 1574176028,
#   'endTime': 1574178412,
#   'heightSmartfin': 0.3808737691417218,
#   'tempSmartfin': 16.602045454545454,
#   'buoyCDIP': '201',
#   'heightCDIP': 0.5349999666213989,
#   'tempCDIP': 17.081256866455078,
#   'latitude': 32.85233376451078,
#   'longitude': -117.26432490878938},
#  {'rideId': '16318',
#   'loc1': 'La Jolla',
#   'loc2': 'San Diego',
#   'loc3': 'San Diego County',
#   'startTime': 1573332063,
#   'endTime': 1573335260,
#   'heightSmartfin': 0.5428762299265988,
#   'tempSmartfin': 19.160367231638414,
#   'buoyCDIP': '201',
#   'heightCDIP': 0.6299999952316284,
#   'tempCDIP': 18.839092254638672,
#   'latitude': 32.85414126618705,
#   'longitude': -117.26592332374102},
#  {'rideId': '16302',
#   'loc1': 'La Jolla',
#   'loc2': 'San Diego',
#   'loc3': 'San Diego County',
#   'startTime': 1572116946,
#   'endTime': 1572120450,
#   'heightSmartfin': 0.6718289115566997,
#   'tempSmartfin': 19.758730240549824,
#   'buoyCDIP': '201',
#   'heightCDIP': 0.39499998092651367,
#   'tempCDIP': 19.683643341064453,
#   'latitude': 32.85993588043478,
#   'longitude': -117.25840547826087},
#  {'rideId': '16301',
#   'loc1': 'La Jolla',
#   'loc2': 'San Diego',
#   'loc3': 'San Diego County',
#   'startTime': 1572031150,
#   'endTime': 1572034052,
#   'heightSmartfin': 0.4013681093396742,
#   'tempSmartfin': 19.13324066390042,
#   'buoyCDIP': '201',
#   'heightCDIP': 0.5299999713897705,
#   'tempCDIP': 18.78200912475586,
#   'latitude': 32.85199344919786,
#   'longitude': -117.26346576203208},
#  {'rideId': '16298',
#   'loc1': 'La Jolla',
#   'loc2': 'San Diego',
#   'loc3': 'San Diego County',
#   'startTime': 1571671460,
#   'endTime': 1571675060,
#   'heightSmartfin': 0.6791315978701143,
#   'tempSmartfin': 17.93609531772575,
#   'buoyCDIP': '201',
#   'heightCDIP': 1.1050000190734863,
#   'tempCDIP': 18.755844116210938,
#   'latitude': 32.851374597961495,
#   'longitude': -117.26316751981881},
#  {'rideId': '16290',
#   'loc1': 'La Jolla',
#   'loc2': 'San Diego',
#   'loc3': 'San Diego County',
#   'startTime': 1569943910,
#   'endTime': 1569947131,
#   'heightSmartfin': 1.3446089018207055,
#   'tempSmartfin': 20.6526261682243,
#   'buoyCDIP': '201',
#   'heightCDIP': 1.065000057220459,
#   'tempCDIP': 20.591821670532227,
#   'latitude': 32.85305064772727,
#   'longitude': -117.2605351590909},
#  {'rideId': '16289',
#   'loc1': 'La Jolla',
#   'loc2': 'San Diego',
#   'loc3': 'San Diego County',
#   'startTime': 1570316489,
#   'endTime': 1570318994,
#   'heightSmartfin': 0.6124114661985623,
#   'tempSmartfin': 21.28510817307692,
#   'buoyCDIP': '201',
#   'heightCDIP': 0.9399999976158142,
#   'tempCDIP': 20.908897399902344,
#   'latitude': 32.850871375000004,
#   'longitude': -117.25927275000001},
#  {'rideId': '16250',
#   'loc1': 'La Jolla',
#   'loc2': 'San Diego',
#   'loc3': 'San Diego County',
#   'startTime': 1568573209,
#   'endTime': 1568578838,
#   'heightSmartfin': 0.5308156496001618,
#   'tempSmartfin': 23.673319786096258,
#   'buoyCDIP': '201',
#   'heightCDIP': 0.5099999904632568,
#   'tempCDIP': 25.040006637573242,
#   'latitude': 32.85087827272727,
#   'longitude': -117.25917336363636},
#  {'rideId': '16249',
#   'loc1': 'La Jolla',
#   'loc2': 'San Diego',
#   'loc3': 'San Diego County',
#   'startTime': 1568504700,
#   'endTime': 1568511539,
#   'heightSmartfin': 0.3141288025546928,
#   'tempSmartfin': 25.567789612676055,
#   'buoyCDIP': '201',
#   'heightCDIP': 0.3774999976158142,
#   'tempCDIP': 24.72783660888672,
#   'latitude': 32.85263450488998,
#   'longitude': -117.26655799511002},
#  {'rideId': '16239',
#   'loc1': 'La Jolla',
#   'loc2': 'San Diego',
#   'loc3': 'San Diego County',
#   'startTime': 1567617265,
#   'endTime': 1567624995,
#   'heightSmartfin': 0.6949528728123969,
#   'tempSmartfin': 26.088663551401872,
#   'buoyCDIP': '201',
#   'heightCDIP': 0.5119999647140503,
#   'tempCDIP': 25.03923225402832,
#   'latitude': 32.85011139100346,
#   'longitude': -117.2637378615917},
#  {'rideId': '16238',
#   'loc1': 'La Jolla',
#   'loc2': 'San Diego',
#   'loc3': 'San Diego County',
#   'startTime': 1567469362,
#   'endTime': 1567473684,
#   'heightSmartfin': 0.3230272591645206,
#   'tempSmartfin': 25.742544568245126,
#   'buoyCDIP': '201',
#   'heightCDIP': 0.34666669368743896,
#   'tempCDIP': 25.5528621673584,
#   'latitude': 32.85212802216539,
#   'longitude': -117.26378623188407},
#  {'rideId': '16237',
#   'loc1': 'La Jolla',
#   'loc2': 'San Diego',
#   'loc3': 'San Diego County',
#   'startTime': 1567469384,
#   'endTime': 1567473104,
#   'heightSmartfin': 0.30515738118656105,
#   'tempSmartfin': 25.798082524271845,
#   'buoyCDIP': '201',
#   'heightCDIP': 0.3500000238418579,
#   'tempCDIP': 25.530839920043945,
#   'latitude': 32.85257005,
#   'longitude': -117.2655791625},
#  {'rideId': '16225',
#   'loc1': 'La Jolla',
#   'loc2': 'San Diego',
#   'loc3': 'San Diego County',
#   'startTime': 1566833282,
#   'endTime': 1566838260,
#   'heightSmartfin': 0.5617861937189434,
#   'tempSmartfin': 21.660911729141475,
#   'buoyCDIP': '201',
#   'heightCDIP': 0.5666666626930237,
#   'tempCDIP': 22.229385375976562,
#   'latitude': 32.850812613636364,
#   'longitude': -117.26170318181818},
#  {'rideId': '16222',
#   'loc1': 'La Jolla',
#   'loc2': 'San Diego',
#   'loc3': 'San Diego County',
#   'startTime': 1566751573,
#   'endTime': 1566757575,
#   'heightSmartfin': 0.4888846897250368,
#   'tempSmartfin': 21.986965897693075,
#   'buoyCDIP': '201',
#   'heightCDIP': 0.550000011920929,
#   'tempCDIP': 22.049503326416016,
#   'latitude': 32.851801875,
#   'longitude': -117.26678038580246},
#  {'rideId': '16221',
#   'loc1': 'La Jolla',
#   'loc2': 'San Diego',
#   'loc3': 'San Diego County',
#   'startTime': 1566752445,
#   'endTime': 1566757791,
#   'heightSmartfin': 0.46394038356167805,
#   'tempSmartfin': 22.036060810810817,
#   'buoyCDIP': '201',
#   'heightCDIP': 0.550000011920929,
#   'tempCDIP': 22.110002517700195,
#   'latitude': 32.85225047116165,
#   'longitude': -117.26819442729489},
#  {'rideId': '16212',
#   'loc1': 'La Jolla',
#   'loc2': 'San Diego',
#   'loc3': 'San Diego County',
#   'startTime': 1565450897,
#   'endTime': 1565453125,
#   'heightSmartfin': 0.4103094581106867,
#   'tempSmartfin': 20.533486486486485,
#   'buoyCDIP': '201',
#   'heightCDIP': 0.6399999856948853,
#   'tempCDIP': 20.74714469909668,
#   'latitude': 32.86017029661017,
#   'longitude': -117.25728508474576},
#  {'rideId': '16211',
#   'loc1': 'La Jolla',
#   'loc2': 'San Diego',
#   'loc3': 'San Diego County',
#   'startTime': 1565281315,
#   'endTime': 1565284127,
#   'heightSmartfin': 0.5039792322452558,
#   'tempSmartfin': 20.964627408993575,
#   'buoyCDIP': '201',
#   'heightCDIP': 0.6000000238418579,
#   'tempCDIP': 20.942005157470703,
#   'latitude': 32.85870677049181,
#   'longitude': -117.257931},
#  {'rideId': '16197',
#   'loc1': 'La Jolla',
#   'loc2': 'San Diego',
#   'loc3': 'San Diego County',
#   'startTime': 1565022966,
#   'endTime': 1565025388,
#   'heightSmartfin': 0.8283634273375001,
#   'tempSmartfin': 22.022547263681588,
#   'buoyCDIP': '201',
#   'heightCDIP': 0.6349999904632568,
#   'tempCDIP': 22.213760375976562,
#   'latitude': 32.85911179673321,
#   'longitude': -117.25778475499092},
#  {'rideId': '16195',
#   'loc1': 'La Jolla',
#   'loc2': 'San Diego',
#   'loc3': 'San Diego County',
#   'startTime': 1564966047,
#   'endTime': 1564969611,
#   'heightSmartfin': 0.4343562987458954,
#   'tempSmartfin': 23.029375,
#   'buoyCDIP': '201',
#   'heightCDIP': 0.675000011920929,
#   'tempCDIP': 22.63750648498535,
#   'latitude': 32.852344864572046,
#   'longitude': -117.2641092524377},
#  {'rideId': '16192',
#   'loc1': 'La Jolla',
#   'loc2': 'San Diego',
#   'loc3': 'San Diego County',
#   'startTime': 1564501090,
#   'endTime': 1564504343,
#   'heightSmartfin': 0.5017183758555545,
#   'tempSmartfin': 23.37277222222222,
#   'buoyCDIP': '201',
#   'heightCDIP': 0.9850000143051147,
#   'tempCDIP': 23.59700584411621,
#   'latitude': 32.858377263610315,
#   'longitude': -117.25849243553009},
#  {'rideId': '16191',
#   'loc1': 'La Jolla',
#   'loc2': 'San Diego',
#   'loc3': 'San Diego County',
#   'startTime': 1564764727,
#   'endTime': 1564766053,
#   'heightSmartfin': 0.642197994479234,
#   'tempSmartfin': 22.986109090909093,
#   'buoyCDIP': '201',
#   'heightCDIP': 0.8299999833106995,
#   'tempCDIP': 22.90399742126465,
#   'latitude': 32.858385920852356,
#   'longitude': -117.25808435312025},
#  {'rideId': '16178',
#   'loc1': 'La Jolla',
#   'loc2': 'San Diego',
#   'loc3': 'San Diego County',
#   'startTime': 1562429966,
#   'endTime': 1562432250,
#   'heightSmartfin': 0.4704977184591453,
#   'tempSmartfin': 18.86951451187335,
#   'buoyCDIP': '201',
#   'heightCDIP': 0.6200000047683716,
#   'tempCDIP': 19.138580322265625,
#   'latitude': 32.858805940803386,
#   'longitude': -117.25890938689217},
#  {'rideId': '16177',
#   'loc1': 'La Jolla',
#   'loc2': 'San Diego',
#   'loc3': 'San Diego County',
#   'startTime': 1563470073,
#   'endTime': 1563472247,
#   'heightSmartfin': 0.621566826362141,
#   'tempSmartfin': 21.213252077562327,
#   'buoyCDIP': '201',
#   'heightCDIP': 0.48000001907348633,
#   'tempCDIP': 20.704288482666016,
#   'latitude': 32.85922895744681,
#   'longitude': -117.25751921276596},
#  {'rideId': '16173',
#   'loc1': 'La Jolla',
#   'loc2': 'San Diego',
#   'loc3': 'San Diego County',
#   'startTime': 1562864784,
#   'endTime': 1562868054,
#   'heightSmartfin': 0.49568249578993706,
#   'tempSmartfin': 21.150633517495397,
#   'buoyCDIP': '201',
#   'heightCDIP': 0.7300000190734863,
#   'tempCDIP': 20.565465927124023,
#   'latitude': 32.858570925925925,
#   'longitude': -117.25853464387465},
#  {'rideId': '16171',
#   'loc1': 'La Jolla',
#   'loc2': 'San Diego',
#   'loc3': 'San Diego County',
#   'startTime': 1562689060,
#   'endTime': 1562690855,
#   'heightSmartfin': 0.5522366718274178,
#   'tempSmartfin': 20.26179865771812,
#   'buoyCDIP': '201',
#   'heightCDIP': 0.5699999928474426,
#   'tempCDIP': 19.881668090820312,
#   'latitude': 32.85874451428571,
#   'longitude': -117.25808476190475},
#  {'rideId': '16169',
#   'loc1': 'La Jolla',
#   'loc2': 'San Diego',
#   'loc3': 'San Diego County',
#   'startTime': 1562517902,
#   'endTime': 1562521095,
#   'heightSmartfin': 0.4204739961160755,
#   'tempSmartfin': 19.33209245283019,
#   'buoyCDIP': '201',
#   'heightCDIP': 0.6499999761581421,
#   'tempCDIP': 19.14000701904297,
#   'latitude': 32.859811362962965,
#   'longitude': -117.25809736296296},
#  {'rideId': '16168',
#   'loc1': 'La Jolla',
#   'loc2': 'San Diego',
#   'loc3': 'San Diego County',
#   'startTime': 1562343424,
#   'endTime': 1562347032,
#   'heightSmartfin': 0.528580888368911,
#   'tempSmartfin': 18.534223706176963,
#   'buoyCDIP': '201',
#   'heightCDIP': 0.8350000381469727,
#   'tempCDIP': 18.814170837402344,
#   'latitude': 32.85881072483222,
#   'longitude': -117.25853473825504},
#  {'rideId': '16167',
#   'loc1': 'La Jolla',
#   'loc2': 'San Diego',
#   'loc3': 'San Diego County',
#   'startTime': 1563224593,
#   'endTime': 1563227025,
#   'heightSmartfin': 0.5220379380877774,
#   'tempSmartfin': 22.757891089108906,
#   'buoyCDIP': '201',
#   'heightCDIP': 0.6899999976158142,
#   'tempCDIP': 22.235004425048828,
#   'latitude': 32.85189403197158,
#   'longitude': -117.26373341030195},
#  {'rideId': '16161',
#   'loc1': 'La Jolla',
#   'loc2': 'San Diego',
#   'loc3': 'San Diego County',
#   'startTime': 1563137308,
#   'endTime': 1563140932,
#   'heightSmartfin': 0.5280891441323716,
#   'tempSmartfin': 22.547958471760797,
#   'buoyCDIP': '201',
#   'heightCDIP': 0.5349999666213989,
#   'tempCDIP': 21.464174270629883,
#   'latitude': 32.85213960509554,
#   'longitude': -117.26298096815286},
#  {'rideId': '16158',
#   'loc1': 'La Jolla',
#   'loc2': 'San Diego',
#   'loc3': 'San Diego County',
#   'startTime': 1562437676,
#   'endTime': 1562442576,
#   'heightSmartfin': 0.6227975974022982,
#   'tempSmartfin': 18.79893243243243,
#   'buoyCDIP': '201',
#   'heightCDIP': 0.8033332824707031,
#   'tempCDIP': 19.29813575744629,
#   'latitude': 32.85082392405064,
#   'longitude': -117.25927487341772},
#  {'rideId': '16148',
#   'loc1': 'La Jolla',
#   'loc2': 'San Diego',
#   'loc3': 'San Diego County',
#   'startTime': 1562082142,
#   'endTime': 1562085838,
#   'heightSmartfin': 0.7370040122823286,
#   'tempSmartfin': 17.222762214983714,
#   'buoyCDIP': '201',
#   'heightCDIP': 1.1349999904632568,
#   'tempCDIP': 18.240007400512695,
#   'latitude': 32.85311720990873,
#   'longitude': -117.2608798565841},
#  {'rideId': '16137',
#   'loc1': 'La Jolla',
#   'loc2': 'San Diego',
#   'loc3': 'San Diego County',
#   'startTime': 1560962575,
#   'endTime': 1560965033,
#   'heightSmartfin': 0.2833940627684416,
#   'tempSmartfin': 18.939855392156865,
#   'buoyCDIP': '201',
#   'heightCDIP': 0.5550000071525574,
#   'tempCDIP': 19.28500747680664,
#   'latitude': 32.85913866920152,
#   'longitude': -117.25823593155894},
#  {'rideId': '16135',
#   'loc1': 'La Jolla',
#   'loc2': 'San Diego',
#   'loc3': 'San Diego County',
#   'startTime': 1560531654,
#   'endTime': 1560534305,
#   'heightSmartfin': 0.3968926971374553,
#   'tempSmartfin': 19.571597727272728,
#   'buoyCDIP': '201',
#   'heightCDIP': 0.6150000095367432,
#   'tempCDIP': 19.8577880859375,
#   'latitude': 32.85932654320988,
#   'longitude': -117.25785539682539},
#  {'rideId': '16134',
#   'loc1': 'La Jolla',
#   'loc2': 'San Diego',
#   'loc3': 'San Diego County',
#   'startTime': 1560270066,
#   'endTime': 1560273109,
#   'heightSmartfin': 0.3515648229045688,
#   'tempSmartfin': 19.904956435643566,
#   'buoyCDIP': '201',
#   'heightCDIP': 0.44999998807907104,
#   'tempCDIP': 19.531005859375,
#   'latitude': 32.85987874418605,
#   'longitude': -117.25794848062016},
#  {'rideId': '16128',
#   'loc1': 'La Jolla',
#   'loc2': 'San Diego',
#   'loc3': 'San Diego County',
#   'startTime': 1560628868,
#   'endTime': 1560633106,
#   'heightSmartfin': 0.6307692597542487,
#   'tempSmartfin': 20.751139204545453,
#   'buoyCDIP': '201',
#   'heightCDIP': 0.5550000071525574,
#   'tempCDIP': 20.499292373657227,
#   'latitude': 32.85607747348119,
#   'longitude': -117.25992567984572},
#  {'rideId': '16126',
#   'loc1': 'La Jolla',
#   'loc2': 'San Diego',
#   'loc3': 'San Diego County',
#   'startTime': 1560628941,
#   'endTime': 1560633101,
#   'heightSmartfin': 0.5532440526363992,
#   'tempSmartfin': 20.460031837916066,
#   'buoyCDIP': '201',
#   'heightCDIP': 0.5550000071525574,
#   'tempCDIP': 20.499292373657227,
#   'latitude': 32.85586644400786,
#   'longitude': -117.26044271119842},
#  {'rideId': '16115',
#   'loc1': 'La Jolla',
#   'loc2': 'San Diego',
#   'loc3': 'San Diego County',
#   'startTime': 1559919895,
#   'endTime': 1559922321,
#   'heightSmartfin': 0.7739041667096287,
#   'tempSmartfin': 17.57927047146402,
#   'buoyCDIP': '201',
#   'heightCDIP': 0.6650000214576721,
#   'tempCDIP': 17.855010986328125,
#   'latitude': 32.85879590982287,
#   'longitude': -117.2588501610306},
#  {'rideId': '16106',
#   'loc1': 'La Jolla',
#   'loc2': 'San Diego',
#   'loc3': 'San Diego County',
#   'startTime': 1559318176,
#   'endTime': 1559322739,
#   'heightSmartfin': 0.8666619215905952,
#   'tempSmartfin': 18.0425,
#   'buoyCDIP': '201',
#   'heightCDIP': 0.7899999618530273,
#   'tempCDIP': 18.33333969116211,
#   'latitude': 32.85095126126126,
#   'longitude': -117.25945306306306},
#  {'rideId': '16103',
#   'loc1': 'La Jolla',
#   'loc2': 'San Diego',
#   'loc3': 'San Diego County',
#   'startTime': 1559143002,
#   'endTime': 1559148077,
#   'heightSmartfin': 0.9466108802237144,
#   'tempSmartfin': 17.682581257413997,
#   'buoyCDIP': '201',
#   'heightCDIP': 1.0950000286102295,
#   'tempCDIP': 18.08235740661621,
#   'latitude': 32.85746011885895,
#   'longitude': -117.25890274167986},
#  {'rideId': '16101',
#   'loc1': 'La Jolla',
#   'loc2': 'San Diego',
#   'loc3': 'San Diego County',
#   'startTime': 1558823027,
#   'endTime': 1558828499,
#   'heightSmartfin': 0.3748512059225787,
#   'tempSmartfin': 18.607677667766776,
#   'buoyCDIP': '201',
#   'heightCDIP': 0.6066666841506958,
#   'tempCDIP': 18.718894958496094,
#   'latitude': 32.85277942655145,
#   'longitude': -117.26547062843677},
#  {'rideId': '16100',
#   'loc1': 'La Jolla',
#   'loc2': 'San Diego',
#   'loc3': 'San Diego County',
#   'startTime': 1559056545,
#   'endTime': 1559062529,
#   'heightSmartfin': 0.5798144840241994,
#   'tempSmartfin': 16.84068209255533,
#   'buoyCDIP': '201',
#   'heightCDIP': 0.9300000667572021,
#   'tempCDIP': 17.44100570678711,
#   'latitude': 32.85765806340455,
#   'longitude': -117.25901885596141},
#  {'rideId': '16099',
#   'loc1': 'La Jolla',
#   'loc2': 'San Diego',
#   'loc3': 'San Diego County',
#   'startTime': 1558823025,
#   'endTime': 1558826186,
#   'heightSmartfin': 5.86383570724265,
#   'tempSmartfin': 18.571798095238094,
#   'buoyCDIP': '201',
#   'heightCDIP': 0.5900000333786011,
#   'tempCDIP': 18.721004486083984,
#   'latitude': 32.85298346153846,
#   'longitude': -117.26731449704143},
#  {'rideId': '16081',
#   'loc1': 'La Jolla',
#   'loc2': 'San Diego',
#   'loc3': 'San Diego County',
#   'startTime': 1557934646,
#   'endTime': 1557939672,
#   'heightSmartfin': 0.5629105544765778,
#   'tempSmartfin': 18.71829341317365,
#   'buoyCDIP': '201',
#   'heightCDIP': 0.5566666722297668,
#   'tempCDIP': 18.76412582397461,
#   'latitude': 32.85092397590361,
#   'longitude': -117.25940457831325},
#  {'rideId': '16079',
#   'loc1': 'La Jolla',
#   'loc2': 'San Diego',
#   'loc3': 'San Diego County',
#   'startTime': 1557846355,
#   'endTime': 1557854897,
#   'heightSmartfin': 0.5343034566572307,
#   'tempSmartfin': 18.3360584918957,
#   'buoyCDIP': '201',
#   'heightCDIP': 0.515999972820282,
#   'tempCDIP': 18.531389236450195,
#   'latitude': 32.85085329842932,
#   'longitude': -117.25934392670156},
#  {'rideId': '16076',
#   'loc1': 'La Jolla',
#   'loc2': 'San Diego',
#   'loc3': 'San Diego County',
#   'startTime': 1557705920,
#   'endTime': 1557709153,
#   'heightSmartfin': 0.5321975203481288,
#   'tempSmartfin': 19.275597765363127,
#   'buoyCDIP': '201',
#   'heightCDIP': 0.8600000143051147,
#   'tempCDIP': 18.870006561279297,
#   'latitude': 32.85121489932886,
#   'longitude': -117.25966557046979},
#  {'rideId': '15996',
#   'loc1': 'La Jolla',
#   'loc2': 'San Diego',
#   'loc3': 'San Diego County',
#   'startTime': 1552669635,
#   'endTime': 1552672639,
#   'heightSmartfin': 0.5384636597695007,
#   'tempSmartfin': 15.83214629258517,
#   'buoyCDIP': '201',
#   'heightCDIP': 0.41499999165534973,
#   'tempCDIP': 15.511007308959961,
#   'latitude': 32.852096089030205,
#   'longitude': -117.26316233704293},
#  {'rideId': '15980',
#   'loc1': 'La Jolla',
#   'loc2': 'San Diego',
#   'loc3': 'San Diego County',
#   'startTime': 1551215592,
#   'endTime': 1551218223,
#   'heightSmartfin': 1.3126418245845508,
#   'tempSmartfin': 15.413704805491992,
#   'buoyCDIP': '201',
#   'heightCDIP': 0.2849999964237213,
#   'tempCDIP': 14.805004119873047,
#   'latitude': 32.85171376271187,
#   'longitude': -117.2636506779661},
#  {'rideId': '15972',
#   'loc1': 'La Jolla',
#   'loc2': 'San Diego',
#   'loc3': 'San Diego County',
#   'startTime': 1551058379,
#   'endTime': 1551062925,
#   'heightSmartfin': 0.6531221269397142,
#   'tempSmartfin': 14.210163999999999,
#   'buoyCDIP': '201',
#   'heightCDIP': 0.5066666603088379,
#   'tempCDIP': 14.64267349243164,
#   'latitude': 32.86464311403509,
#   'longitude': -117.2420797368421},
#  {'rideId': '15963',
#   'loc1': 'La Jolla',
#   'loc2': 'San Diego',
#   'loc3': 'San Diego County',
#   'startTime': 1550861140,
#   'endTime': 1550864375,
#   'heightSmartfin': 0.8751134002551536,
#   'tempSmartfin': 15.065393258426967,
#   'buoyCDIP': '201',
#   'heightCDIP': 0.8700000047683716,
#   'tempCDIP': 14.3972749710083,
#   'latitude': 32.85846145936982,
#   'longitude': -117.25730747927032},
#  {'rideId': '15962',
#   'loc1': 'La Jolla',
#   'loc2': 'San Diego',
#   'loc3': 'San Diego County',
#   'startTime': 1549646446,
#   'endTime': 1549650591,
#   'heightSmartfin': 0.46403378477939916,
#   'tempSmartfin': 15.612076023391813,
#   'buoyCDIP': '201',
#   'heightCDIP': 0.4449999928474426,
#   'tempCDIP': 15.48358154296875,
#   'latitude': 32.86094989371125,
#   'longitude': -117.25207212577502},
#  {'rideId': '15945',
#   'loc1': 'La Jolla',
#   'loc2': 'San Diego',
#   'loc3': 'San Diego County',
#   'startTime': 1549749585,
#   'endTime': 1549752715,
#   'heightSmartfin': 0.4130687409449136,
#   'tempSmartfin': 15.729092307692307,
#   'buoyCDIP': '201',
#   'heightCDIP': 0.3149999976158142,
#   'tempCDIP': 15.497003555297852,
#   'latitude': 32.85223186797753,
#   'longitude': -117.26420502808988},
#  {'rideId': '15859',
#   'loc1': 'La Jolla',
#   'loc2': 'San Diego',
#   'loc3': 'San Diego County',
#   'startTime': 1546718751,
#   'endTime': 1546721743,
#   'heightSmartfin': 0.7219074882063148,
#   'tempSmartfin': 15.12332394366197,
#   'buoyCDIP': '201',
#   'heightCDIP': 0.4650000035762787,
#   'tempCDIP': 15.483007431030273,
#   'latitude': 32.85307128440367,
#   'longitude': -117.25966834862385},
#  {'rideId': '15857',
#   'loc1': 'La Jolla',
#   'loc2': 'San Diego',
#   'loc3': 'San Diego County',
#   'startTime': 1546621448,
#   'endTime': 1546626632,
#   'heightSmartfin': 0.4667968559896883,
#   'tempSmartfin': 15.337380232558141,
#   'buoyCDIP': '201',
#   'heightCDIP': 0.41999998688697815,
#   'tempCDIP': 15.606475830078125,
#   'latitude': 32.85934398642095,
#   'longitude': -117.25784849660523},
#  {'rideId': '15856',
#   'loc1': 'La Jolla',
#   'loc2': 'San Diego',
#   'loc3': 'San Diego County',
#   'startTime': 1546538965,
#   'endTime': 1546541026,
#   'heightSmartfin': 0.33065953780985163,
#   'tempSmartfin': 15.171859649122807,
#   'buoyCDIP': '201',
#   'heightCDIP': 0.4099999964237213,
#   'tempCDIP': 15.62714958190918,
#   'latitude': 32.8589860130719,
#   'longitude': -117.25814032085562},
#  {'rideId': '15854',
#   'loc1': 'La Jolla',
#   'loc2': 'San Diego',
#   'loc3': 'San Diego County',
#   'startTime': 1546626437,
#   'endTime': 1546633011,
#   'heightSmartfin': 0.5808067594807285,
#   'tempSmartfin': 15.583867216117214,
#   'buoyCDIP': '201',
#   'heightCDIP': 0.4099999964237213,
#   'tempCDIP': 15.855911254882812,
#   'latitude': 32.859459670975326,
#   'longitude': -117.25808851938896},
#  {'rideId': '15848',
#   'loc1': 'La Jolla',
#   'loc2': 'San Diego',
#   'loc3': 'San Diego County',
#   'startTime': 1546365100,
#   'endTime': 1546367878,
#   'heightSmartfin': 0.5286699403101088,
#   'tempSmartfin': 15.232898047722344,
#   'buoyCDIP': '201',
#   'heightCDIP': 0.49000000953674316,
#   'tempCDIP': 15.576013565063477,
#   'latitude': 32.8586828928047,
#   'longitude': -117.25857917767989},
#  {'rideId': '16380',
#   'loc1': 'La Jolla',
#   'loc2': 'San Diego',
#   'loc3': 'San Diego County',
#   'startTime': 1576007501,
#   'endTime': 1576009710,
#   'heightSmartfin': 0.5548853024235092,
#   'tempSmartfin': 17.33151226158038,
#   'buoyCDIP': '201',
#   'heightCDIP': 0.7799999713897705,
#   'tempCDIP': 17.3487548828125,
#   'latitude': 32.85199169871795,
#   'longitude': -117.26305794871794},
#  {'rideId': '15692',
#   'loc1': 'La Jolla',
#   'loc2': 'San Diego',
#   'loc3': 'San Diego County',
#   'startTime': 1541791072,
#   'endTime': 1541794669,
#   'heightSmartfin': 0.45559016163497096,
#   'tempSmartfin': 20.044069023569023,
#   'buoyCDIP': '201',
#   'heightCDIP': 0.4414551854133606,
#   'tempCDIP': 19.860002517700195,
#   'latitude': 32.86058653508772,
#   'longitude': -117.25365867324561},
#  {'rideId': 'Sfin-33002a001847363439353035-190712-133655',
#   'loc1': 'Pacific Beach',
#   'loc2': 'San Diego',
#   'loc3': 'San Diego County',
#   'startTime': 1562938616,
#   'endTime': 1562938763,
#   'heightSmartfin': 0.11838336873968074,
#   'tempSmartfin': 19.404572147651006,
#   'buoyCDIP': '201',
#   'heightCDIP': 0.699999988079071,
#   'tempCDIP': 20.94000244140625,
#   'latitude': 32.80280932258066,
#   'longitude': -117.26243596774194},
#  {'rideId': 'Sfin-1a0027001047373333353132-190823-132803',
#   'loc1': 'La Jolla',
#   'loc2': 'San Diego',
#   'loc3': 'San Diego County',
#   'startTime': 1566566884,
#   'endTime': 1566570362,
#   'heightSmartfin': 0.281283425601486,
#   'tempSmartfin': 19.139231209982537,
#   'buoyCDIP': '201',
#   'heightCDIP': 0.5449999570846558,
#   'tempCDIP': 20.24000358581543,
#   'latitude': 32.80550161320754,
#   'longitude': -117.26359421698113},
#  {'rideId': 'Sfin-33002a001847363439353035-190712-125339',
#   'loc1': 'Pacific Beach',
#   'loc2': 'San Diego',
#   'loc3': 'San Diego County',
#   'startTime': 1562936020,
#   'endTime': 1562938340,
#   'heightSmartfin': 0.18665585174876706,
#   'tempSmartfin': 19.583834909716252,
#   'buoyCDIP': '201',
#   'heightCDIP': 0.6100000143051147,
#   'tempCDIP': 20.96286392211914,
#   'latitude': 32.80309041454545,
#   'longitude': -117.26258958181819}]

# %% [markdown]
# ### get multiple rides between start and end date

# %%
startDate = '1541030400'
endDate = '2552566400'

if testing:
    rideGetDate = f'http://127.0.0.1:8000/ride/rides/startDate={startDate},endDate={endDate}' # creates new ride and upload all ride data to db
else:
    rideGetDate = f'{domainName}/ride/rides/startDate={startDate},endDate={endDate}'  # creates new ride and upload all r

response = requests.get(rideGetDate).json()
response
# Out:
# [{'rideId': '16000',
#   'loc1': 'La Jolla',
#   'loc2': 'San Diego',
#   'loc3': 'San Diego County',
#   'startTime': 1552778033,
#   'endTime': 1552781386,
#   'heightSmartfin': 0.40845185873427914,
#   'tempSmartfin': 17.172475763016156,
#   'buoyCDIP': '201',
#   'heightCDIP': 0.45499998331069946,
#   'tempCDIP': 16.7945499420166,
#   'latitude': 32.85231859863946,
#   'longitude': -117.26381327891156},
#  {'rideId': '16376',
#   'loc1': 'La Jolla',
#   'loc2': 'San Diego County',
#   'loc3': 'California',
#   'startTime': 1574726559,
#   'endTime': 1574729135,
#   'heightSmartfin': 0.9460319998263358,
#   'tempSmartfin': 17.275294392523367,
#   'buoyCDIP': '201',
#   'heightCDIP': 0.7250000238418579,
#   'tempCDIP': 17.341251373291016,
#   'latitude': 32.86556967509025,
#   'longitude': -117.25709247292419},
#  {'rideId': '16345',
#   'loc1': 'La Jolla',
#   'loc2': 'San Diego',
#   'loc3': 'San Diego County',
#   'startTime': 1574176028,
#   'endTime': 1574178412,
#   'heightSmartfin': 0.3808737691417218,
#   'tempSmartfin': 16.602045454545454,
#   'buoyCDIP': '201',
#   'heightCDIP': 0.5349999666213989,
#   'tempCDIP': 17.081256866455078,
#   'latitude': 32.85233376451078,
#   'longitude': -117.26432490878938},
#  {'rideId': '16318',
#   'loc1': 'La Jolla',
#   'loc2': 'San Diego',
#   'loc3': 'San Diego County',
#   'startTime': 1573332063,
#   'endTime': 1573335260,
#   'heightSmartfin': 0.5428762299265988,
#   'tempSmartfin': 19.160367231638414,
#   'buoyCDIP': '201',
#   'heightCDIP': 0.6299999952316284,
#   'tempCDIP': 18.839092254638672,
#   'latitude': 32.85414126618705,
#   'longitude': -117.26592332374102},
#  {'rideId': '16302',
#   'loc1': 'La Jolla',
#   'loc2': 'San Diego',
#   'loc3': 'San Diego County',
#   'startTime': 1572116946,
#   'endTime': 1572120450,
#   'heightSmartfin': 0.6718289115566997,
#   'tempSmartfin': 19.758730240549824,
#   'buoyCDIP': '201',
#   'heightCDIP': 0.39499998092651367,
#   'tempCDIP': 19.683643341064453,
#   'latitude': 32.85993588043478,
#   'longitude': -117.25840547826087},
#  {'rideId': '16301',
#   'loc1': 'La Jolla',
#   'loc2': 'San Diego',
#   'loc3': 'San Diego County',
#   'startTime': 1572031150,
#   'endTime': 1572034052,
#   'heightSmartfin': 0.4013681093396742,
#   'tempSmartfin': 19.13324066390042,
#   'buoyCDIP': '201',
#   'heightCDIP': 0.5299999713897705,
#   'tempCDIP': 18.78200912475586,
#   'latitude': 32.85199344919786,
#   'longitude': -117.26346576203208},
#  {'rideId': '16300',
#   'loc1': 'La Jolla',
#   'loc2': 'San Diego County',
#   'loc3': 'California',
#   'startTime': 1571938929,
#   'endTime': 1571941319,
#   'heightSmartfin': 0.49562878481694916,
#   'tempSmartfin': 19.056392947103276,
#   'buoyCDIP': '201',
#   'heightCDIP': 0.6200000047683716,
#   'tempCDIP': 19.49625015258789,
#   'latitude': 32.85170904458599,
#   'longitude': -117.26398047770701},
#  {'rideId': '16299',
#   'loc1': 'La Jolla',
#   'loc2': 'San Diego County',
#   'loc3': 'California',
#   'startTime': 1571859552,
#   'endTime': 1571861725,
#   'heightSmartfin': 0.43162395826775946,
#   'tempSmartfin': 19.359534626038784,
#   'buoyCDIP': '201',
#   'heightCDIP': 0.5699999928474426,
#   'tempCDIP': 19.445722579956055,
#   'latitude': 32.85194301425662,
#   'longitude': -117.26428407331976},
#  {'rideId': '16298',
#   'loc1': 'La Jolla',
#   'loc2': 'San Diego',
#   'loc3': 'San Diego County',
#   'startTime': 1571671460,
#   'endTime': 1571675060,
#   'heightSmartfin': 0.6791315978701143,
#   'tempSmartfin': 17.93609531772575,
#   'buoyCDIP': '201',
#   'heightCDIP': 1.1050000190734863,
#   'tempCDIP': 18.755844116210938,
#   'latitude': 32.851374597961495,
#   'longitude': -117.26316751981881},
#  {'rideId': '16297',
#   'loc1': 'La Jolla',
#   'loc2': 'San Diego County',
#   'loc3': 'California',
#   'startTime': 1571773274,
#   'endTime': 1571775476,
#   'heightSmartfin': 0.43871618389742056,
#   'tempSmartfin': 20.342345646437995,
#   'buoyCDIP': '201',
#   'heightCDIP': 0.574999988079071,
#   'tempCDIP': 20.445003509521484,
#   'latitude': 32.85223,
#   'longitude': -117.26448074074075},
#  {'rideId': '16290',
#   'loc1': 'La Jolla',
#   'loc2': 'San Diego',
#   'loc3': 'San Diego County',
#   'startTime': 1569943910,
#   'endTime': 1569947131,
#   'heightSmartfin': 1.3446089018207055,
#   'tempSmartfin': 20.6526261682243,
#   'buoyCDIP': '201',
#   'heightCDIP': 1.065000057220459,
#   'tempCDIP': 20.591821670532227,
#   'latitude': 32.85305064772727,
#   'longitude': -117.2605351590909},
#  {'rideId': '16289',
#   'loc1': 'La Jolla',
#   'loc2': 'San Diego',
#   'loc3': 'San Diego County',
#   'startTime': 1570316489,
#   'endTime': 1570318994,
#   'heightSmartfin': 0.6124114661985623,
#   'tempSmartfin': 21.28510817307692,
#   'buoyCDIP': '201',
#   'heightCDIP': 0.9399999976158142,
#   'tempCDIP': 20.908897399902344,
#   'latitude': 32.850871375000004,
#   'longitude': -117.25927275000001},
#  {'rideId': '16278',
#   'loc1': 'Camino Del Oro',
#   'loc2': 'La Jolla',
#   'loc3': 'San Diego County',
#   'startTime': 1570316468,
#   'endTime': 1570319063,
#   'heightSmartfin': 13.402122248843234,
#   'tempSmartfin': 21.42676334106729,
#   'buoyCDIP': '201',
#   'heightCDIP': 0.9399999976158142,
#   'tempCDIP': 20.908897399902344,
#   'latitude': 32.852789001636665,
#   'longitude': -117.26180523731587},
#  {'rideId': '16262',
#   'loc1': 'La Jolla',
#   'loc2': 'San Diego County',
#   'loc3': 'California',
#   'startTime': 1569339000,
#   'endTime': 1569342612,
#   'heightSmartfin': 0.5257326257318952,
#   'tempSmartfin': 21.07598,
#   'buoyCDIP': '201',
#   'heightCDIP': 0.5399999618530273,
#   'tempCDIP': 21.315004348754883,
#   'latitude': 32.85057909214092,
#   'longitude': -117.26366577235773},
#  {'rideId': '16253',
#   'loc1': 'La Jolla',
#   'loc2': 'San Diego County',
#   'loc3': 'California',
#   'startTime': 1568996342,
#   'endTime': 1569001399,
#   'heightSmartfin': 0.7603094257000951,
#   'tempSmartfin': 20.56265,
#   'buoyCDIP': '201',
#   'heightCDIP': 0.8999999761581421,
#   'tempCDIP': 20.744709014892578,
#   'latitude': 32.85045954759661,
#   'longitude': -117.26400343072572},
#  {'rideId': '16252',
#   'loc1': 'La Jolla',
#   'loc2': 'San Diego County',
#   'loc3': 'California',
#   'startTime': 1568822826,
#   'endTime': 1568829460,
#   'heightSmartfin': 0.5244763530689744,
#   'tempSmartfin': 21.78315335753176,
#   'buoyCDIP': '201',
#   'heightCDIP': 0.7649999856948853,
#   'tempCDIP': 22.5317440032959,
#   'latitude': 32.85084394448502,
#   'longitude': -117.26346375456538},
#  {'rideId': '16250',
#   'loc1': 'La Jolla',
#   'loc2': 'San Diego',
#   'loc3': 'San Diego County',
#   'startTime': 1568573209,
#   'endTime': 1568578838,
#   'heightSmartfin': 0.5308156496001618,
#   'tempSmartfin': 23.673319786096258,
#   'buoyCDIP': '201',
#   'heightCDIP': 0.5099999904632568,
#   'tempCDIP': 25.040006637573242,
#   'latitude': 32.85087827272727,
#   'longitude': -117.25917336363636},
#  {'rideId': '16249',
#   'loc1': 'La Jolla',
#   'loc2': 'San Diego',
#   'loc3': 'San Diego County',
#   'startTime': 1568504700,
#   'endTime': 1568511539,
#   'heightSmartfin': 0.3141288025546928,
#   'tempSmartfin': 25.567789612676055,
#   'buoyCDIP': '201',
#   'heightCDIP': 0.3774999976158142,
#   'tempCDIP': 24.72783660888672,
#   'latitude': 32.85263450488998,
#   'longitude': -117.26655799511002},
#  {'rideId': '16243',
#   'loc1': 'La Jolla',
#   'loc2': 'San Diego County',
#   'loc3': 'California',
#   'startTime': 1568044591,
#   'endTime': 1568048197,
#   'heightSmartfin': 0.6210725285853507,
#   'tempSmartfin': 23.82446410684474,
#   'buoyCDIP': '201',
#   'heightCDIP': 0.8650000095367432,
#   'tempCDIP': 24.354177474975586,
#   'latitude': 32.85069996138996,
#   'longitude': -117.26453585585585},
#  {'rideId': '16239',
#   'loc1': 'La Jolla',
#   'loc2': 'San Diego',
#   'loc3': 'San Diego County',
#   'startTime': 1567617265,
#   'endTime': 1567624995,
#   'heightSmartfin': 0.6949528728123969,
#   'tempSmartfin': 26.088663551401872,
#   'buoyCDIP': '201',
#   'heightCDIP': 0.5119999647140503,
#   'tempCDIP': 25.03923225402832,
#   'latitude': 32.85011139100346,
#   'longitude': -117.2637378615917},
#  {'rideId': '16238',
#   'loc1': 'La Jolla',
#   'loc2': 'San Diego',
#   'loc3': 'San Diego County',
#   'startTime': 1567469362,
#   'endTime': 1567473684,
#   'heightSmartfin': 0.3230272591645206,
#   'tempSmartfin': 25.742544568245126,
#   'buoyCDIP': '201',
#   'heightCDIP': 0.34666669368743896,
#   'tempCDIP': 25.5528621673584,
#   'latitude': 32.85212802216539,
#   'longitude': -117.26378623188407},
#  {'rideId': '16237',
#   'loc1': 'La Jolla',
#   'loc2': 'San Diego',
#   'loc3': 'San Diego County',
#   'startTime': 1567469384,
#   'endTime': 1567473104,
#   'heightSmartfin': 0.30515738118656105,
#   'tempSmartfin': 25.798082524271845,
#   'buoyCDIP': '201',
#   'heightCDIP': 0.3500000238418579,
#   'tempCDIP': 25.530839920043945,
#   'latitude': 32.85257005,
#   'longitude': -117.2655791625},
#  {'rideId': '16225',
#   'loc1': 'La Jolla',
#   'loc2': 'San Diego',
#   'loc3': 'San Diego County',
#   'startTime': 1566833282,
#   'endTime': 1566838260,
#   'heightSmartfin': 0.5617861937189434,
#   'tempSmartfin': 21.660911729141475,
#   'buoyCDIP': '201',
#   'heightCDIP': 0.5666666626930237,
#   'tempCDIP': 22.229385375976562,
#   'latitude': 32.850812613636364,
#   'longitude': -117.26170318181818},
#  {'rideId': '16222',
#   'loc1': 'La Jolla',
#   'loc2': 'San Diego',
#   'loc3': 'San Diego County',
#   'startTime': 1566751573,
#   'endTime': 1566757575,
#   'heightSmartfin': 0.4888846897250368,
#   'tempSmartfin': 21.986965897693075,
#   'buoyCDIP': '201',
#   'heightCDIP': 0.550000011920929,
#   'tempCDIP': 22.049503326416016,
#   'latitude': 32.851801875,
#   'longitude': -117.26678038580246},
#  {'rideId': '16221',
#   'loc1': 'La Jolla',
#   'loc2': 'San Diego',
#   'loc3': 'San Diego County',
#   'startTime': 1566752445,
#   'endTime': 1566757791,
#   'heightSmartfin': 0.46394038356167805,
#   'tempSmartfin': 22.036060810810817,
#   'buoyCDIP': '201',
#   'heightCDIP': 0.550000011920929,
#   'tempCDIP': 22.110002517700195,
#   'latitude': 32.85225047116165,
#   'longitude': -117.26819442729489},
#  {'rideId': '16212',
#   'loc1': 'La Jolla',
#   'loc2': 'San Diego',
#   'loc3': 'San Diego County',
#   'startTime': 1565450897,
#   'endTime': 1565453125,
#   'heightSmartfin': 0.4103094581106867,
#   'tempSmartfin': 20.533486486486485,
#   'buoyCDIP': '201',
#   'heightCDIP': 0.6399999856948853,
#   'tempCDIP': 20.74714469909668,
#   'latitude': 32.86017029661017,
#   'longitude': -117.25728508474576},
#  {'rideId': '16211',
#   'loc1': 'La Jolla',
#   'loc2': 'San Diego',
#   'loc3': 'San Diego County',
#   'startTime': 1565281315,
#   'endTime': 1565284127,
#   'heightSmartfin': 0.5039792322452558,
#   'tempSmartfin': 20.964627408993575,
#   'buoyCDIP': '201',
#   'heightCDIP': 0.6000000238418579,
#   'tempCDIP': 20.942005157470703,
#   'latitude': 32.85870677049181,
#   'longitude': -117.257931},
#  {'rideId': '16197',
#   'loc1': 'La Jolla',
#   'loc2': 'San Diego',
#   'loc3': 'San Diego County',
#   'startTime': 1565022966,
#   'endTime': 1565025388,
#   'heightSmartfin': 0.8283634273375001,
#   'tempSmartfin': 22.022547263681588,
#   'buoyCDIP': '201',
#   'heightCDIP': 0.6349999904632568,
#   'tempCDIP': 22.213760375976562,
#   'latitude': 32.85911179673321,
#   'longitude': -117.25778475499092},
#  {'rideId': '16196',
#   'loc1': 'Camino Del Oro',
#   'loc2': 'La Jolla',
#   'loc3': 'San Diego County',
#   'startTime': 1564966040,
#   'endTime': 1564969568,
#   'heightSmartfin': 5.443058418243037,
#   'tempSmartfin': 23.12582252559727,
#   'buoyCDIP': '201',
#   'heightCDIP': 0.675000011920929,
#   'tempCDIP': 22.63750648498535,
#   'latitude': 32.852353658536586,
#   'longitude': -117.26365458980044},
#  {'rideId': '16195',
#   'loc1': 'La Jolla',
#   'loc2': 'San Diego',
#   'loc3': 'San Diego County',
#   'startTime': 1564966047,
#   'endTime': 1564969611,
#   'heightSmartfin': 0.4343562987458954,
#   'tempSmartfin': 23.029375,
#   'buoyCDIP': '201',
#   'heightCDIP': 0.675000011920929,
#   'tempCDIP': 22.63750648498535,
#   'latitude': 32.852344864572046,
#   'longitude': -117.2641092524377},
#  {'rideId': '16192',
#   'loc1': 'La Jolla',
#   'loc2': 'San Diego',
#   'loc3': 'San Diego County',
#   'startTime': 1564501090,
#   'endTime': 1564504343,
#   'heightSmartfin': 0.5017183758555545,
#   'tempSmartfin': 23.37277222222222,
#   'buoyCDIP': '201',
#   'heightCDIP': 0.9850000143051147,
#   'tempCDIP': 23.59700584411621,
#   'latitude': 32.858377263610315,
#   'longitude': -117.25849243553009},
#  {'rideId': '16191',
#   'loc1': 'La Jolla',
#   'loc2': 'San Diego',
#   'loc3': 'San Diego County',
#   'startTime': 1564764727,
#   'endTime': 1564766053,
#   'heightSmartfin': 0.642197994479234,
#   'tempSmartfin': 22.986109090909093,
#   'buoyCDIP': '201',
#   'heightCDIP': 0.8299999833106995,
#   'tempCDIP': 22.90399742126465,
#   'latitude': 32.858385920852356,
#   'longitude': -117.25808435312025},
#  {'rideId': '16189',
#   'loc1': 'La Jolla',
#   'loc2': 'San Diego County',
#   'loc3': 'California',
#   'startTime': 1564879762,
#   'endTime': 1564883019,
#   'heightSmartfin': 0.37585717800720597,
#   'tempSmartfin': 23.140972273567467,
#   'buoyCDIP': '201',
#   'heightCDIP': 0.6800000071525574,
#   'tempCDIP': 22.856365203857422,
#   'latitude': 32.85188845997974,
#   'longitude': -117.26467679837891},
#  {'rideId': '16178',
#   'loc1': 'La Jolla',
#   'loc2': 'San Diego',
#   'loc3': 'San Diego County',
#   'startTime': 1562429966,
#   'endTime': 1562432250,
#   'heightSmartfin': 0.4704977184591453,
#   'tempSmartfin': 18.86951451187335,
#   'buoyCDIP': '201',
#   'heightCDIP': 0.6200000047683716,
#   'tempCDIP': 19.138580322265625,
#   'latitude': 32.858805940803386,
#   'longitude': -117.25890938689217},
#  {'rideId': '16177',
#   'loc1': 'La Jolla',
#   'loc2': 'San Diego',
#   'loc3': 'San Diego County',
#   'startTime': 1563470073,
#   'endTime': 1563472247,
#   'heightSmartfin': 0.621566826362141,
#   'tempSmartfin': 21.213252077562327,
#   'buoyCDIP': '201',
#   'heightCDIP': 0.48000001907348633,
#   'tempCDIP': 20.704288482666016,
#   'latitude': 32.85922895744681,
#   'longitude': -117.25751921276596},
#  {'rideId': '16175',
#   'loc1': 'La Jolla',
#   'loc2': 'San Diego County',
#   'loc3': 'California',
#   'startTime': 1563383452,
#   'endTime': 1563389598,
#   'heightSmartfin': 0.5714897617186816,
#   'tempSmartfin': 20.65331929480901,
#   'buoyCDIP': '201',
#   'heightCDIP': 0.7724999785423279,
#   'tempCDIP': 20.967622756958008,
#   'latitude': 32.850568721088436,
#   'longitude': -117.26388915646258},
#  {'rideId': '16173',
#   'loc1': 'La Jolla',
#   'loc2': 'San Diego',
#   'loc3': 'San Diego County',
#   'startTime': 1562864784,
#   'endTime': 1562868054,
#   'heightSmartfin': 0.49568249578993706,
#   'tempSmartfin': 21.150633517495397,
#   'buoyCDIP': '201',
#   'heightCDIP': 0.7300000190734863,
#   'tempCDIP': 20.565465927124023,
#   'latitude': 32.858570925925925,
#   'longitude': -117.25853464387465},
#  {'rideId': '16171',
#   'loc1': 'La Jolla',
#   'loc2': 'San Diego',
#   'loc3': 'San Diego County',
#   'startTime': 1562689060,
#   'endTime': 1562690855,
#   'heightSmartfin': 0.5522366718274178,
#   'tempSmartfin': 20.26179865771812,
#   'buoyCDIP': '201',
#   'heightCDIP': 0.5699999928474426,
#   'tempCDIP': 19.881668090820312,
#   'latitude': 32.85874451428571,
#   'longitude': -117.25808476190475},
#  {'rideId': '16169',
#   'loc1': 'La Jolla',
#   'loc2': 'San Diego',
#   'loc3': 'San Diego County',
#   'startTime': 1562517902,
#   'endTime': 1562521095,
#   'heightSmartfin': 0.4204739961160755,
#   'tempSmartfin': 19.33209245283019,
#   'buoyCDIP': '201',
#   'heightCDIP': 0.6499999761581421,
#   'tempCDIP': 19.14000701904297,
#   'latitude': 32.859811362962965,
#   'longitude': -117.25809736296296},
#  {'rideId': '16168',
#   'loc1': 'La Jolla',
#   'loc2': 'San Diego',
#   'loc3': 'San Diego County',
#   'startTime': 1562343424,
#   'endTime': 1562347032,
#   'heightSmartfin': 0.528580888368911,
#   'tempSmartfin': 18.534223706176963,
#   'buoyCDIP': '201',
#   'heightCDIP': 0.8350000381469727,
#   'tempCDIP': 18.814170837402344,
#   'latitude': 32.85881072483222,
#   'longitude': -117.25853473825504},
#  {'rideId': '16167',
#   'loc1': 'La Jolla',
#   'loc2': 'San Diego',
#   'loc3': 'San Diego County',
#   'startTime': 1563224593,
#   'endTime': 1563227025,
#   'heightSmartfin': 0.5220379380877774,
#   'tempSmartfin': 22.757891089108906,
#   'buoyCDIP': '201',
#   'heightCDIP': 0.6899999976158142,
#   'tempCDIP': 22.235004425048828,
#   'latitude': 32.85189403197158,
#   'longitude': -117.26373341030195},
#  {'rideId': '16161',
#   'loc1': 'La Jolla',
#   'loc2': 'San Diego',
#   'loc3': 'San Diego County',
#   'startTime': 1563137308,
#   'endTime': 1563140932,
#   'heightSmartfin': 0.5280891441323716,
#   'tempSmartfin': 22.547958471760797,
#   'buoyCDIP': '201',
#   'heightCDIP': 0.5349999666213989,
#   'tempCDIP': 21.464174270629883,
#   'latitude': 32.85213960509554,
#   'longitude': -117.26298096815286},
#  {'rideId': '16160',
#   'loc1': 'Camino Del Oro',
#   'loc2': 'La Jolla',
#   'loc3': 'San Diego County',
#   'startTime': 1561232374,
#   'endTime': 1561237352,
#   'heightSmartfin': 0.6445993393206252,
#   'tempSmartfin': 19.8430507859734,
#   'buoyCDIP': '201',
#   'heightCDIP': 0.49000000953674316,
#   'tempCDIP': 19.874710083007812,
#   'latitude': 32.853287827903095,
#   'longitude': -117.26176494569758},
#  {'rideId': '16158',
#   'loc1': 'La Jolla',
#   'loc2': 'San Diego',
#   'loc3': 'San Diego County',
#   'startTime': 1562437676,
#   'endTime': 1562442576,
#   'heightSmartfin': 0.6227975974022982,
#   'tempSmartfin': 18.79893243243243,
#   'buoyCDIP': '201',
#   'heightCDIP': 0.8033332824707031,
#   'tempCDIP': 19.29813575744629,
#   'latitude': 32.85082392405064,
#   'longitude': -117.25927487341772},
#  {'rideId': '16152',
#   'loc1': 'Camino Del Oro',
#   'loc2': 'La Jolla',
#   'loc3': 'San Diego County',
#   'startTime': 1562163090,
#   'endTime': 1562168737,
#   'heightSmartfin': 0.6099946371209849,
#   'tempSmartfin': 16.164471215351814,
#   'buoyCDIP': '201',
#   'heightCDIP': 0.9850000143051147,
#   'tempCDIP': 17.457372665405273,
#   'latitude': 32.85353205148206,
#   'longitude': -117.261237925117},
#  {'rideId': '16148',
#   'loc1': 'La Jolla',
#   'loc2': 'San Diego',
#   'loc3': 'San Diego County',
#   'startTime': 1562082142,
#   'endTime': 1562085838,
#   'heightSmartfin': 0.7370040122823286,
#   'tempSmartfin': 17.222762214983714,
#   'buoyCDIP': '201',
#   'heightCDIP': 1.1349999904632568,
#   'tempCDIP': 18.240007400512695,
#   'latitude': 32.85311720990873,
#   'longitude': -117.2608798565841},
#  {'rideId': '16140',
#   'loc1': 'La Jolla',
#   'loc2': 'San Diego County',
#   'loc3': 'California',
#   'startTime': 1561232409,
#   'endTime': 1561236882,
#   'heightSmartfin': 0.36072965927671047,
#   'tempSmartfin': 19.85794616419919,
#   'buoyCDIP': '201',
#   'heightCDIP': 0.49000000953674316,
#   'tempCDIP': 19.86400604248047,
#   'latitude': 32.85238995881384,
#   'longitude': -117.26468888797363},
#  {'rideId': '16137',
#   'loc1': 'La Jolla',
#   'loc2': 'San Diego',
#   'loc3': 'San Diego County',
#   'startTime': 1560962575,
#   'endTime': 1560965033,
#   'heightSmartfin': 0.2833940627684416,
#   'tempSmartfin': 18.939855392156865,
#   'buoyCDIP': '201',
#   'heightCDIP': 0.5550000071525574,
#   'tempCDIP': 19.28500747680664,
#   'latitude': 32.85913866920152,
#   'longitude': -117.25823593155894},
#  {'rideId': '16135',
#   'loc1': 'La Jolla',
#   'loc2': 'San Diego',
#   'loc3': 'San Diego County',
#   'startTime': 1560531654,
#   'endTime': 1560534305,
#   'heightSmartfin': 0.3968926971374553,
#   'tempSmartfin': 19.571597727272728,
#   'buoyCDIP': '201',
#   'heightCDIP': 0.6150000095367432,
#   'tempCDIP': 19.8577880859375,
#   'latitude': 32.85932654320988,
#   'longitude': -117.25785539682539},
#  {'rideId': '16134',
#   'loc1': 'La Jolla',
#   'loc2': 'San Diego',
#   'loc3': 'San Diego County',
#   'startTime': 1560270066,
#   'endTime': 1560273109,
#   'heightSmartfin': 0.3515648229045688,
#   'tempSmartfin': 19.904956435643566,
#   'buoyCDIP': '201',
#   'heightCDIP': 0.44999998807907104,
#   'tempCDIP': 19.531005859375,
#   'latitude': 32.85987874418605,
#   'longitude': -117.25794848062016},
#  {'rideId': '16128',
#   'loc1': 'La Jolla',
#   'loc2': 'San Diego',
#   'loc3': 'San Diego County',
#   'startTime': 1560628868,
#   'endTime': 1560633106,
#   'heightSmartfin': 0.6307692597542487,
#   'tempSmartfin': 20.751139204545453,
#   'buoyCDIP': '201',
#   'heightCDIP': 0.5550000071525574,
#   'tempCDIP': 20.499292373657227,
#   'latitude': 32.85607747348119,
#   'longitude': -117.25992567984572},
#  {'rideId': '16126',
#   'loc1': 'La Jolla',
#   'loc2': 'San Diego',
#   'loc3': 'San Diego County',
#   'startTime': 1560628941,
#   'endTime': 1560633101,
#   'heightSmartfin': 0.5532440526363992,
#   'tempSmartfin': 20.460031837916066,
#   'buoyCDIP': '201',
#   'heightCDIP': 0.5550000071525574,
#   'tempCDIP': 20.499292373657227,
#   'latitude': 32.85586644400786,
#   'longitude': -117.26044271119842},
#  {'rideId': '16115',
#   'loc1': 'La Jolla',
#   'loc2': 'San Diego',
#   'loc3': 'San Diego County',
#   'startTime': 1559919895,
#   'endTime': 1559922321,
#   'heightSmartfin': 0.7739041667096287,
#   'tempSmartfin': 17.57927047146402,
#   'buoyCDIP': '201',
#   'heightCDIP': 0.6650000214576721,
#   'tempCDIP': 17.855010986328125,
#   'latitude': 32.85879590982287,
#   'longitude': -117.2588501610306},
#  {'rideId': '16106',
#   'loc1': 'La Jolla',
#   'loc2': 'San Diego',
#   'loc3': 'San Diego County',
#   'startTime': 1559318176,
#   'endTime': 1559322739,
#   'heightSmartfin': 0.8666619215905952,
#   'tempSmartfin': 18.0425,
#   'buoyCDIP': '201',
#   'heightCDIP': 0.7899999618530273,
#   'tempCDIP': 18.33333969116211,
#   'latitude': 32.85095126126126,
#   'longitude': -117.25945306306306},
#  {'rideId': '16103',
#   'loc1': 'La Jolla',
#   'loc2': 'San Diego',
#   'loc3': 'San Diego County',
#   'startTime': 1559143002,
#   'endTime': 1559148077,
#   'heightSmartfin': 0.9466108802237144,
#   'tempSmartfin': 17.682581257413997,
#   'buoyCDIP': '201',
#   'heightCDIP': 1.0950000286102295,
#   'tempCDIP': 18.08235740661621,
#   'latitude': 32.85746011885895,
#   'longitude': -117.25890274167986},
#  {'rideId': '16101',
#   'loc1': 'La Jolla',
#   'loc2': 'San Diego',
#   'loc3': 'San Diego County',
#   'startTime': 1558823027,
#   'endTime': 1558828499,
#   'heightSmartfin': 0.3748512059225787,
#   'tempSmartfin': 18.607677667766776,
#   'buoyCDIP': '201',
#   'heightCDIP': 0.6066666841506958,
#   'tempCDIP': 18.718894958496094,
#   'latitude': 32.85277942655145,
#   'longitude': -117.26547062843677},
#  {'rideId': '16100',
#   'loc1': 'La Jolla',
#   'loc2': 'San Diego',
#   'loc3': 'San Diego County',
#   'startTime': 1559056545,
#   'endTime': 1559062529,
#   'heightSmartfin': 0.5798144840241994,
#   'tempSmartfin': 16.84068209255533,
#   'buoyCDIP': '201',
#   'heightCDIP': 0.9300000667572021,
#   'tempCDIP': 17.44100570678711,
#   'latitude': 32.85765806340455,
#   'longitude': -117.25901885596141},
#  {'rideId': '16099',
#   'loc1': 'La Jolla',
#   'loc2': 'San Diego',
#   'loc3': 'San Diego County',
#   'startTime': 1558823025,
#   'endTime': 1558826186,
#   'heightSmartfin': 5.86383570724265,
#   'tempSmartfin': 18.571798095238094,
#   'buoyCDIP': '201',
#   'heightCDIP': 0.5900000333786011,
#   'tempCDIP': 18.721004486083984,
#   'latitude': 32.85298346153846,
#   'longitude': -117.26731449704143},
#  {'rideId': '16098',
#   'loc1': 'Camino Del Oro',
#   'loc2': 'La Jolla',
#   'loc3': 'San Diego County',
#   'startTime': 1558211047,
#   'endTime': 1558213738,
#   'heightSmartfin': 0.6585840842332937,
#   'tempSmartfin': 18.527776286353465,
#   'buoyCDIP': '201',
#   'heightCDIP': 0.9700000286102295,
#   'tempCDIP': 18.89444923400879,
#   'latitude': 32.852913629842185,
#   'longitude': -117.2614705882353},
#  {'rideId': '16088',
#   'loc1': 'Camino Del Oro',
#   'loc2': 'La Jolla',
#   'loc3': 'San Diego County',
#   'startTime': 1558211041,
#   'endTime': 1558213093,
#   'heightSmartfin': 0.7021443095937877,
#   'tempSmartfin': 18.33839882697947,
#   'buoyCDIP': '201',
#   'heightCDIP': 0.9700000286102295,
#   'tempCDIP': 18.905717849731445,
#   'latitude': 32.85282484154929,
#   'longitude': -117.26272632042253},
#  {'rideId': '16081',
#   'loc1': 'La Jolla',
#   'loc2': 'San Diego',
#   'loc3': 'San Diego County',
#   'startTime': 1557934646,
#   'endTime': 1557939672,
#   'heightSmartfin': 0.5629105544765778,
#   'tempSmartfin': 18.71829341317365,
#   'buoyCDIP': '201',
#   'heightCDIP': 0.5566666722297668,
#   'tempCDIP': 18.76412582397461,
#   'latitude': 32.85092397590361,
#   'longitude': -117.25940457831325},
#  {'rideId': '16079',
#   'loc1': 'La Jolla',
#   'loc2': 'San Diego',
#   'loc3': 'San Diego County',
#   'startTime': 1557846355,
#   'endTime': 1557854897,
#   'heightSmartfin': 0.5343034566572307,
#   'tempSmartfin': 18.3360584918957,
#   'buoyCDIP': '201',
#   'heightCDIP': 0.515999972820282,
#   'tempCDIP': 18.531389236450195,
#   'latitude': 32.85085329842932,
#   'longitude': -117.25934392670156},
#  {'rideId': '16076',
#   'loc1': 'La Jolla',
#   'loc2': 'San Diego',
#   'loc3': 'San Diego County',
#   'startTime': 1557705920,
#   'endTime': 1557709153,
#   'heightSmartfin': 0.5321975203481288,
#   'tempSmartfin': 19.275597765363127,
#   'buoyCDIP': '201',
#   'heightCDIP': 0.8600000143051147,
#   'tempCDIP': 18.870006561279297,
#   'latitude': 32.85121489932886,
#   'longitude': -117.25966557046979},
#  {'rideId': '16075',
#   'loc1': 'Camino Del Oro',
#   'loc2': 'La Jolla',
#   'loc3': 'San Diego County',
#   'startTime': 1557705787,
#   'endTime': 1557709044,
#   'heightSmartfin': 0.625128594193755,
#   'tempSmartfin': 19.27739926062847,
#   'buoyCDIP': '201',
#   'heightCDIP': 0.8600000143051147,
#   'tempCDIP': 18.8750057220459,
#   'latitude': 32.85313267313019,
#   'longitude': -117.26268718836565},
#  {'rideId': '16073',
#   'loc1': 'Camino Del Oro',
#   'loc2': 'La Jolla',
#   'loc3': 'San Diego County',
#   'startTime': 1557093607,
#   'endTime': 1557096623,
#   'heightSmartfin': 0.5526880437476933,
#   'tempSmartfin': 18.892421157684634,
#   'buoyCDIP': '201',
#   'heightCDIP': 0.5550000071525574,
#   'tempCDIP': 18.606008529663086,
#   'latitude': 32.85342570687419,
#   'longitude': -117.26251968871595},
#  {'rideId': '16072',
#   'loc1': 'Camino Del Oro',
#   'loc2': 'La Jolla',
#   'loc3': 'San Diego County',
#   'startTime': 1557005556,
#   'endTime': 1557008867,
#   'heightSmartfin': 0.42121212508304046,
#   'tempSmartfin': 19.21462909090909,
#   'buoyCDIP': '201',
#   'heightCDIP': 0.550000011920929,
#   'tempCDIP': 19.0445499420166,
#   'latitude': 32.85253822274881,
#   'longitude': -117.26429058056873},
#  {'rideId': '15996',
#   'loc1': 'La Jolla',
#   'loc2': 'San Diego',
#   'loc3': 'San Diego County',
#   'startTime': 1552669635,
#   'endTime': 1552672639,
#   'heightSmartfin': 0.5384636597695007,
#   'tempSmartfin': 15.83214629258517,
#   'buoyCDIP': '201',
#   'heightCDIP': 0.41499999165534973,
#   'tempCDIP': 15.511007308959961,
#   'latitude': 32.852096089030205,
#   'longitude': -117.26316233704293},
#  {'rideId': '15983',
#   'loc1': 'Camino Del Oro',
#   'loc2': 'La Jolla',
#   'loc3': 'San Diego County',
#   'startTime': 1551392840,
#   'endTime': 1551395458,
#   'heightSmartfin': 0.6335982351252639,
#   'tempSmartfin': 16.803871264367814,
#   'buoyCDIP': '201',
#   'heightCDIP': 0.6299999952316284,
#   'tempCDIP': 16.140005111694336,
#   'latitude': 32.85241135325132,
#   'longitude': -117.26355103690686},
#  {'rideId': '15980',
#   'loc1': 'La Jolla',
#   'loc2': 'San Diego',
#   'loc3': 'San Diego County',
#   'startTime': 1551215592,
#   'endTime': 1551218223,
#   'heightSmartfin': 1.3126418245845508,
#   'tempSmartfin': 15.413704805491992,
#   'buoyCDIP': '201',
#   'heightCDIP': 0.2849999964237213,
#   'tempCDIP': 14.805004119873047,
#   'latitude': 32.85171376271187,
#   'longitude': -117.2636506779661},
#  {'rideId': '15978',
#   'loc1': 'Camino Del Oro',
#   'loc2': 'La Jolla',
#   'loc3': 'San Diego County',
#   'startTime': 1551130785,
#   'endTime': 1551133946,
#   'heightSmartfin': 0.4958321926134144,
#   'tempSmartfin': 15.80256952380952,
#   'buoyCDIP': '201',
#   'heightCDIP': 0.48500001430511475,
#   'tempCDIP': 15.232007026672363,
#   'latitude': 32.853556362297496,
#   'longitude': -117.26174509572901},
#  {'rideId': '15972',
#   'loc1': 'La Jolla',
#   'loc2': 'San Diego',
#   'loc3': 'San Diego County',
#   'startTime': 1551058379,
#   'endTime': 1551062925,
#   'heightSmartfin': 0.6531221269397142,
#   'tempSmartfin': 14.210163999999999,
#   'buoyCDIP': '201',
#   'heightCDIP': 0.5066666603088379,
#   'tempCDIP': 14.64267349243164,
#   'latitude': 32.86464311403509,
#   'longitude': -117.2420797368421},
#  {'rideId': '15963',
#   'loc1': 'La Jolla',
#   'loc2': 'San Diego',
#   'loc3': 'San Diego County',
#   'startTime': 1550861140,
#   'endTime': 1550864375,
#   'heightSmartfin': 0.8751134002551536,
#   'tempSmartfin': 15.065393258426967,
#   'buoyCDIP': '201',
#   'heightCDIP': 0.8700000047683716,
#   'tempCDIP': 14.3972749710083,
#   'latitude': 32.85846145936982,
#   'longitude': -117.25730747927032},
#  {'rideId': '15962',
#   'loc1': 'La Jolla',
#   'loc2': 'San Diego',
#   'loc3': 'San Diego County',
#   'startTime': 1549646446,
#   'endTime': 1549650591,
#   'heightSmartfin': 0.46403378477939916,
#   'tempSmartfin': 15.612076023391813,
#   'buoyCDIP': '201',
#   'heightCDIP': 0.4449999928474426,
#   'tempCDIP': 15.48358154296875,
#   'latitude': 32.86094989371125,
#   'longitude': -117.25207212577502},
#  {'rideId': '15953',
#   'loc1': 'Camino Del Oro',
#   'loc2': 'La Jolla',
#   'loc3': 'San Diego County',
#   'startTime': 1550004572,
#   'endTime': 1550006781,
#   'heightSmartfin': 0.7336012494335505,
#   'tempSmartfin': 16.578817438692095,
#   'buoyCDIP': '201',
#   'heightCDIP': 0.5400000214576721,
#   'tempCDIP': 15.83428955078125,
#   'latitude': 32.853252242798355,
#   'longitude': -117.2632474691358},
#  {'rideId': '15945',
#   'loc1': 'La Jolla',
#   'loc2': 'San Diego',
#   'loc3': 'San Diego County',
#   'startTime': 1549749585,
#   'endTime': 1549752715,
#   'heightSmartfin': 0.4130687409449136,
#   'tempSmartfin': 15.729092307692307,
#   'buoyCDIP': '201',
#   'heightCDIP': 0.3149999976158142,
#   'tempCDIP': 15.497003555297852,
#   'latitude': 32.85223186797753,
#   'longitude': -117.26420502808988},
#  {'rideId': '15859',
#   'loc1': 'La Jolla',
#   'loc2': 'San Diego',
#   'loc3': 'San Diego County',
#   'startTime': 1546718751,
#   'endTime': 1546721743,
#   'heightSmartfin': 0.7219074882063148,
#   'tempSmartfin': 15.12332394366197,
#   'buoyCDIP': '201',
#   'heightCDIP': 0.4650000035762787,
#   'tempCDIP': 15.483007431030273,
#   'latitude': 32.85307128440367,
#   'longitude': -117.25966834862385},
#  {'rideId': '15858',
#   'loc1': 'La Jolla',
#   'loc2': 'San Diego County',
#   'loc3': 'California',
#   'startTime': 1546718595,
#   'endTime': 1546720623,
#   'heightSmartfin': 0.6456327123294124,
#   'tempSmartfin': 15.260178041543025,
#   'buoyCDIP': '201',
#   'heightCDIP': 0.4699999988079071,
#   'tempCDIP': 15.510009765625,
#   'latitude': 32.85177325695581,
#   'longitude': -117.26428310965629},
#  {'rideId': '15857',
#   'loc1': 'La Jolla',
#   'loc2': 'San Diego',
#   'loc3': 'San Diego County',
#   'startTime': 1546621448,
#   'endTime': 1546626632,
#   'heightSmartfin': 0.4667968559896883,
#   'tempSmartfin': 15.337380232558141,
#   'buoyCDIP': '201',
#   'heightCDIP': 0.41999998688697815,
#   'tempCDIP': 15.606475830078125,
#   'latitude': 32.85934398642095,
#   'longitude': -117.25784849660523},
#  {'rideId': '15856',
#   'loc1': 'La Jolla',
#   'loc2': 'San Diego',
#   'loc3': 'San Diego County',
#   'startTime': 1546538965,
#   'endTime': 1546541026,
#   'heightSmartfin': 0.33065953780985163,
#   'tempSmartfin': 15.171859649122807,
#   'buoyCDIP': '201',
#   'heightCDIP': 0.4099999964237213,
#   'tempCDIP': 15.62714958190918,
#   'latitude': 32.8589860130719,
#   'longitude': -117.25814032085562},
#  {'rideId': '15854',
#   'loc1': 'La Jolla',
#   'loc2': 'San Diego',
#   'loc3': 'San Diego County',
#   'startTime': 1546626437,
#   'endTime': 1546633011,
#   'heightSmartfin': 0.5808067594807285,
#   'tempSmartfin': 15.583867216117214,
#   'buoyCDIP': '201',
#   'heightCDIP': 0.4099999964237213,
#   'tempCDIP': 15.855911254882812,
#   'latitude': 32.859459670975326,
#   'longitude': -117.25808851938896},
#  {'rideId': '15848',
#   'loc1': 'La Jolla',
#   'loc2': 'San Diego',
#   'loc3': 'San Diego County',
#   'startTime': 1546365100,
#   'endTime': 1546367878,
#   'heightSmartfin': 0.5286699403101088,
#   'tempSmartfin': 15.232898047722344,
#   'buoyCDIP': '201',
#   'heightCDIP': 0.49000000953674316,
#   'tempCDIP': 15.576013565063477,
#   'latitude': 32.8586828928047,
#   'longitude': -117.25857917767989},
#  {'rideId': '16380',
#   'loc1': 'La Jolla',
#   'loc2': 'San Diego',
#   'loc3': 'San Diego County',
#   'startTime': 1576007501,
#   'endTime': 1576009710,
#   'heightSmartfin': 0.5548853024235092,
#   'tempSmartfin': 17.33151226158038,
#   'buoyCDIP': '201',
#   'heightCDIP': 0.7799999713897705,
#   'tempCDIP': 17.3487548828125,
#   'latitude': 32.85199169871795,
#   'longitude': -117.26305794871794},
#  {'rideId': '15692',
#   'loc1': 'La Jolla',
#   'loc2': 'San Diego',
#   'loc3': 'San Diego County',
#   'startTime': 1541791072,
#   'endTime': 1541794669,
#   'heightSmartfin': 0.45559016163497096,
#   'tempSmartfin': 20.044069023569023,
#   'buoyCDIP': '201',
#   'heightCDIP': 0.4414551854133606,
#   'tempCDIP': 19.860002517700195,
#   'latitude': 32.86058653508772,
#   'longitude': -117.25365867324561},
#  {'rideId': 'Sfin-33002a001847363439353035-190712-133655',
#   'loc1': 'Pacific Beach',
#   'loc2': 'San Diego',
#   'loc3': 'San Diego County',
#   'startTime': 1562938616,
#   'endTime': 1562938763,
#   'heightSmartfin': 0.11838336873968074,
#   'tempSmartfin': 19.404572147651006,
#   'buoyCDIP': '201',
#   'heightCDIP': 0.699999988079071,
#   'tempCDIP': 20.94000244140625,
#   'latitude': 32.80280932258066,
#   'longitude': -117.26243596774194},
#  {'rideId': 'Sfin-33002a001847363439353035-190611-050835',
#   'loc1': 'Fiskebäckskil',
#   'loc2': 'Västra Götalands län',
#   'loc3': 'Sweden',
#   'startTime': 1560229716,
#   'endTime': 1560229875,
#   'heightSmartfin': 0.3059217567528088,
#   'tempSmartfin': 15.187985248447205,
#   'buoyCDIP': '160',
#   'heightCDIP': 0.8799999952316284,
#   'tempCDIP': 13.299999237060547,
#   'latitude': 58.24980933540374,
#   'longitude': 11.446197658385092},
#  {'rideId': 'Sfin-1a0027001047373333353132-190823-132803',
#   'loc1': 'La Jolla',
#   'loc2': 'San Diego',
#   'loc3': 'San Diego County',
#   'startTime': 1566566884,
#   'endTime': 1566570362,
#   'heightSmartfin': 0.281283425601486,
#   'tempSmartfin': 19.139231209982537,
#   'buoyCDIP': '201',
#   'heightCDIP': 0.5449999570846558,
#   'tempCDIP': 20.24000358581543,
#   'latitude': 32.80550161320754,
#   'longitude': -117.26359421698113},
#  {'rideId': 'Sfin-33002a001847363439353035-190613-202618',
#   'loc1': 'Lysekil S',
#   'loc2': 'Fiskebäckskil',
#   'loc3': 'Västra Götalands län',
#   'startTime': 1560457579,
#   'endTime': 1560457640,
#   'heightSmartfin': 0.14820025140417228,
#   'tempSmartfin': 14.401965725806452,
#   'buoyCDIP': '160',
#   'heightCDIP': 1.4800000190734863,
#   'tempCDIP': 11.399999618530273,
#   'latitude': 58.25426887096774,
#   'longitude': 11.45098541935484},
#  {'rideId': 'Sfin-3a0025001047373333353132-190818-171215',
#   'loc1': 'Ocean City',
#   'loc2': 'Cape May County',
#   'loc3': 'New Jersey',
#   'startTime': 1566148335,
#   'endTime': 1566151475,
#   'heightSmartfin': 0.028016691875265096,
#   'tempSmartfin': -33.36292467398765,
#   'buoyCDIP': '209',
#   'heightCDIP': 0.9350000023841858,
#   'tempCDIP': 25.575000762939453,
#   'latitude': 39.287038811188815,
#   'longitude': -74.55268051748251},
#  {'rideId': 'Sfin-33002a001847363439353035-190712-125339',
#   'loc1': 'Pacific Beach',
#   'loc2': 'San Diego',
#   'loc3': 'San Diego County',
#   'startTime': 1562936020,
#   'endTime': 1562938340,
#   'heightSmartfin': 0.18665585174876706,
#   'tempSmartfin': 19.583834909716252,
#   'buoyCDIP': '201',
#   'heightCDIP': 0.6100000143051147,
#   'tempCDIP': 20.96286392211914,
#   'latitude': 32.80309041454545,
#   'longitude': -117.26258958181819}]

# %% [markdown]
# ## Get field(s) of ride(s)
# gets a single attribute of a ride in the database. If count = 1, then we only retrieve the specified ride id, if count > 1, retrieve that amount of rides randomly

# %%
fields = 'heightSmartfin,heightCDIP'


if testing:
    fieldGetSingle = f'http://127.0.0.1:8000/ride/rides/rideId={rideId}/fields={fields}' # creates new ride and upload all ride data to db
else:
    fieldGetSingle = f'{domainName}/ride/rides/rideId={rideId}/fields={fields}' # creates new ride and upload all ride data to db

response = requests.get(fieldGetSingle).json()
response
# Out:
# {'rideId': 'Sfin-3a0025001047373333353132-190818-171215',
#  'heightSmartfin': 0.028016691875265096,
#  'heightCDIP': 0.9350000023841858}

# %% [markdown]
# ### get fields of rides by location

# %%
location = 'San Diego'

if testing:
    fieldGetLocation = f'http://127.0.0.1:8000/ride/rides/location={location}/fields={fields}' # creates new ride and upload all ride data to db
else:
    fieldGetLocation = f'{domainName}/ride/rides/location={location}/fields={fields}' # creates new ride and upload all ride data to db

response = requests.get(fieldGetLocation)
response.json()['data']
# Out:
# [{'rideId': '16000',
#   'heightSmartfin': 0.40845185873427914,
#   'heightCDIP': 0.45499998331069946},
#  {'rideId': '16345',
#   'heightSmartfin': 0.3808737691417218,
#   'heightCDIP': 0.5349999666213989},
#  {'rideId': '16318',
#   'heightSmartfin': 0.5428762299265988,
#   'heightCDIP': 0.6299999952316284},
#  {'rideId': '16302',
#   'heightSmartfin': 0.6718289115566997,
#   'heightCDIP': 0.39499998092651367},
#  {'rideId': '16301',
#   'heightSmartfin': 0.4013681093396742,
#   'heightCDIP': 0.5299999713897705},
#  {'rideId': '16298',
#   'heightSmartfin': 0.6791315978701143,
#   'heightCDIP': 1.1050000190734863},
#  {'rideId': '16290',
#   'heightSmartfin': 1.3446089018207055,
#   'heightCDIP': 1.065000057220459},
#  {'rideId': '16289',
#   'heightSmartfin': 0.6124114661985623,
#   'heightCDIP': 0.9399999976158142},
#  {'rideId': '16250',
#   'heightSmartfin': 0.5308156496001618,
#   'heightCDIP': 0.5099999904632568},
#  {'rideId': '16249',
#   'heightSmartfin': 0.3141288025546928,
#   'heightCDIP': 0.3774999976158142},
#  {'rideId': '16239',
#   'heightSmartfin': 0.6949528728123969,
#   'heightCDIP': 0.5119999647140503},
#  {'rideId': '16238',
#   'heightSmartfin': 0.3230272591645206,
#   'heightCDIP': 0.34666669368743896},
#  {'rideId': '16237',
#   'heightSmartfin': 0.30515738118656105,
#   'heightCDIP': 0.3500000238418579},
#  {'rideId': '16225',
#   'heightSmartfin': 0.5617861937189434,
#   'heightCDIP': 0.5666666626930237},
#  {'rideId': '16222',
#   'heightSmartfin': 0.4888846897250368,
#   'heightCDIP': 0.550000011920929},
#  {'rideId': '16221',
#   'heightSmartfin': 0.46394038356167805,
#   'heightCDIP': 0.550000011920929},
#  {'rideId': '16212',
#   'heightSmartfin': 0.4103094581106867,
#   'heightCDIP': 0.6399999856948853},
#  {'rideId': '16211',
#   'heightSmartfin': 0.5039792322452558,
#   'heightCDIP': 0.6000000238418579},
#  {'rideId': '16197',
#   'heightSmartfin': 0.8283634273375001,
#   'heightCDIP': 0.6349999904632568},
#  {'rideId': '16195',
#   'heightSmartfin': 0.4343562987458954,
#   'heightCDIP': 0.675000011920929},
#  {'rideId': '16192',
#   'heightSmartfin': 0.5017183758555545,
#   'heightCDIP': 0.9850000143051147},
#  {'rideId': '16191',
#   'heightSmartfin': 0.642197994479234,
#   'heightCDIP': 0.8299999833106995},
#  {'rideId': '16178',
#   'heightSmartfin': 0.4704977184591453,
#   'heightCDIP': 0.6200000047683716},
#  {'rideId': '16177',
#   'heightSmartfin': 0.621566826362141,
#   'heightCDIP': 0.48000001907348633},
#  {'rideId': '16173',
#   'heightSmartfin': 0.49568249578993706,
#   'heightCDIP': 0.7300000190734863},
#  {'rideId': '16171',
#   'heightSmartfin': 0.5522366718274178,
#   'heightCDIP': 0.5699999928474426},
#  {'rideId': '16169',
#   'heightSmartfin': 0.4204739961160755,
#   'heightCDIP': 0.6499999761581421},
#  {'rideId': '16168',
#   'heightSmartfin': 0.528580888368911,
#   'heightCDIP': 0.8350000381469727},
#  {'rideId': '16167',
#   'heightSmartfin': 0.5220379380877774,
#   'heightCDIP': 0.6899999976158142},
#  {'rideId': '16161',
#   'heightSmartfin': 0.5280891441323716,
#   'heightCDIP': 0.5349999666213989},
#  {'rideId': '16158',
#   'heightSmartfin': 0.6227975974022982,
#   'heightCDIP': 0.8033332824707031},
#  {'rideId': '16148',
#   'heightSmartfin': 0.7370040122823286,
#   'heightCDIP': 1.1349999904632568},
#  {'rideId': '16137',
#   'heightSmartfin': 0.2833940627684416,
#   'heightCDIP': 0.5550000071525574},
#  {'rideId': '16135',
#   'heightSmartfin': 0.3968926971374553,
#   'heightCDIP': 0.6150000095367432},
#  {'rideId': '16134',
#   'heightSmartfin': 0.3515648229045688,
#   'heightCDIP': 0.44999998807907104},
#  {'rideId': '16128',
#   'heightSmartfin': 0.6307692597542487,
#   'heightCDIP': 0.5550000071525574},
#  {'rideId': '16126',
#   'heightSmartfin': 0.5532440526363992,
#   'heightCDIP': 0.5550000071525574},
#  {'rideId': '16115',
#   'heightSmartfin': 0.7739041667096287,
#   'heightCDIP': 0.6650000214576721},
#  {'rideId': '16106',
#   'heightSmartfin': 0.8666619215905952,
#   'heightCDIP': 0.7899999618530273},
#  {'rideId': '16103',
#   'heightSmartfin': 0.9466108802237144,
#   'heightCDIP': 1.0950000286102295},
#  {'rideId': '16101',
#   'heightSmartfin': 0.3748512059225787,
#   'heightCDIP': 0.6066666841506958},
#  {'rideId': '16100',
#   'heightSmartfin': 0.5798144840241994,
#   'heightCDIP': 0.9300000667572021},
#  {'rideId': '16099',
#   'heightSmartfin': 5.86383570724265,
#   'heightCDIP': 0.5900000333786011},
#  {'rideId': '16081',
#   'heightSmartfin': 0.5629105544765778,
#   'heightCDIP': 0.5566666722297668},
#  {'rideId': '16079',
#   'heightSmartfin': 0.5343034566572307,
#   'heightCDIP': 0.515999972820282},
#  {'rideId': '16076',
#   'heightSmartfin': 0.5321975203481288,
#   'heightCDIP': 0.8600000143051147},
#  {'rideId': '15996',
#   'heightSmartfin': 0.5384636597695007,
#   'heightCDIP': 0.41499999165534973},
#  {'rideId': '15980',
#   'heightSmartfin': 1.3126418245845508,
#   'heightCDIP': 0.2849999964237213},
#  {'rideId': '15972',
#   'heightSmartfin': 0.6531221269397142,
#   'heightCDIP': 0.5066666603088379},
#  {'rideId': '15963',
#   'heightSmartfin': 0.8751134002551536,
#   'heightCDIP': 0.8700000047683716},
#  {'rideId': '15962',
#   'heightSmartfin': 0.46403378477939916,
#   'heightCDIP': 0.4449999928474426},
#  {'rideId': '15945',
#   'heightSmartfin': 0.4130687409449136,
#   'heightCDIP': 0.3149999976158142},
#  {'rideId': '15859',
#   'heightSmartfin': 0.7219074882063148,
#   'heightCDIP': 0.4650000035762787},
#  {'rideId': '15857',
#   'heightSmartfin': 0.4667968559896883,
#   'heightCDIP': 0.41999998688697815},
#  {'rideId': '15856',
#   'heightSmartfin': 0.33065953780985163,
#   'heightCDIP': 0.4099999964237213},
#  {'rideId': '15854',
#   'heightSmartfin': 0.5808067594807285,
#   'heightCDIP': 0.4099999964237213},
#  {'rideId': '15848',
#   'heightSmartfin': 0.5286699403101088,
#   'heightCDIP': 0.49000000953674316},
#  {'rideId': '16380',
#   'heightSmartfin': 0.5548853024235092,
#   'heightCDIP': 0.7799999713897705},
#  {'rideId': '15692',
#   'heightSmartfin': 0.45559016163497096,
#   'heightCDIP': 0.4414551854133606},
#  {'rideId': 'Sfin-33002a001847363439353035-190712-133655',
#   'heightSmartfin': 0.11838336873968074,
#   'heightCDIP': 0.699999988079071},
#  {'rideId': 'Sfin-1a0027001047373333353132-190823-132803',
#   'heightSmartfin': 0.281283425601486,
#   'heightCDIP': 0.5449999570846558},
#  {'rideId': 'Sfin-33002a001847363439353035-190712-125339',
#   'heightSmartfin': 0.18665585174876706,
#   'heightCDIP': 0.6100000143051147}]

# %% [markdown]
# ### get fields of rides by date

# %%
startDate = '1541030400'
endDate = '2552566400'

if testing:
    fieldGetDate = f'http://127.0.0.1:8000/ride/rides/startDate={startDate},endDate={endDate}/fields={fields}' # creates new ride and upload all ride data to db
else:
    fieldGetDate = f'{domainName}/ride/rides/startDate={startDate},endDate={endDate}/fields={fields}' # creates new ride and upload all ride data to db

    

response = requests.get(fieldGetDate).json()
response
# Out:
# {'data': [{'rideId': '16000',
#    'heightSmartfin': 0.40845185873427914,
#    'heightCDIP': 0.45499998331069946},
#   {'rideId': '16376',
#    'heightSmartfin': 0.9460319998263358,
#    'heightCDIP': 0.7250000238418579},
#   {'rideId': '16345',
#    'heightSmartfin': 0.3808737691417218,
#    'heightCDIP': 0.5349999666213989},
#   {'rideId': '16318',
#    'heightSmartfin': 0.5428762299265988,
#    'heightCDIP': 0.6299999952316284},
#   {'rideId': '16302',
#    'heightSmartfin': 0.6718289115566997,
#    'heightCDIP': 0.39499998092651367},
#   {'rideId': '16301',
#    'heightSmartfin': 0.4013681093396742,
#    'heightCDIP': 0.5299999713897705},
#   {'rideId': '16300',
#    'heightSmartfin': 0.49562878481694916,
#    'heightCDIP': 0.6200000047683716},
#   {'rideId': '16299',
#    'heightSmartfin': 0.43162395826775946,
#    'heightCDIP': 0.5699999928474426},
#   {'rideId': '16298',
#    'heightSmartfin': 0.6791315978701143,
#    'heightCDIP': 1.1050000190734863},
#   {'rideId': '16297',
#    'heightSmartfin': 0.43871618389742056,
#    'heightCDIP': 0.574999988079071},
#   {'rideId': '16290',
#    'heightSmartfin': 1.3446089018207055,
#    'heightCDIP': 1.065000057220459},
#   {'rideId': '16289',
#    'heightSmartfin': 0.6124114661985623,
#    'heightCDIP': 0.9399999976158142},
#   {'rideId': '16278',
#    'heightSmartfin': 13.402122248843234,
#    'heightCDIP': 0.9399999976158142},
#   {'rideId': '16262',
#    'heightSmartfin': 0.5257326257318952,
#    'heightCDIP': 0.5399999618530273},
#   {'rideId': '16253',
#    'heightSmartfin': 0.7603094257000951,
#    'heightCDIP': 0.8999999761581421},
#   {'rideId': '16252',
#    'heightSmartfin': 0.5244763530689744,
#    'heightCDIP': 0.7649999856948853},
#   {'rideId': '16250',
#    'heightSmartfin': 0.5308156496001618,
#    'heightCDIP': 0.5099999904632568},
#   {'rideId': '16249',
#    'heightSmartfin': 0.3141288025546928,
#    'heightCDIP': 0.3774999976158142},
#   {'rideId': '16243',
#    'heightSmartfin': 0.6210725285853507,
#    'heightCDIP': 0.8650000095367432},
#   {'rideId': '16239',
#    'heightSmartfin': 0.6949528728123969,
#    'heightCDIP': 0.5119999647140503},
#   {'rideId': '16238',
#    'heightSmartfin': 0.3230272591645206,
#    'heightCDIP': 0.34666669368743896},
#   {'rideId': '16237',
#    'heightSmartfin': 0.30515738118656105,
#    'heightCDIP': 0.3500000238418579},
#   {'rideId': '16225',
#    'heightSmartfin': 0.5617861937189434,
#    'heightCDIP': 0.5666666626930237},
#   {'rideId': '16222',
#    'heightSmartfin': 0.4888846897250368,
#    'heightCDIP': 0.550000011920929},
#   {'rideId': '16221',
#    'heightSmartfin': 0.46394038356167805,
#    'heightCDIP': 0.550000011920929},
#   {'rideId': '16212',
#    'heightSmartfin': 0.4103094581106867,
#    'heightCDIP': 0.6399999856948853},
#   {'rideId': '16211',
#    'heightSmartfin': 0.5039792322452558,
#    'heightCDIP': 0.6000000238418579},
#   {'rideId': '16197',
#    'heightSmartfin': 0.8283634273375001,
#    'heightCDIP': 0.6349999904632568},
#   {'rideId': '16196',
#    'heightSmartfin': 5.443058418243037,
#    'heightCDIP': 0.675000011920929},
#   {'rideId': '16195',
#    'heightSmartfin': 0.4343562987458954,
#    'heightCDIP': 0.675000011920929},
#   {'rideId': '16192',
#    'heightSmartfin': 0.5017183758555545,
#    'heightCDIP': 0.9850000143051147},
#   {'rideId': '16191',
#    'heightSmartfin': 0.642197994479234,
#    'heightCDIP': 0.8299999833106995},
#   {'rideId': '16189',
#    'heightSmartfin': 0.37585717800720597,
#    'heightCDIP': 0.6800000071525574},
#   {'rideId': '16178',
#    'heightSmartfin': 0.4704977184591453,
#    'heightCDIP': 0.6200000047683716},
#   {'rideId': '16177',
#    'heightSmartfin': 0.621566826362141,
#    'heightCDIP': 0.48000001907348633},
#   {'rideId': '16175',
#    'heightSmartfin': 0.5714897617186816,
#    'heightCDIP': 0.7724999785423279},
#   {'rideId': '16173',
#    'heightSmartfin': 0.49568249578993706,
#    'heightCDIP': 0.7300000190734863},
#   {'rideId': '16171',
#    'heightSmartfin': 0.5522366718274178,
#    'heightCDIP': 0.5699999928474426},
#   {'rideId': '16169',
#    'heightSmartfin': 0.4204739961160755,
#    'heightCDIP': 0.6499999761581421},
#   {'rideId': '16168',
#    'heightSmartfin': 0.528580888368911,
#    'heightCDIP': 0.8350000381469727},
#   {'rideId': '16167',
#    'heightSmartfin': 0.5220379380877774,
#    'heightCDIP': 0.6899999976158142},
#   {'rideId': '16161',
#    'heightSmartfin': 0.5280891441323716,
#    'heightCDIP': 0.5349999666213989},
#   {'rideId': '16160',
#    'heightSmartfin': 0.6445993393206252,
#    'heightCDIP': 0.49000000953674316},
#   {'rideId': '16158',
#    'heightSmartfin': 0.6227975974022982,
#    'heightCDIP': 0.8033332824707031},
#   {'rideId': '16152',
#    'heightSmartfin': 0.6099946371209849,
#    'heightCDIP': 0.9850000143051147},
#   {'rideId': '16148',
#    'heightSmartfin': 0.7370040122823286,
#    'heightCDIP': 1.1349999904632568},
#   {'rideId': '16140',
#    'heightSmartfin': 0.36072965927671047,
#    'heightCDIP': 0.49000000953674316},
#   {'rideId': '16137',
#    'heightSmartfin': 0.2833940627684416,
#    'heightCDIP': 0.5550000071525574},
#   {'rideId': '16135',
#    'heightSmartfin': 0.3968926971374553,
#    'heightCDIP': 0.6150000095367432},
#   {'rideId': '16134',
#    'heightSmartfin': 0.3515648229045688,
#    'heightCDIP': 0.44999998807907104},
#   {'rideId': '16128',
#    'heightSmartfin': 0.6307692597542487,
#    'heightCDIP': 0.5550000071525574},
#   {'rideId': '16126',
#    'heightSmartfin': 0.5532440526363992,
#    'heightCDIP': 0.5550000071525574},
#   {'rideId': '16115',
#    'heightSmartfin': 0.7739041667096287,
#    'heightCDIP': 0.6650000214576721},
#   {'rideId': '16106',
#    'heightSmartfin': 0.8666619215905952,
#    'heightCDIP': 0.7899999618530273},
#   {'rideId': '16103',
#    'heightSmartfin': 0.9466108802237144,
#    'heightCDIP': 1.0950000286102295},
#   {'rideId': '16101',
#    'heightSmartfin': 0.3748512059225787,
#    'heightCDIP': 0.6066666841506958},
#   {'rideId': '16100',
#    'heightSmartfin': 0.5798144840241994,
#    'heightCDIP': 0.9300000667572021},
#   {'rideId': '16099',
#    'heightSmartfin': 5.86383570724265,
#    'heightCDIP': 0.5900000333786011},
#   {'rideId': '16098',
#    'heightSmartfin': 0.6585840842332937,
#    'heightCDIP': 0.9700000286102295},
#   {'rideId': '16088',
#    'heightSmartfin': 0.7021443095937877,
#    'heightCDIP': 0.9700000286102295},
#   {'rideId': '16081',
#    'heightSmartfin': 0.5629105544765778,
#    'heightCDIP': 0.5566666722297668},
#   {'rideId': '16079',
#    'heightSmartfin': 0.5343034566572307,
#    'heightCDIP': 0.515999972820282},
#   {'rideId': '16076',
#    'heightSmartfin': 0.5321975203481288,
#    'heightCDIP': 0.8600000143051147},
#   {'rideId': '16075',
#    'heightSmartfin': 0.625128594193755,
#    'heightCDIP': 0.8600000143051147},
#   {'rideId': '16073',
#    'heightSmartfin': 0.5526880437476933,
#    'heightCDIP': 0.5550000071525574},
#   {'rideId': '16072',
#    'heightSmartfin': 0.42121212508304046,
#    'heightCDIP': 0.550000011920929},
#   {'rideId': '15996',
#    'heightSmartfin': 0.5384636597695007,
#    'heightCDIP': 0.41499999165534973},
#   {'rideId': '15983',
#    'heightSmartfin': 0.6335982351252639,
#    'heightCDIP': 0.6299999952316284},
#   {'rideId': '15980',
#    'heightSmartfin': 1.3126418245845508,
#    'heightCDIP': 0.2849999964237213},
#   {'rideId': '15978',
#    'heightSmartfin': 0.4958321926134144,
#    'heightCDIP': 0.48500001430511475},
#   {'rideId': '15972',
#    'heightSmartfin': 0.6531221269397142,
#    'heightCDIP': 0.5066666603088379},
#   {'rideId': '15963',
#    'heightSmartfin': 0.8751134002551536,
#    'heightCDIP': 0.8700000047683716},
#   {'rideId': '15962',
#    'heightSmartfin': 0.46403378477939916,
#    'heightCDIP': 0.4449999928474426},
#   {'rideId': '15953',
#    'heightSmartfin': 0.7336012494335505,
#    'heightCDIP': 0.5400000214576721},
#   {'rideId': '15945',
#    'heightSmartfin': 0.4130687409449136,
#    'heightCDIP': 0.3149999976158142},
#   {'rideId': '15859',
#    'heightSmartfin': 0.7219074882063148,
#    'heightCDIP': 0.4650000035762787},
#   {'rideId': '15858',
#    'heightSmartfin': 0.6456327123294124,
#    'heightCDIP': 0.4699999988079071},
#   {'rideId': '15857',
#    'heightSmartfin': 0.4667968559896883,
#    'heightCDIP': 0.41999998688697815},
#   {'rideId': '15856',
#    'heightSmartfin': 0.33065953780985163,
#    'heightCDIP': 0.4099999964237213},
#   {'rideId': '15854',
#    'heightSmartfin': 0.5808067594807285,
#    'heightCDIP': 0.4099999964237213},
#   {'rideId': '15848',
#    'heightSmartfin': 0.5286699403101088,
#    'heightCDIP': 0.49000000953674316},
#   {'rideId': '16380',
#    'heightSmartfin': 0.5548853024235092,
#    'heightCDIP': 0.7799999713897705},
#   {'rideId': '15692',
#    'heightSmartfin': 0.45559016163497096,
#    'heightCDIP': 0.4414551854133606},
#   {'rideId': 'Sfin-33002a001847363439353035-190712-133655',
#    'heightSmartfin': 0.11838336873968074,
#    'heightCDIP': 0.699999988079071},
#   {'rideId': 'Sfin-33002a001847363439353035-190611-050835',
#    'heightSmartfin': 0.3059217567528088,
#    'heightCDIP': 0.8799999952316284},
#   {'rideId': 'Sfin-1a0027001047373333353132-190823-132803',
#    'heightSmartfin': 0.281283425601486,
#    'heightCDIP': 0.5449999570846558},
#   {'rideId': 'Sfin-33002a001847363439353035-190613-202618',
#    'heightSmartfin': 0.14820025140417228,
#    'heightCDIP': 1.4800000190734863},
#   {'rideId': 'Sfin-3a0025001047373333353132-190818-171215',
#    'heightSmartfin': 0.028016691875265096,
#    'heightCDIP': 0.9350000023841858},
#   {'rideId': 'Sfin-33002a001847363439353035-190712-125339',
#    'heightSmartfin': 0.18665585174876706,
#    'heightCDIP': 0.6100000143051147}]}

# %% [markdown]
# ### list all active CDIP buoys

# %%
if testing:
    buoyList = 'http://127.0.0.1:8000/ride/buoys'
else:
    buoyList = f'{domainName}/ride/buoys'

# %%
response = requests.get(buoyList)
data = response.json()
data
# Out:
# ['028',
#  '029',
#  '036',
#  '045',
#  '067',
#  '071',
#  '076',
#  '092',
#  '094',
#  '098',
#  '100',
#  '103',
#  '106',
#  '121',
#  '132',
#  '134',
#  '139',
#  '142',
#  '143',
#  '147',
#  '150',
#  '154',
#  '155',
#  '157',
#  '158',
#  '160',
#  '162',
#  '163',
#  '166',
#  '168',
#  '179',
#  '181',
#  '185',
#  '188',
#  '189',
#  '191',
#  '192',
#  '194',
#  '196',
#  '197',
#  '198',
#  '200',
#  '201',
#  '203',
#  '204',
#  '209',
#  '213',
#  '214',
#  '215',
#  '217',
#  '220',
#  '221',
#  '222',
#  '224',
#  '225',
#  '226',
#  '233',
#  '236',
#  '238',
#  '239',
#  '240',
#  '243',
#  '244',
#  '430',
#  '433']

# %% [markdown]
# ### get dataframes

# %%
dftype= 'motion'


if testing:
    getdf = f'http://127.0.0.1:8000/ride/rides/rideId={rideId}/dataframes/type={dftype}'
else:
    getdf = f'{domainName}/ride/rides/rideId={rideId}/dataframes/type={dftype}'
    
response = requests.get(getdf)
response
# Out:
# <Response [200]>

# %%
mdf = pd.read_csv(BytesIO(response.content))
mdf
# Out:
#                          time        ax        ay        az   latitude  \
# 0     2019-08-18 17:12:15.900  0.040527  0.953003 -0.210938  39.286986
# 1     2019-08-18 17:12:16.900 -0.019409  1.182129 -0.124573  39.286987
# 2     2019-08-18 17:12:17.900  0.048767  1.026855 -0.054932  39.286989
# 3     2019-08-18 17:12:18.900  0.016602  1.000488 -0.171631  39.286990
# 4     2019-08-18 17:12:19.800  0.001770  1.103638 -0.126282  39.286989
# ...                       ...       ...       ...       ...        ...
# 5823  2019-08-18 18:04:33.400 -1.798279  0.017578  1.210938        NaN
# 5824  2019-08-18 18:04:33.900 -1.798279  0.017578  1.210938        NaN
# 5825  2019-08-18 18:04:34.500 -1.798279  0.017578  1.210938        NaN
# 5826  2019-08-18 18:04:35.000 -1.798279  0.017578  1.210938        NaN
# 5827  2019-08-18 18:04:35.500 -1.798279  0.017578  1.210938        NaN
#
#       longitude  temperature    wet     timestamp
# 0    -74.552823    30.929688   True  1.566148e+09
# 1    -74.552814    30.750000   True  1.566148e+09
# 2    -74.552810    30.515625   True  1.566148e+09
# 3    -74.552804    30.351562   True  1.566148e+09
# 4    -74.552796    30.148438   True  1.566148e+09
# ...         ...          ...    ...           ...
# 5823        NaN  -133.601562  False  1.566151e+09
# 5824        NaN  -133.601562  False  1.566151e+09
# 5825        NaN  -133.601562  False  1.566151e+09
# 5826        NaN  -133.601562  False  1.566151e+09
# 5827        NaN  -133.601562  False  1.566151e+09
#
# [5828 rows x 9 columns]

# %% [markdown]
# ### delete ride by id

# %%
rideId = '15692'
if testing:
    rideDelete = f'http://127.0.0.1:8000/ride/rides/rideId={rideId}'
else:
    rideDelete = f'{domainName}/ride/rides/rideId={rideId}'

response = requests.delete(rideDelete)
response.content
