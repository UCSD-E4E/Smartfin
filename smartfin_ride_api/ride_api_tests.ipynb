# %% [markdown]
# # Smartfin Ride API
# The Smartfin Ride API makes it quick and easy to obtain smartfin ride data using a Django REST API.
#
# All ride queries go through the ride endpoint, so all urls should be in the format:
# "[domain name]/ride/"

# %%
base_url_example = f'http://127.0.0.1:8000/ride/'

# %% [markdown]
# you can add "many/" to the url, causing it to return multiple random rides worth of Smartfin data, and you can specify how many by inputting that number to the url as well along with the request's regular parameters.
#
# Here is an example of the url for retrieving the smartfinHeight of 20 rides:

# %%
fieldGetManyExample =  f'http://127.0.0.1:8000/ride/many/field-get/heightSmartfin/20'

# %% [markdown]
# if you just want to get one ride's worth of data, don't add "many/" to the url and just pass in the ride id instead of the count. Here is the same query but for one ride:

# %%
rideId = '15692'
field = 'heightSmartfin'
fieldGetSingleExample = f'http://127.0.0.1:8000/ride/field-get/{rideId}/{field}/'

# %% [markdown]
# ## EXAMPLES OF EACH FUNCTION

# %%
# imports
import requests
import pandas as pd
from io import StringIO

# %% [markdown]
# ## URLs

# %% [markdown]
# 'List all ride ids': '/ride-list/',
#
# 'Get single ride': '/ride-get/<str:rideId>/',
#
# 'Get random set of rides': '/many/ride-get/<int:count>/',
#
# 'Filter rides by location': '/location/ride-get/<str:location>/',
#
# 'Filter rides by date': '/date/ride-get/<str:startDate>/<str:endDate>/',
#
# 'Get single ride attribute': 'field-get/<str:rideId>/<str:fields>/',
#
# 'Get attributes of random set of rides': 'random/field-get/<int:count>/<str:fields>/',
#
# 'Get attributes of rides filtered by location': 'location/field-get/<str:location>/<str:fields>/',
#
# 'Get attributes of rides filtered by date': 'date/field-get/<str:startDate>/<str:endDate>/<str:fields>/',
#
# 'Update heights of all rides in database': 'update-heights/',
# 'Get list of active CDIP buoys': 'buoy-list/'

# %%
testing = False # determines what url we are requesting from

# %% [markdown]
# ## Create / Get New Ride(s)
# This query takes a rideId parameter and searches the database for that ride. If it doesn't exist then a new ride is created and all the data is uploaded and returned as a response. If the ride exists, then it just gets returned as a response. The actual data can be extracted from the response object using response.json() which formats the data as a python dictionary

# %%
rideId = '15692'
count = 0
location = 'San Diego'
startDate = '1541030400'
endDate = '1552566400'

if testing:
    rideGetSingle = f'http://127.0.0.1:8000/ride/ride-get/{rideId}/' # creates new ride and upload all ride data to db
    rideGetRandom = f'http://127.0.0.1:8000/ride/random/ride-get/{count}/' # creates new ride and upload all ride data to db
    rideGetLocation = f'http://127.0.0.1:8000/ride/location/ride-get/{location}/' # creates new ride and upload all ride data to db
    rideGetDate = f'http://127.0.0.1:8000/ride/date/ride-get/{startDate}/{endDate}/' # creates new ride and upload all ride data to db
else:
    rideGetSingle = f'https://lit-sands-95859.herokuapp.com/ride/ride-get/{rideId}/' # creates new ride and upload all ride data to db
    rideGetRandom = f'https://lit-sands-95859.herokuapp.com/ride/random/ride-get/{count}/' # creates new ride and upload all ride data to db
    rideGetLocation = f'https://lit-sands-95859.herokuapp.com/ride/location/ride-get/{location}/' # creates new ride and upload all ride data to db
    rideGetDate = f'https://lit-sands-95859.herokuapp.com/ride/date/ride-get/{startDate}/{endDate}/' # creates new ride and upload all r

# %% [markdown]
# ### get single ride by id

# %%
response = requests.get(rideGetSingle).json()
response
# Out:
# {'rideId': '15692',
#  'loc1': 'La Jolla',
#  'loc2': 'San Diego',
#  'loc3': 'San Diego County',
#  'startTime': '1541791072',
#  'endTime': '1541794669',
#  'heightSmartfin': 0.4627763961677482,
#  'heightList': '[0.13002787628578255, 0.09630767785969012, 0.06141652355998606, 0.14480514194889424, 0.1905285885846914, 0.09228307226388097, 0.06760592734572643, 0.04503542613327249, 0.06455273706961867, 0.19379453167362734, 0.0946668097935667, 0.17028749311005015, 0.24078977322006523, 0.22866089746876714, 0.01542811510811556, 0.19837595820703285, 0.1828868432144813, 0.07225801606643642, 0.2111497409266052, 0.05102051287370263, 0.21935835460424366, 0.1250843298147071, 0.038136233781319036, 0.2018124663248193, 0.11076352432229801, 0.043363887203159014, 0.011993105312607548, 0.027707515172119824, 0.20977906984520697, 0.05730773449329512, 0.052238809850149365, 0.17581231976553588, 0.09446714756230432, 0.16312804318672874, 0.12921150966097655, 0.15895461612502254, 0.035111810642651356, 0.08781922939591208, 0.192235732145595, 0.007777597366032309, 0.11526221916579622, 0.07320670882252223, 0.0305023351761021, 0.024605667169459007, 0.019452525653164902, 0.05762825536303809, 0.04380291458760845, 0.30328946189904016, 0.09113920840208117, 0.20172528579102916, 0.009900325472747364, 0.027498742028789134, 0.12339679387472138, 0.2953575417434464, 0.04605186231245004, 0.07039262555698324, 0.03946782409841734, 0.0371220720624367, 0.07344269077901114, 0.035663571446054615, 0.06722183949697691, 0.025932607541093288, 0.014778382265276573, 0.12500633692902888, 0.07513786288204191, 0.07160868347800228, 0.0846678776733138, 0.021927711492377485, 0.08436872424101013, 0.09266446408722209, 0.06802568871286338, 0.13682941165344623, 0.1297522605519344, 0.03203217997646285, 0.0648774415688246, 0.08149403701896504, 0.017110146010346237, 0.006715987431484562, 0.1732745476521645, 0.016025927644671603, 0.09581798781718029, 0.04501648259943908, 0.07505141643168639, 0.07012742161072363, 0.04454442711084086, 0.036118664932043396, 0.11681999836325022, 0.017211031918377813, 0.07893921127626521, 0.10453084952225306, 0.14727022794344802, 0.021583446186296873, 0.006397210099160838, 0.021008736893747125, 0.158585509181953, 0.03414894269337487, 0.20102437451535093, 0.02307469264109317, 0.10324464681038151, 0.02789267239323592, 0.030694946975574136, 0.16166760974445424, 0.12004798749065468, 0.11489886360242459, 0.043191678982626214, 0.013999059616257113, 0.13298721882654196, 0.2361305974500545, 0.026846629552892347, 0.03407797966791394, 0.11009555738896046, 0.17202042942763957, 0.12567940438612868, 0.08031792110561842, 0.13620938743405572, 0.030105520504099037, 0.07617518476658519, 0.0755194824970033, 0.051216270134753925, 0.11539915426922871, 0.038390582404771195, 0.2509865300572859, 0.5580025544429639, 0.21397111310619393, 0.016761043534013448, 0.13356534438899595, 0.09541874613702558, 0.014336098435047151, 0.05894316331353214, 0.03240083257558004, 0.11339318282794872, 0.0855056373899102, 0.014535484424174856, 0.17843025926827308, 0.2671522381475687, 0.05646324689495113, 0.05470696210781534, 0.08950526338543016, 0.11819769665740064, 0.10221004049403286, 0.01091798534473064, 0.014376633108225075, 0.04449134304546609, 0.04729432261010746, 0.15251117697285926, 0.045167017325472486, 0.055191351728327225, 0.10997534377396828, 0.007708052236441844, 0.05305044082744423, 0.05004811162022768, 0.051257049471486446, 0.026009986890157693, 0.09101873767348576, 0.024555819570931593, 0.21013060330221, 0.020392089605776348, 0.04517359459691113, 0.09836319174596295, 0.02679656843117522, 0.0048627840970882335, 0.02494579310036654, 0.07675935459493174, 0.011523599269266275, 0.03337749071474107, 0.009271481961648655, 0.1265355834923827, 0.07808882693351532, 0.11028062158116848, 0.17666887876182039, 0.17058985497343415, 0.1236098549777764, 0.08199698472901551, 0.047050451076198894, 0.048672207345167695, 0.020919483450013297, 0.1501758665826276, 0.12904074544784516, 0.02173697534195885, 0.05202576615377354]',
#  'heightSampleRate': 10,
#  'tempSmartfin': 20.044069023569023,
#  'tempList': '[20.688000000000002, 20.561999999999998, 20.5, 20.375, 20.375, 20.312, 20.25, 20.188, 20.188, 20.125, 20.062, 20.062, 20.062, 20.0, 20.0, 20.0, 20.0, 19.938, 19.938, 19.938, 19.875, 19.875, 19.875, 19.875, 19.875, 19.875, 19.875, 19.875, 20.0, 20.0, 20.0, 19.938, 19.938, 19.938, 19.938, 19.875, 19.875, 19.875, 19.875, 19.875, 19.938, 19.938, 19.938, 19.938, 19.938, 19.875, 19.938, 19.875, 19.875, 19.875, 19.875, 19.875, 19.875, 19.875, 19.875, 19.875, 19.875, 19.875, 19.875, 19.875, 19.875, 19.875, 19.875, 19.812, 19.875, 19.875, 19.875, 19.875, 19.875, 19.875, 19.875, 19.875, 19.875, 19.875, 19.875, 19.938, 19.875, 19.875, 19.938, 19.938, 19.875, 19.875, 19.938, 19.938, 19.875, 19.938, 19.938, 19.938, 19.938, 19.938, 19.938, 19.938, 19.938, 19.938, 19.938, 19.938, 19.938, 19.938, 19.938, 19.938, 19.938, 19.938, 19.938, 19.938, 19.938, 19.938, 19.938, 19.938, 19.938, 19.938, 19.938, 19.938, 19.938, 19.938, 19.875, 19.938, 19.938, 19.938, 20.0, 19.938, 20.0, 19.938, 19.938, 19.938, 19.938, 19.938, 19.938, 19.938, 19.938, 19.938, 19.938, 19.938, 19.938, 19.938, 19.938, 19.938, 19.938, 19.938, 19.938, 20.0, 19.938, 19.938, 20.0, 20.0, 20.0, 20.0, 20.0, 20.0, 20.0, 20.0, 20.0, 20.0, 20.0, 20.0, 19.938, 19.938, 20.0, 20.0, 20.0, 20.0, 20.0, 20.0, 20.0, 20.0, 20.0, 20.0, 20.0, 20.0, 20.0, 20.0, 20.0, 20.0, 20.0, 20.0, 20.0, 20.0, 20.0, 20.0, 20.0, 20.0, 20.0, 20.0, 20.0, 20.0, 20.062, 20.0, 20.0, 20.0, 20.0, 20.0, 20.0, 20.0, 20.0, 20.0, 20.0, 20.0, 20.0, 20.0, 20.0, 20.0, 20.0, 20.062, 20.062, 20.062, 20.062, 20.062, 20.062, 20.062, 20.062, 20.062, 20.062, 20.062, 20.062, 20.0, 20.0, 20.0, 20.0, 20.0, 20.0, 20.0, 20.0, 20.0, 20.0, 20.0, 20.0, 20.0, 20.0, 20.0, 20.062, 20.062, 20.0, 20.0, 20.062, 20.062, 20.062, 20.062, 20.062, 20.062, 20.062, 20.125, 20.125, 20.062, 20.062, 20.062, 20.062, 20.062, 20.062, 20.062, 20.062, 20.0, 20.0, 20.0, 20.0, 19.938, 19.938, 19.938, 19.938, 19.938, 19.938, 19.938, 19.938, 19.938, 19.938, 20.0, 20.0, 20.0, 20.062, 20.062, 20.062, 20.062, 20.062, 20.062, 20.0, 20.0, 20.0, 20.0, 20.0, 20.0, 20.0, 20.0, 20.0, 20.062, 20.0, 20.0, 20.0, 20.0, 20.0, 20.0, 20.0, 20.0, 20.0, 20.0, 20.0, 20.0, 20.0, 20.0, 20.0, 20.0, 20.0, 20.0, 20.0, 20.0, 20.0, 20.0, 20.0, 20.062, 20.0, 20.062, 20.0, 20.062, 20.0, 20.0, 20.062, 20.0, 20.0, 20.0, 20.062, 20.062, 20.062, 20.062, 20.062, 20.062, 20.062, 20.062, 20.062, 20.062, 20.125, 20.125, 20.062, 20.125, 20.125, 20.125, 20.125, 20.125, 20.125, 20.125, 20.125, 20.125, 20.125, 20.062, 20.125, 20.062, 20.125, 20.062, 20.062, 20.062, 20.062, 20.062, 20.062, 20.062, 20.062, 20.125, 20.062, 20.062, 20.062, 20.062, 20.062, 20.062, 20.125, 20.062, 20.062, 20.062, 20.062, 20.062, 20.062, 20.062, 20.062, 20.062, 20.062, 20.062, 20.062, 20.062, 20.062, 20.125, 20.125, 20.062, 20.062, 20.062, 20.062, 20.062, 20.062, 20.062, 20.062, 20.0, 20.062, 20.062, 20.0, 20.062, 20.0, 20.0, 20.062, 20.062, 20.0, 20.0, 20.0, 20.0, 20.0, 20.062, 20.062, 20.062, 20.062, 20.062, 20.062, 20.062, 20.062, 20.062, 20.062, 20.062, 20.125, 20.062, 20.062, 20.062, 20.062, 20.062, 20.062, 20.062, 20.062, 20.062, 20.125, 20.125, 20.125, 20.188, 20.188, 20.188, 20.125, 20.125, 20.125, 20.125, 20.125, 20.125, 20.062, 20.062, 20.062, 20.062, 20.062, 20.0, 20.0, 20.062, 20.062, 20.125, 20.125, 20.125, 20.062, 20.062, 20.062, 20.062, 20.062, 20.062, 20.0, 20.0, 19.938, 19.938, 20.0, 20.0, 20.0, 20.0, 20.0, 20.062, 20.062, 20.0, 20.062, 20.062, 20.125, 20.125, 20.125, 20.125, 20.125, 20.125, 20.125, 20.125, 20.125, 20.125, 20.062, 20.062, 20.062, 20.125, 20.125, 20.062, 20.062, 20.062, 20.062, 20.062, 20.0, 20.0, 20.0, 20.0, 19.938, 19.938, 19.938, 19.938, 20.0, 20.0, 20.0, 20.0, 20.062, 20.125, 20.062, 20.062, 20.0, 20.0, 20.0, 19.938, 20.0, 20.062, 20.062, 20.125, 20.125, 20.125, 20.125, 20.188, 20.125, 20.188, 20.125, 20.125, 20.125, 20.125, 20.125, 20.062, 20.125, 20.188, 20.188, 20.188, 20.188, 20.188, 20.188, 20.188, 20.188, 20.125, 20.125, 20.125, 20.125, 20.125, 20.125, 20.062, 20.062, 20.0 ...
#  'tempSampleRate': 6,
#  'buoyCDIP': '201',
#  'heightCDIP': 0.4414551854133606,
#  'tempCDIP': 19.860002517700195,
#  'latitude': 32.86058653508772,
#  'longitude': -117.25365867324561,
#  'motionData': 'UTC,Time,IMU A1,IMU A2,IMU A3,IMU G1,IMU G2,IMU G3,IMU M1,IMU M2,IMU M3\n2018-11-09 19:17:52+00:00,1414850.8732,-0.2825157958984375,-0.01915361328125087,2.31758720703125,-21.5,23.0,2.5,-39.5,-171.0,186.0\n2018-11-09 19:17:53+00:00,1414851.86525,0.26815058593749996,-0.282515795898437,1.5658078857421873,7.0,15.25,16.5,-42.25,-165.25,195.25\n2018-11-09 19:17:54+00:00,1414852.86775,-0.2154781494140625,-0.05746083984375083,1.7190367919921874,52.0,35.25,-2.0,-43.75,-171.75,189.75\n2018-11-09 19:17:55+00:00,1414853.86825,-0.033518823242187495,0.05267243652343723,2.27927998046875,10.25,39.5,52.5,-42.75,-169.75,184.75\n2018-11-09 19:17:56+00:00,1414854.86275,-0.19153613281249998,1.3646949462890632,1.3024457031249999,-63.25,-45.75,103.0,-92.0,-158.0,209.5\n2018-11-09 19:17:57+00:00,1414855.969,1.388636962890625,0.22026655273437434,2.0925322509765625,72.25,142.75,-112.25,-12.25,-162.25,184.75\n2018-11-09 19:17:58+00:00,1414856.8655,-0.1771709228515625,-0.12928688964843715,1.867477294921875,7.25,50.75,28.0,-48.5,-162.5,201.0\n2018-11-09 19:17:59+00:00,1414857.864,0.0047884033203125,-0.46447512207031316,1.6615759521484375,42.75,27.0,-15.25,-53.75,-166.25,193.25\n2018-11-09 19:18:00+00:00,1414858.86475,-0.4261678955078125,-0.12449848632812532,1.455674609375,-36.0,21.75,9.25,-52.0,-163.0,203.5\n2018-11-09 19:18:01+00:00,1414859.8685,-0.74699091796875,-0.26815058593749974,1.0678139404296874,36.0,37.0,-11.75,-53.25,-160.75,207.75\n2018-11-09 19:18:02+00:00,1414860.868,-0.842758984375,0.5554547851562504,1.2737152832031249,61.5,24.25,103.75,-96.25,-167.75,191.25\n2018-11-09 19:18:03+00:00,1414861.8612000002,0.16280571289062498,-2.006340991210937,3.2034418212890623,-164.25,50.25,-58.0,-49.75,-168.75,182.25\n2018-11-09 19:18:04+00:00,1414862.86725,-1.7286135986328124,-0.1628057128906253,3.8690298828125,43.5,108.0,35.0,-67.25,-182.75,101.25\n2018-11-09 19:18:05+00:00,1414863.86575,-1.1109095703125,0.5027823486328131,2.001552587890625,102.25,-25.0,-7.25,-80.0,-167.0,185.5\n2018-11-09 19:18:06+00:00,1414864.8685,-0.6368576416015624,-0.2537853759765625,1.6136919189453125,-32.5,31.25,18.25,-69.25,-163.25,198.75\n2018-11-09 19:18:07+00:00,1414865.86425,-1.1013327636718748,-0.31603461914062514,1.656787548828125,40.5,-12.75,6.5,-62.75,-163.25,203.25\n2018-11-09 19:18:08+00:00,1414866.8608,0.32082302246093747,-0.27293898925781335,1.7190367919921874,-31.25,-23.5,26.75,-63.0,-165.0,202.0\n2018-11-09 19:18:09+00:00,1414867.865,-0.8762778076171874,1.0582371337890617,2.6431986328124997,50.25,-32.75,-88.25,-66.5,-174.5,159.0\n2018-11-09 19:18:10+00:00,1414868.8635,-0.1867477294921875,-0.3064578124999997,0.507570751953125,-18.75,119.5,17.5,-43.75,-161.75,201.75\n2018-11-09 19:18:11+00:00,1414869.8665,0.181959326171875,-0.028730419921874528,1.9297265380859374,-28.25,1.25,23.25,-58.25,-164.25,202.75\n2018-11-09 19:18:12+00:00,1414870.87,-0.814028564453125,-0.2537853759765625,1.446097802734375,14.5,-14.5,-14.25,-61.75,-166.75,195.75\n2018-11-09 19:18:13+00:00,1414871.8625,-0.8188169677734375,0.10055646972656263,1.426944189453125,29.75,64.5,21.75,-58.75,-168.25,202.75\n2018-11-09 19:18:14+00:00,1414872.7522,-1.0582371337890624,-0.3256114257812506,1.465251416015625,2.5,19.75,-2.25,-63.0,-163.0,205.5\n2018-11-09 19:18:15+00:00,1414873.86875,-0.6560112548828124,-0.32082302246093697,1.7238251953125,1.5,21.25,22.5,-66.0,-166.0,198.5\n2018-11-09 19:18:16+00:00,1414874.86675,-0.40222587890625,-0.31603461914062514,1.8339584716796873,30.0,25.5,23.25,-66.5,-168.0,198.0\n2018-11-09 19:18:17+00:00,1414875.8665,-0.565031591796875,0.6272808349609367,2.346317626953125,-99.75,-21.25,68.0,-101.5,-171.0,178.5\n2018-11-09 19:18:18+00:00,1414876.869,-1.216254443359375,-1.8483236816406245,1.5418658691406248,30.25,172.25,-37.75,-71.5,-169.5,179.0\n2018-11-09 19:18:19+00:00,1414877.844,-0.2537853759765625,0.21547814941406251,2.0446482177734375,26.0,70.75,-20.75,-116.25,-165.25,188.75\n2018-11-09 19:18:20+00:00,1414878.86375,-0.5363011718749999,-0.11013327636718806,1.4365209 ...
#  'oceanData': 'UTC,Time,Temperature 1,Calibrated Temperature 1,Temperature 1 Stable,Temperature 2,Calibrated Temperature 2,Temperature 2 Stable\n2018-11-09 19:17:52+00:00,1414850803.0,331.0,20.688000000000002,0.0,4996.0,19.684,0.0\n2018-11-09 19:17:58+00:00,1414856823.0,329.0,20.561999999999998,0.0,4983.0,19.633,0.0\n2018-11-09 19:18:04+00:00,1414862844.0,328.0,20.5,0.0,4987.0,19.649,0.0\n2018-11-09 19:18:10+00:00,1414868864.0,326.0,20.375,0.0,4990.0,19.660999999999998,0.0\n2018-11-09 19:18:16+00:00,1414874884.0,326.0,20.375,0.0,4994.0,19.676,0.0\n2018-11-09 19:18:22+00:00,1414880903.0,325.0,20.312,0.0,4989.0,19.657,0.0\n2018-11-09 19:18:28+00:00,1414886923.0,324.0,20.25,0.0,4983.0,19.633,0.0\n2018-11-09 19:18:34+00:00,1414892943.0,323.0,20.188,0.0,4981.0,19.625,0.0\n2018-11-09 19:18:40+00:00,1414898962.0,323.0,20.188,0.0,4966.0,19.567,0.0\n2018-11-09 19:18:46+00:00,1414904982.0,322.0,20.125,0.0,4965.0,19.563,0.0\n2018-11-09 19:18:52+00:00,1414911002.0,321.0,20.062,0.0,4957.0,19.531,0.0\n2018-11-09 19:18:59+00:00,1414917022.0,321.0,20.062,0.0,4953.0,19.516,0.0\n2018-11-09 19:19:05+00:00,1414923042.0,321.0,20.062,0.0,4959.0,19.539,0.0\n2018-11-09 19:19:11+00:00,1414929062.0,320.0,20.0,0.0,4968.0,19.574,0.0\n2018-11-09 19:19:17+00:00,1414935082.0,320.0,20.0,0.0,4967.0,19.57,0.0\n2018-11-09 19:19:23+00:00,1414941102.0,320.0,20.0,0.0,4967.0,19.57,1.0\n2018-11-09 19:19:29+00:00,1414947122.0,320.0,20.0,0.0,4968.0,19.574,1.0\n2018-11-09 19:19:35+00:00,1414953141.0,319.0,19.938,0.0,4969.0,19.578,1.0\n2018-11-09 19:19:41+00:00,1414959162.0,319.0,19.938,0.0,4976.0,19.605999999999998,1.0\n2018-11-09 19:19:47+00:00,1414965182.0,319.0,19.938,0.0,4970.0,19.582,1.0\n2018-11-09 19:19:53+00:00,1414971203.0,318.0,19.875,0.0,4974.0,19.598,1.0\n2018-11-09 19:19:59+00:00,1414977223.0,318.0,19.875,0.0,4973.0,19.594,1.0\n2018-11-09 19:20:05+00:00,1414983243.0,318.0,19.875,0.0,4968.0,19.574,1.0\n2018-11-09 19:20:11+00:00,1414989263.0,318.0,19.875,0.0,4979.0,19.618,0.0\n2018-11-09 19:20:17+00:00,1414995284.0,318.0,19.875,0.0,4982.0,19.629,0.0\n2018-11-09 19:20:23+00:00,1415001304.0,318.0,19.875,0.0,4969.0,19.578,0.0\n2018-11-09 19:20:29+00:00,1415007324.0,318.0,19.875,0.0,4999.0,19.695999999999998,0.0\n2018-11-09 19:20:35+00:00,1415013345.0,318.0,19.875,0.0,5008.0,19.730999999999998,0.0\n2018-11-09 19:20:41+00:00,1415019365.0,320.0,20.0,0.0,4982.0,19.629,0.0\n2018-11-09 19:20:48+00:00,1415025387.0,320.0,20.0,0.0,4980.0,19.621,0.0\n2018-11-09 19:20:54+00:00,1415031407.0,320.0,20.0,0.0,4974.0,19.598,0.0\n2018-11-09 19:21:00+00:00,1415037426.0,319.0,19.938,0.0,4971.0,19.586,0.0\n2018-11-09 19:21:06+00:00,1415043447.0,319.0,19.938,0.0,4957.0,19.531,1.0\n2018-11-09 19:21:12+00:00,1415049468.0,319.0,19.938,0.0,4966.0,19.567,0.0\n2018-11-09 19:21:18+00:00,1415055489.0,319.0,19.938,0.0,4961.0,19.547,0.0\n2018-11-09 19:21:24+00:00,1415061509.0,318.0,19.875,0.0,4949.0,19.5,0.0\n2018-11-09 19:21:30+00:00,1415067529.0,318.0,19.875,0.0,4960.0,19.543,0.0\n2018-11-09 19:21:36+00:00,1415073549.0,318.0,19.875,0.0,4971.0,19.586,0.0\n2018-11-09 19:21:42+00:00,1415079568.0,318.0,19.875,0.0,4967.0,19.57,0.0\n2018-11-09 19:21:48+00:00,1415085588.0,318.0,19.875,0.0,4976.0,19.605999999999998,0.0\n2018-11-09 19:21:54+00:00,1415091608.0,319.0,19.938,0.0,4961.0,19.547,0.0\n2018-11-09 19:22:00+00:00,1415097627.0,319.0,19.938,0.0,4967.0,19.57,0.0\n2018-11-09 19:22:06+00:00,1415103648.0,319.0,19.938,0.0,4964.0,19.559,0.0\n2018-11-09 19:22:12+00:00,1415109668.0,319.0,19.938,0.0,4967.0,19.57,0.0\n2018-11-09 19:22:18+00:00,1415115688.0,319.0,19.938,0.0,4957.0,19.531,0.0\n2018-11-09 19:22:24+00:00,1415121708.0,318.0,19.875,1.0,4956.0,19.527,1.0\n2018-11-09 19:22:30+00:00,1415127729.0,319.0,19.938,0.0,4966.0,19.567,0.0\n2018-11-09 19:22:37+00:00,1415133749.0,318.0,19.875,0.0,4973.0,19.594,0.0\n2018-11-09 19:22:43+00:00,1415139770.0,318.0,19.875,1.0,4969.0,19.578,1.0\n2018-11-09 19:22:49+00:00,1415145789.0,318.0,19.875,1.0,4969.0,19.578,1.0\n2018-11-09 19:22:55+00:00,1415151809.0,318.0, ...

# %% [markdown]
# ### get multiple random rides

# %%
response = requests.get(rideGetRandom)
data = response.json()
[ride['rideId'] for ride in data]
# Out:
# ['15692',
#  '16380',
#  '16376',
#  '16345',
#  '16318',
#  '16302',
#  '16301',
#  '16300',
#  '16299',
#  '16298',
#  '16297',
#  '16290',
#  '16289',
#  '16278',
#  '16262',
#  '16253',
#  '16252',
#  '16250',
#  '16249',
#  '16243',
#  '16239',
#  '16238',
#  '16237',
#  '16225',
#  '16222',
#  '16221',
#  '16212',
#  '16211',
#  '16197',
#  '16196',
#  '16195',
#  '16192',
#  '16191',
#  '16189',
#  '16178',
#  '16177',
#  '16175',
#  '16173',
#  '16171',
#  '16169',
#  '16168',
#  '16167',
#  '16161',
#  '16160',
#  '16158',
#  '16152',
#  '16148',
#  '16140',
#  '16137',
#  '16135',
#  '16134',
#  '16128',
#  '16126',
#  '16115',
#  '16106',
#  '16103',
#  '16101',
#  '16100',
#  '16099',
#  '16098',
#  '16088',
#  '16081',
#  '16079',
#  '16076',
#  '16075',
#  '16073',
#  '16072',
#  '16000',
#  '15996',
#  '15983',
#  '15980',
#  '15978',
#  '15972',
#  '15963',
#  '15962',
#  '15953',
#  '15945',
#  '15859',
#  '15858',
#  '15857',
#  '15856',
#  '15854',
#  '15848']

# %% [markdown]
# ### get multiple rides by location

# %%
response = requests.get(rideGetLocation)
data = response.json()
[ride['rideId'] for ride in data]
# Out:
# ['15692',
#  '16380',
#  '16345',
#  '16318',
#  '16302',
#  '16301',
#  '16298',
#  '16290',
#  '16289',
#  '16250',
#  '16249',
#  '16239',
#  '16238',
#  '16237',
#  '16225',
#  '16222',
#  '16221',
#  '16212',
#  '16211',
#  '16197',
#  '16195',
#  '16192',
#  '16191',
#  '16178',
#  '16177',
#  '16173',
#  '16171',
#  '16169',
#  '16168',
#  '16167',
#  '16161',
#  '16158',
#  '16148',
#  '16137',
#  '16135',
#  '16134',
#  '16128',
#  '16126',
#  '16115',
#  '16106',
#  '16103',
#  '16101',
#  '16100',
#  '16099',
#  '16081',
#  '16079',
#  '16076',
#  '16000',
#  '15996',
#  '15980',
#  '15972',
#  '15963',
#  '15962',
#  '15945',
#  '15859',
#  '15857',
#  '15856',
#  '15854',
#  '15848']

# %% [markdown]
# ### get multiple rides between start and end date

# %%
response = requests.get(rideGetDate)
data = response.json()
[ride['rideId'] for ride in data]
# Out:
# ['15692',
#  '15983',
#  '15980',
#  '15978',
#  '15972',
#  '15963',
#  '15962',
#  '15953',
#  '15945',
#  '15859',
#  '15858',
#  '15857',
#  '15856',
#  '15854',
#  '15848']

# %% [markdown]
# ## Get field(s) of ride(s)
# gets a single attribute of a ride in the database. If count = 1, then we only retrieve the specified ride id, if count > 1, retrieve that amount of rides randomly

# %%
fields = 'heightSmartfin'

if testing:
    fieldGetSingle = f'http://127.0.0.1:8000/ride/field-get/{rideId}/{fields}/' # creates new ride and upload all ride data to db
    fieldGetRandom = f'http://127.0.0.1:8000/ride/random/field-get/{count}/{fields}/' # creates new ride and upload all ride data to db
    fieldGetLocation = f'http://127.0.0.1:8000/ride/location/field-get/{location}/{fields}/' # creates new ride and upload all ride data to db
    fieldGetDate = f'http://127.0.0.1:8000/ride/date/field-get/{startDate}/{endDate}/{fields}/' # creates new ride and upload all ride data to db
else:
    fieldGetSingle = f'https://lit-sands-95859.herokuapp.com/ride/field-get/{rideId}/{fields}/' # creates new ride and upload all ride data to db
    fieldGetRandom = f'https://lit-sands-95859.herokuapp.com/ride/random/field-get/{count}/{fields}/' # creates new ride and upload all ride data to db
    fieldGetLocation = f'https://lit-sands-95859.herokuapp.com/ride/location/field-get/{location}/{fields}/' # creates new ride and upload all ride data to db
    fieldGetDate = f'https://lit-sands-95859.herokuapp.com/ride/date/field-get/{startDate}/{endDate}/{fields}/' # creates new ride and upload all ride data to db

# %%
response = requests.get(fieldGetSingle)
response.json()
# Out:
# {'heightSmartfin': 0.4627763961677482}

# %% [markdown]
# ### get fields of random rides

# %%
response = requests.get(fieldGetRandom)
response.json()['data']
# Out:
# [{'rideId': '15692', 'heightSmartfin': 0.4627763961677482},
#  {'rideId': '16380', 'heightSmartfin': 0.5590487240759578},
#  {'rideId': '16376', 'heightSmartfin': 0.9452605601171257},
#  {'rideId': '16345', 'heightSmartfin': 0.4584316394793693},
#  {'rideId': '16318', 'heightSmartfin': 0.5046445915309702},
#  {'rideId': '16302', 'heightSmartfin': 0.6496881974640748},
#  {'rideId': '16301', 'heightSmartfin': 0.3980063825082968},
#  {'rideId': '16300', 'heightSmartfin': 0.5119586229454351},
#  {'rideId': '16299', 'heightSmartfin': 0.42575072751492293},
#  {'rideId': '16298', 'heightSmartfin': 0.6827793676797396},
#  {'rideId': '16297', 'heightSmartfin': 0.4277936109265481},
#  {'rideId': '16290', 'heightSmartfin': 1.3478621251970722},
#  {'rideId': '16289', 'heightSmartfin': 0.6106659239662217},
#  {'rideId': '16278', 'heightSmartfin': 13.408752684422717},
#  {'rideId': '16262', 'heightSmartfin': 0.4966136986782835},
#  {'rideId': '16253', 'heightSmartfin': 0.7600966185439203},
#  {'rideId': '16252', 'heightSmartfin': 0.5349635351126728},
#  {'rideId': '16250', 'heightSmartfin': 0.5267541266279585},
#  {'rideId': '16249', 'heightSmartfin': 0.320888589939161},
#  {'rideId': '16243', 'heightSmartfin': 0.6206356862244736},
#  {'rideId': '16239', 'heightSmartfin': 0.6741870881720926},
#  {'rideId': '16238', 'heightSmartfin': 0.31457115052745704},
#  {'rideId': '16237', 'heightSmartfin': 0.32335430876906257},
#  {'rideId': '16225', 'heightSmartfin': 0.54981810136727},
#  {'rideId': '16222', 'heightSmartfin': 0.47084205191039},
#  {'rideId': '16221', 'heightSmartfin': 0.4319540899458727},
#  {'rideId': '16212', 'heightSmartfin': 0.4103879821867719},
#  {'rideId': '16211', 'heightSmartfin': 0.5029026028915657},
#  {'rideId': '16197', 'heightSmartfin': 0.8295003310935322},
#  {'rideId': '16196', 'heightSmartfin': 5.458667578375172},
#  {'rideId': '16195', 'heightSmartfin': 0.44575377137086303},
#  {'rideId': '16192', 'heightSmartfin': 0.49044612903692486},
#  {'rideId': '16191', 'heightSmartfin': 0.5991598279960914},
#  {'rideId': '16189', 'heightSmartfin': 0.3239138692256915},
#  {'rideId': '16178', 'heightSmartfin': 0.4679436020698194},
#  {'rideId': '16177', 'heightSmartfin': 0.6216348169477769},
#  {'rideId': '16175', 'heightSmartfin': 0.5762497547269518},
#  {'rideId': '16173', 'heightSmartfin': 0.49591636864541633},
#  {'rideId': '16171', 'heightSmartfin': 0.5500457606026834},
#  {'rideId': '16169', 'heightSmartfin': 0.422189613665582},
#  {'rideId': '16168', 'heightSmartfin': 0.5290967091550641},
#  {'rideId': '16167', 'heightSmartfin': 0.5303050483699155},
#  {'rideId': '16161', 'heightSmartfin': 0.5393537657170508},
#  {'rideId': '16160', 'heightSmartfin': 0.9571022901502121},
#  {'rideId': '16158', 'heightSmartfin': 0.6267886754580873},
#  {'rideId': '16152', 'heightSmartfin': 0.6273824630263807},
#  {'rideId': '16148', 'heightSmartfin': 0.7424905027257902},
#  {'rideId': '16140', 'heightSmartfin': 0.37670778361373486},
#  {'rideId': '16137', 'heightSmartfin': 0.292369410048274},
#  {'rideId': '16135', 'heightSmartfin': 0.39656736009880406},
#  {'rideId': '16134', 'heightSmartfin': 0.36117532006700653},
#  {'rideId': '16128', 'heightSmartfin': 0.6370554722934997},
#  {'rideId': '16126', 'heightSmartfin': 0.5590969240352415},
#  {'rideId': '16115', 'heightSmartfin': 0.780947768660232},
#  {'rideId': '16106', 'heightSmartfin': 0.8697398594896543},
#  {'rideId': '16103', 'heightSmartfin': 0.9494276331676084},
#  {'rideId': '16101', 'heightSmartfin': 0.42186578505971706},
#  {'rideId': '16100', 'heightSmartfin': 0.6082320081965215},
#  {'rideId': '16099', 'heightSmartfin': 5.8803668666855895},
#  {'rideId': '16098', 'heightSmartfin': 0.6379587389842524},
#  {'rideId': '16088', 'heightSmartfin': 0.7172927274501932},
#  {'rideId': '16081', 'heightSmartfin': 0.5719928009663098},
#  {'rideId': '16079', 'heightSmartfin': 0.5412308009993136},
#  {'rideId': '16076', 'heightSmartfin': 0.5709620498929476},
#  {'rideId': '16075', 'heightSmartfin': 0.6175169676761413},
#  {'rideId': '16073', 'heightSmartfin': 0.5076929158964522},
#  {'rideId': '16072', 'heightSmartfin': 0.42220742976990366},
#  {'rideId': '16000', 'heightSmartfin': 0.41188492125104315},
#  {'rideId': '15996', 'heightSmartfin': 0.5408493348769459},
#  {'rideId': '15983', 'heightSmartfin': 0.6304485142589018},
#  {'rideId': '15980', 'heightSmartfin': 1.2310790203744395},
#  {'rideId': '15978', 'heightSmartfin': 0.47447633441911763},
#  {'rideId': '15972', 'heightSmartfin': 0.6435360852109306},
#  {'rideId': '15963', 'heightSmartfin': 0.8760445295484257},
#  {'rideId': '15962', 'heightSmartfin': 0.4584329574188188},
#  {'rideId': '15953', 'heightSmartfin': 0.7418679161313633},
#  {'rideId': '15945', 'heightSmartfin': 0.3981912713268298},
#  {'rideId': '15859', 'heightSmartfin': 0.7226037488125758},
#  {'rideId': '15858', 'heightSmartfin': 0.6433389939696775},
#  {'rideId': '15857', 'heightSmartfin': 0.46273299498116394},
#  {'rideId': '15856', 'heightSmartfin': 0.3239601440036302},
#  {'rideId': '15854', 'heightSmartfin': 0.5801816260967135},
#  {'rideId': '15848', 'heightSmartfin': 0.5300296239462102}]

# %% [markdown]
# ### get fields of rides by location

# %%
response = requests.get(fieldGetLocation)
response.json()['data']
# Out:
# [{'heightSmartfin': 0.4627763961677482},
#  {'heightSmartfin': 0.5590487240759578},
#  {'heightSmartfin': 0.9452605601171257},
#  {'heightSmartfin': 0.4584316394793693},
#  {'heightSmartfin': 0.5046445915309702},
#  {'heightSmartfin': 0.6496881974640748},
#  {'heightSmartfin': 0.3980063825082968},
#  {'heightSmartfin': 0.5119586229454351},
#  {'heightSmartfin': 0.42575072751492293},
#  {'heightSmartfin': 0.6827793676797396},
#  {'heightSmartfin': 0.4277936109265481},
#  {'heightSmartfin': 1.3478621251970722},
#  {'heightSmartfin': 0.6106659239662217},
#  {'heightSmartfin': 13.408752684422717},
#  {'heightSmartfin': 0.4966136986782835},
#  {'heightSmartfin': 0.7600966185439203},
#  {'heightSmartfin': 0.5349635351126728},
#  {'heightSmartfin': 0.5267541266279585},
#  {'heightSmartfin': 0.320888589939161},
#  {'heightSmartfin': 0.6206356862244736},
#  {'heightSmartfin': 0.6741870881720926},
#  {'heightSmartfin': 0.31457115052745704},
#  {'heightSmartfin': 0.32335430876906257},
#  {'heightSmartfin': 0.54981810136727},
#  {'heightSmartfin': 0.47084205191039},
#  {'heightSmartfin': 0.4319540899458727},
#  {'heightSmartfin': 0.4103879821867719},
#  {'heightSmartfin': 0.5029026028915657},
#  {'heightSmartfin': 0.8295003310935322},
#  {'heightSmartfin': 5.458667578375172},
#  {'heightSmartfin': 0.44575377137086303},
#  {'heightSmartfin': 0.49044612903692486},
#  {'heightSmartfin': 0.5991598279960914},
#  {'heightSmartfin': 0.3239138692256915},
#  {'heightSmartfin': 0.4679436020698194},
#  {'heightSmartfin': 0.6216348169477769},
#  {'heightSmartfin': 0.5762497547269518},
#  {'heightSmartfin': 0.49591636864541633},
#  {'heightSmartfin': 0.5500457606026834},
#  {'heightSmartfin': 0.422189613665582},
#  {'heightSmartfin': 0.5290967091550641},
#  {'heightSmartfin': 0.5303050483699155},
#  {'heightSmartfin': 0.5393537657170508},
#  {'heightSmartfin': 0.9571022901502121},
#  {'heightSmartfin': 0.6267886754580873},
#  {'heightSmartfin': 0.6273824630263807},
#  {'heightSmartfin': 0.7424905027257902},
#  {'heightSmartfin': 0.37670778361373486},
#  {'heightSmartfin': 0.292369410048274},
#  {'heightSmartfin': 0.39656736009880406},
#  {'heightSmartfin': 0.36117532006700653},
#  {'heightSmartfin': 0.6370554722934997},
#  {'heightSmartfin': 0.5590969240352415},
#  {'heightSmartfin': 0.780947768660232},
#  {'heightSmartfin': 0.8697398594896543},
#  {'heightSmartfin': 0.9494276331676084},
#  {'heightSmartfin': 0.42186578505971706},
#  {'heightSmartfin': 0.6082320081965215},
#  {'heightSmartfin': 5.8803668666855895},
#  {'heightSmartfin': 0.6379587389842524},
#  {'heightSmartfin': 0.7172927274501932},
#  {'heightSmartfin': 0.5719928009663098},
#  {'heightSmartfin': 0.5412308009993136},
#  {'heightSmartfin': 0.5709620498929476},
#  {'heightSmartfin': 0.6175169676761413},
#  {'heightSmartfin': 0.5076929158964522},
#  {'heightSmartfin': 0.42220742976990366},
#  {'heightSmartfin': 0.41188492125104315},
#  {'heightSmartfin': 0.5408493348769459},
#  {'heightSmartfin': 0.6304485142589018},
#  {'heightSmartfin': 1.2310790203744395},
#  {'heightSmartfin': 0.47447633441911763},
#  {'heightSmartfin': 0.6435360852109306},
#  {'heightSmartfin': 0.8760445295484257},
#  {'heightSmartfin': 0.4584329574188188},
#  {'heightSmartfin': 0.7418679161313633},
#  {'heightSmartfin': 0.3981912713268298},
#  {'heightSmartfin': 0.7226037488125758},
#  {'heightSmartfin': 0.6433389939696775},
#  {'heightSmartfin': 0.46273299498116394},
#  {'heightSmartfin': 0.3239601440036302},
#  {'heightSmartfin': 0.5801816260967135},
#  {'heightSmartfin': 0.5300296239462102}]

# %% [markdown]
# ### get fields of rides by date

# %%
response = requests.get(fieldGetDate)
response.json()['data']
# Out:
# [{'heightSmartfin': 0.4627763961677482},
#  {'heightSmartfin': 0.6304485142589018},
#  {'heightSmartfin': 1.2310790203744395},
#  {'heightSmartfin': 0.47447633441911763},
#  {'heightSmartfin': 0.6435360852109306},
#  {'heightSmartfin': 0.8760445295484257},
#  {'heightSmartfin': 0.4584329574188188},
#  {'heightSmartfin': 0.7418679161313633},
#  {'heightSmartfin': 0.3981912713268298},
#  {'heightSmartfin': 0.7226037488125758},
#  {'heightSmartfin': 0.6433389939696775},
#  {'heightSmartfin': 0.46273299498116394},
#  {'heightSmartfin': 0.3239601440036302},
#  {'heightSmartfin': 0.5801816260967135},
#  {'heightSmartfin': 0.5300296239462102}]

# %% [markdown]
# ### update heights of rides in db

# %% [markdown]
# ### list all active CDIP buoys

# %%
if testing:
    buoyList = 'http://127.0.0.1:8000/ride/buoy-list'
else:
    buoyList = 'https://lit-sands-95859.herokuapp.com/ride/buoy-list/'

# %%
response = requests.get(buoyList)
data = response.json()
data
# Out:
# ['028',
#  '029',
#  '036',
#  '045',
#  '067',
#  '071',
#  '076',
#  '092',
#  '094',
#  '098',
#  '100',
#  '103',
#  '106',
#  '121',
#  '132',
#  '134',
#  '139',
#  '142',
#  '143',
#  '147',
#  '150',
#  '154',
#  '155',
#  '157',
#  '158',
#  '160',
#  '162',
#  '163',
#  '166',
#  '168',
#  '171',
#  '179',
#  '181',
#  '185',
#  '187',
#  '188',
#  '189',
#  '191',
#  '192',
#  '194',
#  '196',
#  '197',
#  '198',
#  '200',
#  '201',
#  '203',
#  '209',
#  '213',
#  '214',
#  '215',
#  '217',
#  '220',
#  '221',
#  '222',
#  '224',
#  '225',
#  '226',
#  '230',
#  '233',
#  '236',
#  '238',
#  '239',
#  '240',
#  '243',
#  '244',
#  '247',
#  '430',
#  '433']
